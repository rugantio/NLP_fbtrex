# %% [markdown]
# # Argentine Election Analysis

# %% [markdown]
# ## Introduction
# In this notebook I analyze a Spanish dataset set up during the [Argentine legislative election](https://en.wikipedia.org/wiki/Argentine_legislative_election,_2017) of 2017.
# This dataset contains the data of 9 facebook bots, crawled over a period of 16 days, following 45 sources.
#
# __Note__: If you haven't done it already, go through the set up in the *README* of [this repo](https://github.com/rugantio/nlp_fbtrex/).
#
# ### Roadmap
# Download dataset -> cast JSON to txt -> tokenization -> normalization -> phrase modeling -> topic mining -> burst the bubble -> word2vec algebra & predictive analysis
#
# ## Dataset
# The dataset was prepared by the [__Facebook Tracking Exposed__](https://facebook.tracking.exposed/) project and can be retrieved in a convenient JSON format from the specific GitHub [__repo__](https://github.com/tracking-exposed/experiments-data/tree/master/silver).
# There are two separate files that we'll try to breakdown:
# * __fbtrex-data-\*.json__ - Contains all impressions relative to single users
# * __semantic-entities.json__ - Contains all available metadata regarding posts
#
# The text field of every posts is enclosed in *semantic-entities.json*, while I can use *fbtrex-data-\*.json* to correlate which user has visualized this content, thus providing an easy way to investigate the Facebook filter bubble.
# Given a ready working environment, as explained is the *README* of this repo, just go ahead and download the files:

# %%
# %%bash
# #Download Argentine dataset in a data subdir
# mkdir data && cd data
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/fbtrex-data-1.json.zip
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/semantic-entities.json.zip

# %% [markdown]
# __Note__: This commands are supposed to be executed in a bash environment, not in the notebook itself. The operation may fail due to permissions.
#
# Extract the content from the zip archive:

# %%
# %%bash
# #Extract JSON from zipped archives
# cd data
# unzip fbtrex-data-1.json.zip
# unzip semantic-entities.json.zip

# %% [markdown]
# __Note__: To try out this notebook I made a shorter version of the JSON, I highly recommend to do the same

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Now that we have the dataset in JSON format, we can use the [JSON Python library](https://docs.python.org/3/library/json.html) to decode its content and store it in a Python variable. The variable type depends on the actual content of the provided file, by [default](https://docs.python.org/3/library/json.html#json-to-py-table) a JSON object is decoded to a dict and an arrays to a list. The recommended approach for working with encoded text files, is to use the [codecs Python library](https://docs.python.org/3/library/codecs.html):

# %%
import codecs
import json

with codecs.open('data/semantic-entities.json',encoding='utf-8') as data_json:    
    data = json.load(data_json)

# %% [markdown]
# To print to stdout the content of the parsed JSON file just use [pprint](https://docs.python.org/3/library/pprint.html), the data pretty printer:

# %%
import pprint
pprint.pprint(data)

# %% [markdown]
# It's useful to check if the casting was performed correctly before proceding, the resulting decoded type can be inspected with:

# %%
print(type(data))
# Out:
# <class 'list'>

# %% [markdown]
# __Note__: If you are using Spyder IDE you can keep track of variable simply looking at the variable explorer window.
#
# So the JSON is now a list. How many entities do we have?

# %%
data_len = len(data)
print('There are {} total elements to analyze.'.format(data_len+1))
# Out:
# There are 438 total elements to analyze.

# %% [markdown]
# Let's go deeper. We decoded the JSON to a list, but what kind of list is it? What happened to JSON objects?

# %%
for i in range(data_len):
    print(type(data[i]))

# %% [markdown]
# Of course, *data* is not a simple list, it's a nested list of dictionaries! Let's print the *dict_keys*:

# %%
for i in range(data_len):
    print(data[i].keys())

# %% [markdown]
# This is interesting: in the provided dataset there are some entities that don't have a *text* field. So let's first take only the elements that have a text field and put them in a new non-nested list:

# %%
tex = []
for i in range(data_len):
    if 'text' in data[i]:
        tex.append(data[i]['text'])

# %% [markdown]
# This is better. We now have an actual working list. Again, how many entities do we have?

# %%
tex_len = len(tex)
print('There are actually {} text elements to analyze!'.format(tex_len+1))
# Out:
# There are actually 430 text elements to analyze!

# %% [markdown]
# This is good enough for now, later we can make a deeper analysis, associating each *text* key with its *id* key and its *time* key to correlate which user visualizes which entity and when.
#
# It's good practice to have a new txt file for every step in NLP processing. So let's create a new txt file populated with the *text keys* of the *tex list*, __one per line__.
#
# Since some of the text values are made of more than one paragraphs, we need to substitute linebreaks (newline character) with a space character. Some caution is needed because some paragraphs have a double linebreak.

# %%
#Swap linebreaks with a space
for i in range(tex_len):
    tex[i] = tex[i].replace('\n\n','\n')
    tex[i] = tex[i].replace('\n',' ')

#Create new txt with text keys (one per line)
with codecs.open('data/text.txt','w',encoding='utf-8') as text:
    for i in range(tex_len):
        text.write('%s\n' % tex[i])

# %% [markdown]
# To view the file and check that everything was executed as it should you don't need another editor:

# %%
#Print the first 3000 characters
with codecs.open('data/text.txt',encoding='utf-8') as text:    
    print(text.read(3000))
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. , contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo. El gobierno nos acompañ ...
# Detuvieron a un profesor universitario acusado de tirarle huevos a Macri El profesor universitario Aníbal Prina, acusado de haber tirado huevos contra la comitiva presidencial, en el marco de la visita que hizo el jueves el jefe de Estado Mauricio Macri a Santa Rosa, fue detenido este viernes por la Policía Federal. Prina fue el tercer candidato a diputado nacional por el kirchnerista Frente Peronista Barrial y quedó arrestado en la Facultad de Agronomía. El docente está acusado de cometer el delito de intimidación publica estipulado por el artículo 211 del Código Penal. En principio, Prina estuvo demorado durante dos horas en la Facultad de Agronomía, ubicada en la ruta 5, a 10 kilómetros de

# %% [markdown]
# Data preprocessing is over, we now have a txt ready to feed our NLP modules!
# ## Language processing with SpaCy

# %% [markdown]
# Text mining tasks have become incredibly easy thanks to [spaCy](http://alpha.spacy.io/), a NLP Python module which provides:
# * Non-destructive tokenization
# * Syntax-driven sentence segmentation
# * Pre-trained word vectors
# * Part-of-speech tagging
# * Named entity recognition
# * Labelled dependency parsing
# * A built-in visualizer
#
# ...and much more, all with just one function!
#
# SpaCy also provides some already trained [models](https://alpha.spacy.io/models/) which you can use out-of-the-box to process different languages. SpaCy's core is written in pure C (via Cython), it's currently the [fastest](https://alpha.spacy.io/usage/facts-figures) parser available and makes [multithreading](https://explosion.ai/blog/multithreading-with-cython) profitable by virtue of Cython.
#
# Follow the *README* of this repo and install the Spanish language model. Now import the model, open text.txt file and store content in a single string:

# %%
# %%time 
import spacy

#Initialize SpaCy's pipeline
nlp = spacy.load('es_core_web_sm')

#Open text file and store content in a single str
with codecs.open('data/text.txt',encoding='utf-8') as text:
    full_txt = text.read()
# Out:
# CPU times: user 802 ms, sys: 400 ms, total: 1.2 s
# Wall time: 2.51 s

# %% [markdown]
# Now that we have a processing pipeline, we can call a *nlp* instance as if it were a function on a string of text. This will produce a [Doc](https://alpha.spacy.io/api/doc) object, a special container that holds all linguistic annotations of the text fed in.
#
# Let's first explore how SpaCy processes a single entity, before diving into the dataset:

# %%
# %%time
#Snip single line of text
with codecs.open('data/text.txt',encoding='utf-8') as text:
    line_txt = text.readline()

#Standard way of processing text 
doc = nlp(line_txt)
# Out:
# CPU times: user 446 ms, sys: 744 ms, total: 1.19 s
# Wall time: 601 ms

# %%
print(doc)
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. , contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo. El gobierno nos acompañ ...

# %% [markdown]
# Looks exactly the same! But what happened under the hood? Have a look at how [spaCy's pipeline](https://alpha.spacy.io/usage/processing-pipelines) is made:
#
# Text -> tokenizer -> tagger -> parser -> ner -> Doc
#
# Text analysis is built in from bottom-up. The *tokenizer* creates a Doc data structure, breaking the text in tokens and storing their metadata in a tensor. The *tagger* takes these tokens (and their context) and uses the information to make predictions of the part-of-speech tags. The *parser* assigns dependency labels between tokens and segments text in sentences. The *ner*, named entity recognizer, detects and labels named entities.
# ### Sentence detection and segmentation

# %%
for num, sent in enumerate(doc.sents):
    print ('Sentence {}:'.format(num + 1),sent,end='\n')
# Out:
# Sentence 1: Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle.
# Sentence 2: Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento.
# Sentence 3: El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia.
# Sentence 4: Allí, le prometió ayuda.
# Sentence 5: Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana.
# Sentence 6: Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio.
# Sentence 7: Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo.
# Sentence 8: No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales.
# Sentence 9: Macri me dijo que lo hagamos.
# Sentence 10: Los tiempos de Nación no son los mismos que los de la gente".
# Sentence 11: "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-.
# Sentence 12: Puse plata de mi bolsillo, pero no puedo más.
# Sentence 13: No pedí nada para mí, era para la gente.
# Sentence 14: Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".
# Sentence 15: Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera.
# Sentence 16: , contó.
# Sentence 17: Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.
# Sentence 18: No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'.
# Sentence 19: ¿Cómo me van a contar eso? .
# Sentence 20: No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo.
# Sentence 21: Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos".
# Sentence 22: El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”.
# Sentence 23: Luego, le regaló una camiseta de Talleres con el nombre del presidente.
# Sentence 24: Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle".
# Sentence 25: "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 26: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado.
# Sentence 27: “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba.
# Sentence 28: Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 29: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia.
# Sentence 30: Cuando hablamos con el gobierno se comprometieron a ayudarnos.
# Sentence 31: El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente.
# Sentence 32: Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga.
# Sentence 33: Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen.
# Sentence 34: Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue.
# Sentence 35: Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación.
# Sentence 36: Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga.
# Sentence 37: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo.
# Sentence 38: El gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema.
# Sentence 39: Tanto nosotros cómo el Estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer.
# Sentence 40: Entendemos, además, que el Estado debe cuidar el dinero de los argentinos.
# Sentence 41: Nosotros vimos una situación de vulnerabilidad y quisimos ayudar.
# Sentence 42: Desde el Estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie.
# Sentence 43: Por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida, que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan.
# Sentence 44: Esta gente en situación de calle, ES GENTE BUENA Y TODOS TENEMOS QUE AYUDARLOS.
# Sentence 45: ESTAN SOLOS Y DESPROTEGIDOS.
# Sentence 46: Ratificamos nuestras ganas, buscaremos la manera y cuando estén dadas todas las condiciones necesarias, en conjunto con el gobierno nacional, retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle, darles formación y trabajo para que puedan vivir dignamente.

# %% [markdown]
# ### Part-of-speech (POS) tagging and grammar analysis
# Using [Pandas](http://pandas.pydata.org/), Python Data Analysis library, we can have a clean table visualization.
# - Text: The original word text.
# - POS: The simple part-of-speech tag.
# - Tag: The detailed part-of-speech tag, with full morphology!
# - Dep: Syntactic dependency, i.e. the relation between tokens.

# %%
import pandas as pd

token_text = [token.orth_ for token in doc]
token_pos = [token.pos_ for token in doc]
token_tag = [token.tag_ for token in doc]
token_dep = [token.dep_ for token in doc]

pd.DataFrame(list(zip(token_text,token_pos,token_tag,token_dep)), columns=['Text', 'POS','Tag','Dep'])
# Out:
#             Text    POS                                                Tag  \
# 0          Cerró   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past...
# 1             el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 2        comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 3       cordobés    ADJ                                   ADJ__Number=Sing
# 4             al    ADP      ADP__AdpType=Preppron|Gender=Masc|Number=Sing
# 5            que   PRON                                 PRON__PronType=Rel
# 6          Macri  PROPN                                           PROPN___
# 7             le   PRON   PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs
# 8          había    AUX  AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|V...
# 9      prometido   VERB  VERB__Gender=Masc|Number=Sing|Tense=Past|VerbF...
# 10         ayuda   NOUN                       NOUN__Gender=Fem|Number=Sing
# 11          Luis  PROPN                                           PROPN___
# 12      Almadaes  PROPN                                           PROPN___
# 13      cordobés    ADJ                                   ADJ__Number=Plur
# 14        ytenía   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|...
# 15            un    DET  DET__Definite=Ind|Gender=Masc|Number=Sing|Pron...
# 16       comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 17   comunitario    ADJ                       ADJ__Gender=Masc|Number=Sing
# 18             y   CONJ                                           CCONJ___
# 19           una    DET  DET__Definite=Ind|Gender=Fem|Number=Sing|PronT...
# 20     fundación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 21          para    ADP                                  ADP__AdpType=Prep
# 22        ayudar   VERB                                 VERB__VerbForm=Inf
# 23             a    ADP                                  ADP__AdpType=Prep
# 24         gente   NOUN                       NOUN__Gender=Fem|Number=Sing
# 25            en    ADP                                  ADP__AdpType=Prep
# 26     situación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 27            de    ADP                                  ADP__AdpType=Prep
# 28         calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 29             .  PUNCT                              PUNCT__PunctType=Peri
# ..           ...    ...                                                ...
# 952     gobierno   NOUN                      NOUN__Gender=Masc|Number=Sing
# 953     nacional    ADJ                                   ADJ__Number=Sing
# 954            ,  PUNCT                              PUNCT__PunctType=Comm
# 955  retomaremos   VERB  VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres...
# 956           el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 957      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 958       juntos    ADJ                       ADJ__Gender=Masc|Number=Plur
# 959         para    ADP                                  ADP__AdpType=Prep
# 960        sacar   VERB                                 VERB__VerbForm=Inf
# 961            a    ADP                                  ADP__AdpType=Prep
# 962        todas    DET           DET__Gender=Fem|Number=Plur|PronType=Ind
# 963          las    DET  DET__Definite=Def|Gender=Fem|Number=Plur|PronT...
# 964     personas   NOUN                       NOUN__Gender=Fem|Number=Plur
# 965          que   PRON                                 PRON__PronType=Rel
# 966      podamos    AUX  AUX__Mood=Sub|Number=Plur|Person=1|Tense=Pres|...
# 967           de    ADP                                  ADP__AdpType=Prep
# 968           la    DET  DET__Definite=Def|Gender=Fem|Number=Sing|PronT...
# 969        calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 970            ,  PUNCT                              PUNCT__PunctType=Comm
# 971       darles    ADJ                                   ADJ__Number=Plur
# 972    formación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 973            y   CONJ                                           CCONJ___
# 974      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 975         para    ADP                                  ADP__AdpType=Prep
# 976          que  SCONJ                                           SCONJ___
# 977       puedan    AUX  AUX__Mood=Sub|Number=Plur|Person=3|Tense=Pres|...
# 978        vivir   VERB                                 VERB__VerbForm=Inf
# 979   dignamente    ADV                                             ADV___
# 980            .  PUNCT                              PUNCT__PunctType=Peri
# 981           \n  SPACE
#
#         Dep
# 0      ROOT
# 1       det
# 2     nsubj
# 3      amod
# 4      case
# 5       obj
# 6     nsubj
# 7       obj
# 8       aux
# 9       acl
# 10      obj
# 11    nsubj
# 12     flat
# 13    nsubj
# 14    advcl
# 15      det
# 16      obj
# 17     amod
# 18       cc
# 19      det
# 20     conj
# 21     mark
# 22      acl
# 23     case
# 24      obj
# 25     case
# 26      obl
# 27     case
# 28     nmod
# 29    punct
# ..      ...
# 952    nmod
# 953    amod
# 954   punct
# 955   advcl
# 956     det
# 957     obj
# 958    amod
# 959    mark
# 960   advcl
# 961    case
# 962     det
# 963     det
# 964     obj
# 965     obj
# 966     acl
# 967    case
# 968     det
# 969     obj
# 970   punct
# 971    amod
# 972   appos
# 973      cc
# 974    conj
# 975    mark
# 976    mark
# 977     aux
# 978   advcl
# 979  advmod
# 980   punct
# 981
#
# [982 rows x 4 columns]

# %% [markdown]
# ### Navigating the parse tree
# SpaCy uses the terms head and child to describe the words connected by a single arc in the dependency tree. The term dep is used for the arc label, which describes the type of syntactic relation that connects the child to the head. As with other attributes, the value of .dep is a hash value. You can get the string value with .dep\_.
# - Text: The original token text.
# - Dep: The syntactic relation connecting child to head.
# - Head text: The original text of the token head.
# - Head POS: The part-of-speech tag of the token head.
# - Children: The immediate syntactic dependents of the token.

# %%
token_text = [token.text for token in doc]
token_head_pos = [token.head.pos_ for token in doc]
token_head_text = [token.head.text for token in doc]
token_dep = [token.dep_ for token in doc]
token_children = [[child for child in token.children] for token in doc]
pd.DataFrame(list(zip(token_text,token_dep,token_head_text,token_head_pos,token_children)), columns=['Text','Dep','Head text','Head POS','Children'])
# Out:
#             Text     Dep    Head text Head POS  \
# 0          Cerró    ROOT        Cerró     VERB
# 1             el     det      comedor     NOUN
# 2        comedor   nsubj        Cerró     VERB
# 3       cordobés    amod      comedor     NOUN
# 4             al    case          que     PRON
# 5            que     obj    prometido     VERB
# 6          Macri   nsubj    prometido     VERB
# 7             le     obj    prometido     VERB
# 8          había     aux    prometido     VERB
# 9      prometido     acl     cordobés      ADJ
# 10         ayuda     obj    prometido     VERB
# 11          Luis   nsubj    prometido     VERB
# 12      Almadaes    flat         Luis    PROPN
# 13      cordobés   nsubj       ytenía     VERB
# 14        ytenía   advcl        Cerró     VERB
# 15            un     det      comedor     NOUN
# 16       comedor     obj       ytenía     VERB
# 17   comunitario    amod      comedor     NOUN
# 18             y      cc    fundación     NOUN
# 19           una     det    fundación     NOUN
# 20     fundación    conj      comedor     NOUN
# 21          para    mark       ayudar     VERB
# 22        ayudar     acl    fundación     NOUN
# 23             a    case        gente     NOUN
# 24         gente     obj       ayudar     VERB
# 25            en    case    situación     NOUN
# 26     situación     obl       ayudar     VERB
# 27            de    case        calle     NOUN
# 28         calle    nmod    situación     NOUN
# 29             .   punct        Cerró     VERB
# ..           ...     ...          ...      ...
# 952     gobierno    nmod     conjunto     NOUN
# 953     nacional    amod     gobierno     NOUN
# 954            ,   punct     conjunto     NOUN
# 955  retomaremos   advcl  Ratificamos     VERB
# 956           el     det      trabajo     NOUN
# 957      trabajo     obj  retomaremos     VERB
# 958       juntos    amod      trabajo     NOUN
# 959         para    mark        sacar     VERB
# 960        sacar   advcl  retomaremos     VERB
# 961            a    case     personas     NOUN
# 962        todas     det          las      DET
# 963          las     det     personas     NOUN
# 964     personas     obj        sacar     VERB
# 965          que     obj      podamos      AUX
# 966      podamos     acl     personas     NOUN
# 967           de    case        calle     NOUN
# 968           la     det        calle     NOUN
# 969        calle     obj      podamos      AUX
# 970            ,   punct      podamos      AUX
# 971       darles    amod    formación     NOUN
# 972    formación   appos     personas     NOUN
# 973            y      cc      trabajo     NOUN
# 974      trabajo    conj    formación     NOUN
# 975         para    mark        vivir     VERB
# 976          que    mark        vivir     VERB
# 977       puedan     aux        vivir     VERB
# 978        vivir   advcl        sacar     VERB
# 979   dignamente  advmod        vivir     VERB
# 980            .   punct  Ratificamos     VERB
# 981           \n                    .    PUNCT
#
#                                  Children
# 0                    [comedor, ytenía, .]
# 1                                      []
# 2                          [el, cordobés]
# 3                             [prometido]
# 4                                      []
# 5                                    [al]
# 6                                      []
# 7                                      []
# 8                                      []
# 9    [que, Macri, le, había, ayuda, Luis]
# 10                                     []
# 11                             [Almadaes]
# 12                                     []
# 13                                     []
# 14                    [cordobés, comedor]
# 15                                     []
# 16           [un, comunitario, fundación]
# 17                                     []
# 18                                     []
# 19                                     []
# 20                       [y, una, ayudar]
# 21                                     []
# 22               [para, gente, situación]
# 23                                     []
# 24                                    [a]
# 25                                     []
# 26                            [en, calle]
# 27                                     []
# 28                                   [de]
# 29                                     []
# ..                                    ...
# 952                   [con, el, nacional]
# 953                                    []
# 954                                    []
# 955            [conjunto, trabajo, sacar]
# 956                                    []
# 957                          [el, juntos]
# 958                                    []
# 959                                    []
# 960               [para, personas, vivir]
# 961                                    []
# 962                                    []
# 963                               [todas]
# 964          [a, las, podamos, formación]
# 965                                    []
# 966                       [que, calle, ,]
# 967                                    []
# 968                                    []
# 969                              [de, la]
# 970                                    []
# 971                                    []
# 972                     [darles, trabajo]
# 973                                    []
# 974                                   [y]
# 975                                    []
# 976                                    []
# 977                                    []
# 978       [para, que, puedan, dignamente]
# 979                                    []
# 980                                  [\n]
# 981                                    []
#
# [982 rows x 5 columns]

# %% [markdown]
# ### Named entity recognition (NER)

# %%
for num, ent in enumerate(doc.ents):
    print ('Entity {}:'.format(num + 1),ent,'-', ent.label_,end='\n')
# Out:
# Entity 1: Macri - PER
# Entity 2: Luis Almadaes - PER
# Entity 3: Desesperado - LOC
# Entity 4: Mauricio Macripara - PER
# Entity 5: Allí - PER
# Entity 6: Yo Te Ayudo Amigo del Alma - MISC
# Entity 7: Almada - LOC
# Entity 8: La Naciónque - LOC
# Entity 9: Puse - PER
# Entity 10: No llamé al Presidente - MISC
# Entity 11: Macri me dijo - MISC
# Entity 12: Los tiempos de Nación - MISC
# Entity 13: Puse - PER
# Entity 14: No pedí nada para mí - MISC
# Entity 15: Vino el Presidente - PER
# Entity 16: Almada - LOC
# Entity 17: Provincia - LOC
# Entity 18: Municipalidad - LOC
# Entity 19: Hace - ORG
# Entity 20: Carolina Stanley - PER
# Entity 21: Presidente - PER
# Entity 22: Ahora - MISC
# Entity 23: Almada - LOC
# Entity 24: Cómo - MISC
# Entity 25: No tengo más plata - MISC
# Entity 26: Laburo - MISC
# Entity 27: El día de la visita presidencial - MISC
# Entity 28: Talleres - ORG
# Entity 29: Sin embargo - MISC
# Entity 30: Almada - LOC
# Entity 31: Estado Nacional - LOC
# Entity 32: Ayer - LOC
# Entity 33: Ello nos obliga a seguirlos - MISC
# Entity 34: Yo te ayudo Amigo del Alma - MISC
# Entity 35: Estado Nacional - LOC
# Entity 36: Córdoba - LOC
# Entity 37: Ayer - LOC
# Entity 38: Ello nos obliga a seguirlos - MISC
# Entity 39: Cuando hablamos con el gobierno - MISC
# Entity 40: El Ministerio de Desarrollo Social de la Nación - MISC
# Entity 41: Mientras no los tuvimos nosotros salimos por nuestra - MISC
# Entity 42: Le dimos Comida - MISC
# Entity 43: Le dimos Trabajo - MISC
# Entity 44: Le dimos Albergue - MISC
# Entity 45: Este flagelo esta contaminando gravemente nuestra población - MISC
# Entity 46: Entendimos que no alcanza con alimentarlos - MISC
# Entity 47: Ayer - LOC
# Entity 48: Le - LOC
# Entity 49: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido - MISC
# Entity 50: El gobierno nos acompaña - MISC
# Entity 51: Tanto nosotros - MISC
# Entity 52: Estado entendemos - LOC
# Entity 53: Entendemos - MISC
# Entity 54: Estado - LOC
# Entity 55: Nosotros - MISC
# Entity 56: Desde el Estado - MISC
# Entity 57: Por eso es necesario - MISC
# Entity 58: ES GENTE BUENA Y TODOS TENEMOS - MISC
# Entity 59: AYUDARLOS - LOC
# Entity 60: ESTAN SOLOS - MISC
# Entity 61: DESPROTEGIDOS - MISC
# Entity 62: Ratificamos - LOC
# Entity 63:
#  - MISC

# %% [markdown]
# ### Visualization with displaCy
# SpaCy has an integrated visualization library that can display the content in two styles: *dep* and *ent*.
# The *dep* style shows the dependency between words using arcs, the *ent* style prints out the text with colored NER labels wrapped around words.
#
# The method *.serve()* launches a local web server for visualization while the method *.render()* provides an image.
#
# __Note__: Style *dep* is not working well in Spanish because *tag* is used instead of *POS* for annotating words, but the *tag* field is much larger than *POS* thus causing overlapping.
#
# __Note2__: Style *ent* can't be viewed in Github, but in Jupyter is great.

# %%
from spacy import displacy
#displacy.serve(doc, style='dep')
options = {'distance':425, 'arrow_spacing':6}
displacy.render(doc,style='dep', jupyter=True, options=options)

# %%
#displacy.serve(doc, style='dep')
displacy.render(doc,style='ent', jupyter=True)

# %% [markdown]
# ### Text normalization: stemming, lemmatization and shape analysis
# Let's now move on to single token analysis. *Normalization* is a way of processing text that involves changing the words to make them less unique. We talk about *stemming* when we take the words and we remove the end, producing a new word that is not in the language dictionary. *Lemmatization* takes inflected words as input and tries to give the root word as output, so in some way is similar to stemming, but it produces meaningful (actually existing) words. The token *shape* is the decapitalization char mask that gets applied to the original (orthodox) token.

# %%
token_lemma = [token.lemma_ for token in doc]
token_shape = [token.shape_ for token in doc]

pd.DataFrame(list(zip(token_text, token_lemma, token_shape)),columns=['token_text', 'token_lemma', 'token_shape'])
# Out:
#       token_text  token_lemma token_shape
# 0          Cerró        cerró       Xxxxx
# 1             el           el          xx
# 2        comedor      comedor        xxxx
# 3       cordobés     cordobés        xxxx
# 4             al           al          xx
# 5            que          que         xxx
# 6          Macri        macri       Xxxxx
# 7             le           le          xx
# 8          había        había        xxxx
# 9      prometido    prometido        xxxx
# 10         ayuda        ayuda        xxxx
# 11          Luis         luis        Xxxx
# 12      Almadaes     almadaes       Xxxxx
# 13      cordobés     cordobés        xxxx
# 14        ytenía       ytenía        xxxx
# 15            un           un          xx
# 16       comedor      comedor        xxxx
# 17   comunitario  comunitario        xxxx
# 18             y            y           x
# 19           una          una         xxx
# 20     fundación    fundación        xxxx
# 21          para         para        xxxx
# 22        ayudar       ayudar        xxxx
# 23             a            a           x
# 24         gente        gente        xxxx
# 25            en           en          xx
# 26     situación    situación        xxxx
# 27            de           de          xx
# 28         calle        calle        xxxx
# 29             .            .           .
# ..           ...          ...         ...
# 952     gobierno     gobierno        xxxx
# 953     nacional     nacional        xxxx
# 954            ,            ,           ,
# 955  retomaremos  retomaremos        xxxx
# 956           el           el          xx
# 957      trabajo      trabajo        xxxx
# 958       juntos       juntos        xxxx
# 959         para         para        xxxx
# 960        sacar        sacar        xxxx
# 961            a            a           x
# 962        todas        todas        xxxx
# 963          las          las         xxx
# 964     personas     personas        xxxx
# 965          que          que         xxx
# 966      podamos      podamos        xxxx
# 967           de           de          xx
# 968           la           la          xx
# 969        calle        calle        xxxx
# 970            ,            ,           ,
# 971       darles       darles        xxxx
# 972    formación    formación        xxxx
# 973            y            y           x
# 974      trabajo      trabajo        xxxx
# 975         para         para        xxxx
# 976          que          que         xxx
# 977       puedan       puedan        xxxx
# 978        vivir        vivir        xxxx
# 979   dignamente   dignamente        xxxx
# 980            .            .           .
# 981           \n           \n          \n
#
# [982 rows x 3 columns]

# %% [markdown]
# Lemmatization is actually not supported for the Spanish language model. We still have some normalization, as seen from the shape mask applied to every word.
#
# ### Token-level entity analysis
# The standard way to access entity annotations is the *doc.ents* property, but you can also access token entity annotations using the *token.ent_iob* and *token.ent_type* attributes; *token.ent_iob* indicates whether an entity starts, continues or ends on the tag.
#
# IOB Scheme:
# - *I* - Token is *inside* an entity.
# - *O* - Token is *outside* an entity.
# - *B* - Token is the *beginning* of an entity.

# %%
token_entity_type = [token.ent_type_ for token in doc]
token_entity_iob = [token.ent_iob_ for token in doc]

pd.DataFrame(list(zip(token_text, token_entity_type, token_entity_iob)), columns=['token_text', 'entity_type', 'inside_outside_begin'])
# Out:
#       token_text entity_type inside_outside_begin
# 0          Cerró                                O
# 1             el                                O
# 2        comedor                                O
# 3       cordobés                                O
# 4             al                                O
# 5            que                                O
# 6          Macri         PER                    B
# 7             le                                O
# 8          había                                O
# 9      prometido                                O
# 10         ayuda                                O
# 11          Luis         PER                    B
# 12      Almadaes         PER                    I
# 13      cordobés                                O
# 14        ytenía                                O
# 15            un                                O
# 16       comedor                                O
# 17   comunitario                                O
# 18             y                                O
# 19           una                                O
# 20     fundación                                O
# 21          para                                O
# 22        ayudar                                O
# 23             a                                O
# 24         gente                                O
# 25            en                                O
# 26     situación                                O
# 27            de                                O
# 28         calle                                O
# 29             .                                O
# ..           ...         ...                  ...
# 952     gobierno                                O
# 953     nacional                                O
# 954            ,                                O
# 955  retomaremos                                O
# 956           el                                O
# 957      trabajo                                O
# 958       juntos                                O
# 959         para                                O
# 960        sacar                                O
# 961            a                                O
# 962        todas                                O
# 963          las                                O
# 964     personas                                O
# 965          que                                O
# 966      podamos                                O
# 967           de                                O
# 968           la                                O
# 969        calle                                O
# 970            ,                                O
# 971       darles                                O
# 972    formación                                O
# 973            y                                O
# 974      trabajo                                O
# 975         para                                O
# 976          que                                O
# 977       puedan                                O
# 978        vivir                                O
# 979   dignamente                                O
# 980            .                                O
# 981           \n        MISC                    B
#
# [982 rows x 3 columns]

# %% [markdown]
# ### Token-level attributes
# Other useful metadata is provided, such as the relative frequency of tokens, and whether or not a token matches any of these categories:
# - stopword
# - punctuation
# - whitespace
# - number
# - url
#
# and many more token [attributes](https://alpha.spacy.io/api/token#attributes)!

# %%
token_attributes = [(token.orth_,token.prob,token.is_stop,token.is_punct,token.is_space,token.like_num,token.like_url) for token in doc]

df = pd.DataFrame(token_attributes,columns=['text','log_probability','stop?','punctuation?','whitespace?','number?','url?'])

df.loc[:, 'stop?':'url?'] = (df.loc[:, 'stop?':'url?'].applymap(lambda x: u'Yes' if x else u''))
                                               
df
# Out:
#             text  log_probability stop? punctuation? whitespace? number? url?
# 0          Cerró            -20.0
# 1             el            -20.0   Yes
# 2        comedor            -20.0
# 3       cordobés            -20.0
# 4             al            -20.0   Yes
# 5            que            -20.0   Yes
# 6          Macri            -20.0
# 7             le            -20.0   Yes
# 8          había            -20.0   Yes
# 9      prometido            -20.0
# 10         ayuda            -20.0
# 11          Luis            -20.0
# 12      Almadaes            -20.0
# 13      cordobés            -20.0
# 14        ytenía            -20.0
# 15            un            -20.0   Yes
# 16       comedor            -20.0
# 17   comunitario            -20.0
# 18             y            -20.0
# 19           una            -20.0   Yes
# 20     fundación            -20.0
# 21          para            -20.0   Yes
# 22        ayudar            -20.0
# 23             a            -20.0
# 24         gente            -20.0
# 25            en            -20.0   Yes
# 26     situación            -20.0
# 27            de            -20.0   Yes
# 28         calle            -20.0
# 29             .            -20.0                Yes
# ..           ...              ...   ...          ...         ...     ...  ...
# 952     gobierno            -20.0
# 953     nacional            -20.0
# 954            ,            -20.0                Yes
# 955  retomaremos            -20.0
# 956           el            -20.0   Yes
# 957      trabajo            -20.0   Yes
# 958       juntos            -20.0
# 959         para            -20.0   Yes
# 960        sacar            -20.0
# 961            a            -20.0
# 962        todas            -20.0   Yes
# 963          las            -20.0   Yes
# 964     personas            -20.0
# 965          que            -20.0   Yes
# 966      podamos            -20.0
# 967           de            -20.0   Yes
# 968           la            -20.0   Yes
# 969        calle            -20.0
# 970            ,            -20.0                Yes
# 971       darles            -20.0
# 972    formación            -20.0
# 973            y            -20.0
# 974      trabajo            -20.0   Yes
# 975         para            -20.0   Yes
# 976          que            -20.0   Yes
# 977       puedan            -20.0
# 978        vivir            -20.0
# 979   dignamente            -20.0
# 980            .            -20.0                Yes
# 981           \n            -20.0                            Yes
#
# [982 rows x 7 columns]

# %% [markdown]
# The relative frequency is not stored in the model, but that's not important since we don't intend to rely on it anyways.
# ### Text normalization, lemmatization and sentence segmentation
# Now that we have explored all that spaCy can do for us, we can use it to parse our *text.txt* and generate a new *parsed_text.txt* that has the same text, normalized, lemmatized and segmented in sentences. I decided not to remove stop words because they can be part of composite words, as explained in the phrase modeling section of this notebook.
#
# We first define a helper function that constructs a generator to loop over the *text.txt* and yield the review one-by-one. A generator is similar to an iterator but it can be used only once because its content is generated on the fly and not stored in memory, saving precious computation.
#
# Then pass on the reviews to spaCy using the *.pipe()* method via a generator function to parse the reviews, lemmatize the text, and yield segmantized sentences. The standard way to initialize spaCy would be to call *nlp(text.txt)* on each review, but I will make use instead of the *.pipe()* method which allows efficient [multi-threading](https://spacy.io/docs/usage/processing-text#multithreading). Two [arguments](https://alpha.spacy.io/api/language#pipe) are given to *.pipe()*: *batch_size* is the number of reviews to buffer and *n_threads* which is the number of worker threads to use (default is 2, if -1 OpenMP will decide how many to use at run time, like in our case). You can also pass a *disable* option to turn off some components of the pipeline that is not needed to further optimize the processing. Note that all processing algorithms are linear-time in the length of the string.
#
# Finally, we write the sentences to a new txt file, *parsed_text.txt*.

# %%
# %%time
#Helper function that yields all reviews via generator 
def get_review(filename):
    with codecs.open(filename, encoding='utf_8') as textfile:
        for review in textfile:
            yield review
            
#Generator function to parse reviews, lemmatize the text, and yield sentences
#WARNING: This task is computationally demanding, adjust batch_size and n_threads according to your machine
def lemmatize_corpus(filename):
    for parsed_review in nlp.pipe(get_review(filename),batch_size=10, n_threads=-1):
        for sent in parsed_review.sents:
            yield u' '.join([token.lemma_ for token in sent if not (token.is_punct or token.is_space)])

with codecs.open('data/parsed_text.txt', 'w', encoding='utf_8') as f:
    for sent in lemmatize_corpus('data/text.txt'):
        f.write(sent + '\n')
# Out:
# CPU times: user 38.4 s, sys: 44.2 s, total: 1min 22s
# Wall time: 25.3 s

# %% [markdown]
# Let's see an excerpt of what we got out of it:

# %%
with codecs.open('data/parsed_text.txt',encoding='utf-8') as parsed_text:    
    print(parsed_text.read(3000))
# Out:
# cerró el comedor cordobés al que macri le había prometido ayuda luis almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle
# desesperado en mayo le envió un mensaje por redes sociales al presidente mauricio macripara que lo ayude a sostener el emprendimiento
# el mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia
# allí le prometió ayuda
# pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana
# su fundación yo te ayudo amigo del alma ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio
# almada dijo a la naciónque debió cerrar la fundación puse mi esfuerzo cumplí con lo que me comprometí pero solo no puedo
# no llamé al presidente para pedirle alfajores sino para que nos ayudara con tratamiento de adicciones con asistentes sociales
# macri me dijo que lo hagamos
# los tiempos de nación no son los mismos que los de la gente
# me fueron pateando primero dos meses después tres y la semana pasada me dijeron cuatro meses -continuó-
# puse plata de mi bolsillo pero no puedo más
# no pedí nada para mí era para la gente
# vino el presidente estamos haciendo un laburo donde tendrían que estar ellos
# almada dijo que son requisitos y más requisitos y nos piden un salón que sale $ 20.000 aparte del que estamos pagando la provincia nos dio alojamiento para los muchachos y la municipalidad nos dio el permiso para la venta callejera
# contó
# hace unos días habló telefónicamente con la ministra carolina stanley y según señaló envió a una asesora
# no me reuní con un concejal sino con el presidente y para mí su palabra vale ahora me dicen almada no le dijimos que empezara
# cómo me van a contar eso
# no tengo más plata lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo
# laburo diez horas por día para la sociedad pero no puedo más ahora la pelota está en la cancha de ellos
# el día de la visita presidencial el cordobés contó con el presidente carancheamos unos pollos de la fuente
# luego le regaló una camiseta de talleres con el nombre del presidente
# sin embargo luego de anunciar el cese de actividades de la fundación almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando con el estado nacional para ayudar a las personas en situación de calle
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia explica el comunicado
# yo te ayudo amigo del alma ratifica que va a seguir trabajando con el estado nacional para ayudar a personas en situación de calle en córdoba
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia
# cuando hablamos con el gobierno se comprometieron a ayudarnos
# el ministerio de desarrollo social de la nación nos habían pedido algunos requisitos para que todo sea de manera transparente
# mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos le dimos comida le dimos trabajo y le dimos albergue pero se nos hizo imposible luchar contra el flagelo de la droga
# este flagelo esta contaminando gravemente nuestra población principalmente a los que menos tienen
# entendimos que no alcanza con alimentarlos darles trabajo y la posibilidad de dormir en un albergue
# ayer tuvimos que parar la pelota no podemos resolver este problema desde la fundación
# le generamos un empleo dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga
# acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo
# el gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema
# tanto nosotros cómo el estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer
# entendemos además que el estado debe cuidar el dinero de los argentinos
# nosotros vimos una situación de vulnerabilidad y quisimos ayudar
# desde el estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie
# por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan
# esta gente en situación de calle es gente buena y todos tenemos que ayudarlos
# estan solos y desprotegidos
# ratificamos nuestras ganas buscaremos la manera y cuando estén dadas todas las condiciones necesarias en conjunto con el gobierno nacional retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle darles formación y trabajo para que puedan vivir dignamente
# detuvieron a un profesor universitario acusado de tirarle huevos a macri el profesor universitario aníbal prina acusado de haber tirado huevos contra la comitiva presidencial en el marco de la visita que hizo el jueves el jefe de estado mauricio macri a santa rosa fue detenido este viernes por la policía federal
# prina fue el tercer candidato a diputado nacional por el kirchnerista frente peronista barrial y quedó arrestado en la facultad de agronomía
# el docente está acusado de cometer el delito de intimidación publica estipulado por el artículo 211 del código penal
# en principio prina estuvo demorado durante dos horas en la facultad de agronomía ubicada en la ruta 5 a 10 kilómetros de la capital provincial porque el juez federal facundo cubas dio la orden de manera telefónica pero no estaba redactado el escrito forma

# %% [markdown]
# ## Phrase Modeling with Gensim

# %% [markdown]
# Phrase modeling is a form of text manipulation that consists in producing new one token words from two or more tokens. As we saw in named entity recognition, there are groups of words that represent things that have nothing to do with the single words themselves that make up the group. For example *New York* is supposed to be different in meaning from *New* and *York*. We would like to have these single token words joined together in a single word, with an underscore instead of a space.
#
# We will use [gensim](https://radimrehurek.com/gensim/index.html) to achieve this task. Gensim provided common phrase detection (multiword expressions) from a stream of sentences. The phrases are collocations (frequently co-occurring tokens). In the built-in [*gensim.models.phrases.Phrases*](https://radimrehurek.com/gensim/models/phrases.html) class there are actually two ways ([formulas](https://radimrehurek.com/gensim/models/phrases.html#id2)) for measuring the co-occurrence of these composite words in the corpus, meaning the frequency these words appear together in sequence compared to the frequency they appear alone. We will use the *default* mode, with a *threshold* set to *245*.
#
# Gensim's [LineSentence](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.LineSentence) class provides a convenient iterator for working with other gensim components. It streams the sentences from disk, so that you never have to hold the entire corpus in RAM at once. This allows you to scale your modeling pipeline up to potentially very large corpora.
#
# Finally, we write the sentences to a new txt file, *bigram_sents.txt*, and we snip the head to check the result.

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

#Creates iterable of sentences
unigram_sents = LineSentence(u'data/parsed_text.txt')

#Initialize the model from an iterable of sentences 
bigram_model = Phrases(unigram_sents, threshold=245)

#Write processed sentences to the new file 
with codecs.open('data/bigram_sents.txt', 'w', encoding='utf-8') as f:
     for sent in unigram_sents:
            bigram_sent = u' '.join(bigram_model[sent])
            f.write(bigram_sent + '\n')

#Print the first 3000 characters
with codecs.open('data/bigram_sents.txt',encoding='utf-8') as parsed_text:    
    print(parsed_text.read(3000))
# Out:
# cerró el comedor cordobés al que macri le había prometido ayuda luis almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle
# desesperado en mayo le envió un mensaje por redes_sociales al presidente mauricio macripara que lo ayude a sostener el emprendimiento
# el mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia
# allí le prometió ayuda
# pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana
# su fundación yo te ayudo amigo del alma ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio
# almada dijo a la naciónque debió cerrar la fundación puse mi esfuerzo cumplí con lo que me comprometí pero solo no puedo
# no llamé al presidente para pedirle alfajores sino para que nos ayudara con tratamiento de adicciones con asistentes sociales
# macri me dijo que lo hagamos
# los tiempos de nación no son los mismos que los de la gente
# me fueron pateando primero dos meses después tres y la semana pasada me dijeron cuatro meses -continuó-
# puse plata de mi bolsillo pero no puedo más
# no pedí nada para mí era para la gente
# vino el presidente estamos haciendo un laburo donde tendrían que estar ellos
# almada dijo que son requisitos y más requisitos y nos piden un salón que sale $ 20.000 aparte del que estamos pagando la provincia nos dio alojamiento para los muchachos y la municipalidad nos dio el permiso para la venta callejera
# contó
# hace unos días habló telefónicamente con la ministra carolina stanley y según señaló envió a una asesora
# no me reuní con un concejal sino con el presidente y para mí su palabra vale ahora me dicen almada no le dijimos que empezara
# cómo me van a contar eso
# no tengo más plata lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo
# laburo diez horas por día para la sociedad pero no puedo más ahora la pelota está en la cancha de ellos
# el día de la visita presidencial el cordobés contó con el presidente carancheamos unos pollos de la fuente
# luego le regaló una camiseta de talleres con el nombre del presidente
# sin_embargo luego de anunciar el cese de actividades de la fundación almada emitió un comunicado a través de las redes_sociales en el que afirma que seguirá trabajando con el estado nacional para ayudar a las personas en situación de calle
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia explica el comunicado
# yo te ayudo amigo del alma ratifica que va a seguir trabajando con el estado nacional para ayudar a personas en situación de calle en córdoba
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia
# cuando hablamos con el gobierno se comprometieron a ayudarnos
# el ministerio de desarrollo social de la nación nos habían pedido algunos requisitos para que todo sea de manera transparente
# mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos le dimos comida le dimos trabajo y le dimos albergue pero se nos hizo imposible luchar contra el flagelo de la droga
# este flagelo esta contaminando gravemente nuestra población principalmente a los que menos tienen
# entendimos que no alcanza con alimentarlos darles trabajo y la posibilidad de dormir en un albergue
# ayer tuvimos que parar la pelota no podemos resolver este problema desde la fundación
# le generamos un empleo dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga
# acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo
# el gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema
# tanto nosotros cómo el estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer
# entendemos además que el estado debe cuidar el dinero de los argentinos
# nosotros vimos una situación de vulnerabilidad y quisimos ayudar
# desde el estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie
# por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan
# esta gente en situación de calle es gente buena y todos tenemos que ayudarlos
# estan solos y desprotegidos
# ratificamos nuestras ganas buscaremos la manera y cuando estén dadas todas las condiciones necesarias en conjunto con el gobierno nacional retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle darles formación y trabajo para que puedan vivir dignamente
# detuvieron a un profesor universitario acusado de tirarle huevos a macri el profesor universitario_aníbal prina acusado de haber tirado huevos contra la comitiva_presidencial en el marco de la visita que hizo el jueves el jefe de estado mauricio_macri a santa_rosa fue detenido este viernes por la policía_federal
# prina fue el tercer candidato a diputado_nacional por el kirchnerista frente_peronista barrial y quedó arrestado en la facultad de agronomía
# el docente está acusado de cometer el delito de intimidación publica estipulado por el artículo_211 del código_penal
# en principio prina estuvo demorado durante dos horas en la facultad de agronomía ubicada en la ruta 5 a 10 kilómetros de la capital provincial porque el juez_federal facundo_cubas dio la orden de manera telefónica pero no estaba redactado el escrito forma

# %% [markdown]
# We can see that gensim has picked up some composite phrases that we expected such as mauricio_macri, policía_federal, código_penal etc. and some unexpected ones such as sin_embargo, universitario_aníbal etc. With a correct lemmatization this process is far more accurate because inflections in the words account for a larger number of tokens and the co-occurrence model produces more false positives. Still, adjusting the threshold to *245* has somewhat mitigated the false processing, producing a functional text.
