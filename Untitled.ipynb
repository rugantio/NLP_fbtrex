# %% [markdown]
# # Argentine Election Analysis

# %% [markdown]
# ## Introduction
# In this notebook I analyze a Spanish dataset set up during the [Argentine legislative election](https://en.wikipedia.org/wiki/Argentine_legislative_election,_2017) of 2017.
# This dataset contains the data of 9 facebook bots, crawled over a period of 16 days, following 45 sources.
#
# __Note__: If you haven't done it already, go through the set up in the *README* of [this repo](https://github.com/rugantio/nlp_fbtrex/).
#
# ### Roadmap
# Download dataset -> cast JSON to txt -> tokenization -> normalization -> phrase modeling -> topic mining -> burst the bubble -> word2vec algebra & predictive analysis
#
# ## Dataset
# The dataset was prepared by the [__Facebook Tracking Exposed__](https://facebook.tracking.exposed/) project and can be retrieved in a convenient JSON format from the specific GitHub [__repo__](https://github.com/tracking-exposed/experiments-data/tree/master/silver).
# There are two separate files that we'll try to breakdown:
# * __fbtrex-data-\*.json__ - Contains all impressions relative to single users
# * __semantic-entities.json__ - Contains all available metadata regarding posts
#
# The text field of every posts is enclosed in *semantic-entities.json*, while I can use *fbtrex-data-\*.json* to correlate which user has visualized this content, thus providing an easy way to investigate the Facebook filter bubble.
# Given a ready working environment, as explained is the *README* of this repo, just go ahead and download the files:

# %%
# %%bash
# #Download Argentine dataset in a data subdir
# mkdir data && cd data
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/fbtrex-data-1.json.zip
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/semantic-entities.json.zip

# %% [markdown]
# __Note__: This commands are supposed to be executed in a bash environment, not in the notebook itself. The operation may fail due to permissions.
#
# Extract the content from the zip archive:

# %%
# %%bash
# #Extract JSON from zipped archives
# cd data
# unzip fbtrex-data-1.json.zip
# unzip semantic-entities.json.zip

# %% [markdown]
# __Note__: To try out this notebook I made a shorter version of the JSON, I highly recommend to do the same

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Now that we have the dataset in JSON format, we can use the [JSON Python library](https://docs.python.org/3/library/json.html) to decode its content and store it in a Python variable. The variable type depends on the actual content of the provided file, by [default](https://docs.python.org/3/library/json.html#json-to-py-table) a JSON object is decoded to a dict and an arrays to a list. The recommended approach for working with encoded text files, is to use the [codecs Python library](https://docs.python.org/3/library/codecs.html):

# %%
import codecs
import json

with codecs.open('data/semantic-entities.json',encoding='utf-8') as data_json:    
    data = json.load(data_json)

# %% [markdown]
# To print to stdout the content of the parsed JSON file just use [pprint](https://docs.python.org/3/library/pprint.html), the data pretty printer:

# %%
import pprint
pprint.pprint(data)

# %% [markdown]
# It's useful to check if the casting was performed correctly before proceding, the resulting decoded type can be inspected with:

# %%
print(type(data))
# Out:
# <class 'list'>

# %% [markdown]
# __Note__: If you are using Spyder IDE you can keep track of variable simply looking at the variable explorer window.
#
# So the JSON is now a list. How many entities do we have?

# %%
print('There are {} total elements to analyze.'.format(len(data)))
# Out:
# There are 437 total elements to analyze.

# %% [markdown]
# Let's go deeper. We decoded the JSON to a list, but what kind of list is it? What happened to JSON objects?

# %%
for item in data:
    print(type(item))

# %% [markdown]
# Of course, *data* is not a simple list, it's a nested list of dictionaries! Let's print the *dict_keys*:

# %%
for item in data:
    print(item.keys())

# %% [markdown]
# This is interesting: in the provided dataset there are some entities that don't have a *text* field, due to some errors of the parser. So let's first take only the elements that have a text field and put them in a new non-nested list:

# %%
tex = [item['text'] for item in data if 'text' in item]
print (tex)

# %% [markdown]
# This is better. We now have an actual working list. Again, how many entities do we have?

# %%
print('There are actually {} text elements to analyze!'.format(len(tex)))
# Out:
# There are actually 429 text elements to analyze!

# %% [markdown]
# This is good enough for now, later we can make a deeper analysis, associating each *text* key with its *id* key and its *time* key to correlate which user visualizes which entity and when.
#
# It's good practice to have a new txt file for every step in NLP processing. So let's create a new txt file populated with the *text keys* of the *tex list*, __one per line__.
#
# Since some of the text values are made of more than one paragraphs, we need to substitute linebreaks (newline character) with a space character. Some caution is needed because some paragraphs have a double linebreak.

# %%
#Swap linebreaks with a space
for i in range(len(tex)):
    tex[i] = tex[i].replace('\n\n','\n')
    tex[i] = tex[i].replace('\n',' ')

#Create new txt with text keys (one per line)
with codecs.open('data/text.txt','w',encoding='utf-8') as text:
    for i in range(len(tex)):
        text.write('%s\n' % tex[i])

# %% [markdown]
# To view the file and check that everything was executed as it should you don't need another editor:

# %%
#Print the first 3000 characters
with codecs.open('data/text.txt',encoding='utf-8') as text:    
    print(text.read(3000))
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macri para que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. El proyecto quedó rengo", contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo ...
# Detuvieron a un profesor universitario acusado de tirarle huevos a Macri El profesor universitario Aníbal Prina, acusado de haber tirado huevos contra la comitiva presidencial, en el marco de la visita que hizo el jueves el jefe de Estado Mauricio Macri a Santa Rosa, fue detenido este viernes por la Policía Federal. Prina fue el tercer candidato a diputado nacional por el kirchnerista Frente Peronista Barrial y quedó arrestado en la Facultad de Agronomía. El docente está acusado de cometer el delito de intimidación publica estipulado por el artículo 211 del Código Penal. En principio, Prina estuvo demorado durante dos horas en la Facultad de Agronomía, ubicada en la ru

# %% [markdown]
# Data preprocessing is over, we now have a txt ready to feed our NLP modules!
# ## Language processing with SpaCy

# %% [markdown]
# Text mining tasks have become incredibly easy thanks to [spaCy](http://alpha.spacy.io/), a NLP Python module which provides:
# * Non-destructive tokenization
# * Syntax-driven sentence segmentation
# * Pre-trained word vectors
# * Part-of-speech tagging
# * Named entity recognition
# * Labelled dependency parsing
# * A built-in visualizer
#
# ...and much more, all with just one function!
#
# SpaCy also provides some already trained [models](https://alpha.spacy.io/models/) which you can use out-of-the-box to process different languages. SpaCy's core is written in pure C (via Cython), it's currently the [fastest](https://alpha.spacy.io/usage/facts-figures) parser available and makes [multithreading](https://explosion.ai/blog/multithreading-with-cython) profitable by virtue of Cython.
#
# Follow the *README* of this repo and install the Spanish language model. Now import the model, and load spaCy's pipeline:

# %%
# %%time 
import spacy

#Initialize SpaCy's pipeline
nlp = spacy.load('es_core_web_sm')
# Out:
# CPU times: user 303 ms, sys: 34.1 ms, total: 337 ms
# Wall time: 1.23 s

# %% [markdown]
# Now that we have a processing pipeline, we can call a *nlp* instance as if it were a function on a string of text. This will produce a [Doc](https://alpha.spacy.io/api/doc) object, a special container that holds all linguistic annotations of the text fed in.
#
# Let's first explore how SpaCy processes a single entity, before diving into the dataset:

# %%
# %%time
#Snip single line of text
with codecs.open('data/text.txt',encoding='utf-8') as text:
    line_txt = text.readline()

#Standard way of processing text 
doc = nlp(line_txt)
# Out:
# CPU times: user 502 ms, sys: 1.06 s, total: 1.56 s
# Wall time: 696 ms

# %%
print(doc)
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macri para que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. El proyecto quedó rengo", contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo ...

# %% [markdown]
# Looks exactly the same! But what happened under the hood? Have a look at how [spaCy's pipeline](https://alpha.spacy.io/usage/processing-pipelines) is made:
#
# __Text -> tokenizer -> tagger -> parser -> ner -> Doc__
#
# Text analysis is built from bottom-up. The *tokenizer* creates a *Doc* data structure, breaking the text in tokens and storing their metadata in a tensor. The *tagger* takes these tokens (and their context) and uses the information to make predictions of the part-of-speech tags. The *parser* assigns dependency labels between tokens and segments text in sentences. The *ner*, named entity recognizer, detects and labels named entities.
# ### Sentence detection and segmentation
# Sentences are automatically extracted from each post:

# %%
for i, sent in enumerate(doc.sents):
    print ('Sentence {}:'.format(i + 1),sent,end='\n')
# Out:
# Sentence 1: Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle.
# Sentence 2: Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macri para que lo ayude a sostener el emprendimiento.
# Sentence 3: El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia.
# Sentence 4: Allí, le prometió ayuda.
# Sentence 5: Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana.
# Sentence 6: Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio.
# Sentence 7: Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo.
# Sentence 8: No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales.
# Sentence 9: Macri me dijo que lo hagamos.
# Sentence 10: Los tiempos de Nación no son los mismos que los de la gente".
# Sentence 11: "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-.
# Sentence 12: Puse plata de mi bolsillo, pero no puedo más.
# Sentence 13: No pedí nada para mí, era para la gente.
# Sentence 14: Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".
# Sentence 15: Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera.
# Sentence 16: El proyecto quedó rengo", contó.
# Sentence 17: Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.
# Sentence 18: No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'.
# Sentence 19: ¿Cómo me van a contar eso? .
# Sentence 20: No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo.
# Sentence 21: Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos".
# Sentence 22: El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”.
# Sentence 23: Luego, le regaló una camiseta de Talleres con el nombre del presidente.
# Sentence 24: Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle".
# Sentence 25: "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 26: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado.
# Sentence 27: “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba.
# Sentence 28: Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 29: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia.
# Sentence 30: Cuando hablamos con el gobierno se comprometieron a ayudarnos.
# Sentence 31: El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente.
# Sentence 32: Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga.
# Sentence 33: Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen.
# Sentence 34: Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue.
# Sentence 35: Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación.
# Sentence 36: Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga.
# Sentence 37: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo.
# Sentence 38: El gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema.
# Sentence 39: Tanto nosotros cómo el Estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer.
# Sentence 40: Entendemos, además, que el Estado debe cuidar el dinero de los argentinos.
# Sentence 41: Nosotros vimos una situación de vulnerabilidad y quisimos ayudar.
# Sentence 42: Desde el Estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie.
# Sentence 43: Por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida, que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan.
# Sentence 44: Esta gente en situación de calle, ES GENTE BUENA Y TODOS TENEMOS QUE AYUDARLOS.
# Sentence 45: ESTAN SOLOS Y DESPROTEGIDOS.
# Sentence 46: Ratificamos nuestras ganas, buscaremos la manera y cuando estén dadas todas las condiciones necesarias, en conjunto con el gobierno nacional, retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle, darles formación y trabajo para que puedan vivir dignamente.

# %% [markdown]
# ### Part-of-speech (POS) tagging and grammar analysis
# Using [Pandas](http://pandas.pydata.org/), Python Data Analysis library, we can have a clean table visualization.
# - Text: The original word text.
# - POS: The simple part-of-speech tag.
# - Tag: The detailed part-of-speech tag, with full morphology!
# - Dep: Syntactic dependency, i.e. the relation between tokens.

# %%
import pandas as pd

token_text = [token.orth_ for token in doc]
token_pos = [token.pos_ for token in doc]
token_tag = [token.tag_ for token in doc]
token_dep = [token.dep_ for token in doc]

pd.DataFrame(list(zip(token_text,token_pos,token_tag,token_dep)), columns=['Text', 'POS','Tag','Dep'])
# Out:
#             Text    POS                                                Tag  \
# 0          Cerró   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past...
# 1             el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 2        comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 3       cordobés    ADJ                                   ADJ__Number=Sing
# 4             al    ADP      ADP__AdpType=Preppron|Gender=Masc|Number=Sing
# 5            que   PRON                                 PRON__PronType=Rel
# 6          Macri  PROPN                                           PROPN___
# 7             le   PRON   PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs
# 8          había    AUX  AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|V...
# 9      prometido   VERB  VERB__Gender=Masc|Number=Sing|Tense=Past|VerbF...
# 10         ayuda   NOUN                       NOUN__Gender=Fem|Number=Sing
# 11          Luis  PROPN                                           PROPN___
# 12      Almadaes  PROPN                                           PROPN___
# 13      cordobés    ADJ                                   ADJ__Number=Plur
# 14        ytenía   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|...
# 15            un    DET  DET__Definite=Ind|Gender=Masc|Number=Sing|Pron...
# 16       comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 17   comunitario    ADJ                       ADJ__Gender=Masc|Number=Sing
# 18             y   CONJ                                           CCONJ___
# 19           una    DET  DET__Definite=Ind|Gender=Fem|Number=Sing|PronT...
# 20     fundación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 21          para    ADP                                  ADP__AdpType=Prep
# 22        ayudar   VERB                                 VERB__VerbForm=Inf
# 23             a    ADP                                  ADP__AdpType=Prep
# 24         gente   NOUN                       NOUN__Gender=Fem|Number=Sing
# 25            en    ADP                                  ADP__AdpType=Prep
# 26     situación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 27            de    ADP                                  ADP__AdpType=Prep
# 28         calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 29             .  PUNCT                              PUNCT__PunctType=Peri
# ..           ...    ...                                                ...
# 958     gobierno   NOUN                      NOUN__Gender=Masc|Number=Sing
# 959     nacional    ADJ                                   ADJ__Number=Sing
# 960            ,  PUNCT                              PUNCT__PunctType=Comm
# 961  retomaremos   VERB  VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres...
# 962           el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 963      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 964       juntos    ADJ                       ADJ__Gender=Masc|Number=Plur
# 965         para    ADP                                  ADP__AdpType=Prep
# 966        sacar   VERB                                 VERB__VerbForm=Inf
# 967            a    ADP                                  ADP__AdpType=Prep
# 968        todas    DET           DET__Gender=Fem|Number=Plur|PronType=Ind
# 969          las    DET  DET__Definite=Def|Gender=Fem|Number=Plur|PronT...
# 970     personas   NOUN                       NOUN__Gender=Fem|Number=Plur
# 971          que   PRON                                 PRON__PronType=Rel
# 972      podamos    AUX  AUX__Mood=Sub|Number=Plur|Person=1|Tense=Pres|...
# 973           de    ADP                                  ADP__AdpType=Prep
# 974           la    DET  DET__Definite=Def|Gender=Fem|Number=Sing|PronT...
# 975        calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 976            ,  PUNCT                              PUNCT__PunctType=Comm
# 977       darles    ADJ                                   ADJ__Number=Plur
# 978    formación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 979            y   CONJ                                           CCONJ___
# 980      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 981         para    ADP                                  ADP__AdpType=Prep
# 982          que  SCONJ                                           SCONJ___
# 983       puedan    AUX  AUX__Mood=Sub|Number=Plur|Person=3|Tense=Pres|...
# 984        vivir   VERB                                 VERB__VerbForm=Inf
# 985   dignamente    ADV                                             ADV___
# 986            .  PUNCT                              PUNCT__PunctType=Peri
# 987           \n  SPACE
#
#         Dep
# 0      ROOT
# 1       det
# 2     nsubj
# 3      amod
# 4      case
# 5       obj
# 6     nsubj
# 7       obj
# 8       aux
# 9       acl
# 10      obj
# 11    nsubj
# 12     flat
# 13    nsubj
# 14    advcl
# 15      det
# 16      obj
# 17     amod
# 18       cc
# 19      det
# 20     conj
# 21     mark
# 22      acl
# 23     case
# 24      obj
# 25     case
# 26      obl
# 27     case
# 28     nmod
# 29    punct
# ..      ...
# 958    nmod
# 959    amod
# 960   punct
# 961   advcl
# 962     det
# 963     obj
# 964    amod
# 965    mark
# 966   advcl
# 967    case
# 968     det
# 969     det
# 970     obj
# 971     obj
# 972     acl
# 973    case
# 974     det
# 975     obj
# 976   punct
# 977    amod
# 978   appos
# 979      cc
# 980    conj
# 981    mark
# 982    mark
# 983     aux
# 984   advcl
# 985  advmod
# 986   punct
# 987
#
# [988 rows x 4 columns]

# %% [markdown]
# ### Navigating the parse tree
# SpaCy uses the terms *head* and *child* to describe the words connected by a single arc in the dependency tree. The term *dep* is used for the arc label, which describes the type of syntactic relation that connects the child to the head. As with other attributes, the value of *.dep* is a hash value. You can get the string value with *.dep\_*.
# - Text: The original token text.
# - Dep: The syntactic relation connecting child to head.
# - Head text: The original text of the token head.
# - Head POS: The part-of-speech tag of the token head.
# - Children: The immediate syntactic dependents of the token.

# %%
token_text = [token.text for token in doc]
token_head_pos = [token.head.pos_ for token in doc]
token_head_text = [token.head.text for token in doc]
token_dep = [token.dep_ for token in doc]
token_children = [[child for child in token.children] for token in doc]
pd.DataFrame(list(zip(token_text,token_dep,token_head_text,token_head_pos,token_children)), columns=['Text','Dep','Head text','Head POS','Children'])
# Out:
#             Text     Dep    Head text Head POS  \
# 0          Cerró    ROOT        Cerró     VERB
# 1             el     det      comedor     NOUN
# 2        comedor   nsubj        Cerró     VERB
# 3       cordobés    amod      comedor     NOUN
# 4             al    case          que     PRON
# 5            que     obj    prometido     VERB
# 6          Macri   nsubj    prometido     VERB
# 7             le     obj    prometido     VERB
# 8          había     aux    prometido     VERB
# 9      prometido     acl     cordobés      ADJ
# 10         ayuda     obj    prometido     VERB
# 11          Luis   nsubj    prometido     VERB
# 12      Almadaes    flat         Luis    PROPN
# 13      cordobés   nsubj       ytenía     VERB
# 14        ytenía   advcl        Cerró     VERB
# 15            un     det      comedor     NOUN
# 16       comedor     obj       ytenía     VERB
# 17   comunitario    amod      comedor     NOUN
# 18             y      cc    fundación     NOUN
# 19           una     det    fundación     NOUN
# 20     fundación    conj      comedor     NOUN
# 21          para    mark       ayudar     VERB
# 22        ayudar     acl    fundación     NOUN
# 23             a    case        gente     NOUN
# 24         gente     obj       ayudar     VERB
# 25            en    case    situación     NOUN
# 26     situación     obl       ayudar     VERB
# 27            de    case        calle     NOUN
# 28         calle    nmod    situación     NOUN
# 29             .   punct        Cerró     VERB
# ..           ...     ...          ...      ...
# 958     gobierno    nmod     conjunto     NOUN
# 959     nacional    amod     gobierno     NOUN
# 960            ,   punct     conjunto     NOUN
# 961  retomaremos   advcl  Ratificamos     VERB
# 962           el     det      trabajo     NOUN
# 963      trabajo     obj  retomaremos     VERB
# 964       juntos    amod      trabajo     NOUN
# 965         para    mark        sacar     VERB
# 966        sacar   advcl  retomaremos     VERB
# 967            a    case     personas     NOUN
# 968        todas     det          las      DET
# 969          las     det     personas     NOUN
# 970     personas     obj        sacar     VERB
# 971          que     obj      podamos      AUX
# 972      podamos     acl     personas     NOUN
# 973           de    case        calle     NOUN
# 974           la     det        calle     NOUN
# 975        calle     obj      podamos      AUX
# 976            ,   punct      podamos      AUX
# 977       darles    amod    formación     NOUN
# 978    formación   appos     personas     NOUN
# 979            y      cc      trabajo     NOUN
# 980      trabajo    conj    formación     NOUN
# 981         para    mark        vivir     VERB
# 982          que    mark        vivir     VERB
# 983       puedan     aux        vivir     VERB
# 984        vivir   advcl        sacar     VERB
# 985   dignamente  advmod        vivir     VERB
# 986            .   punct  Ratificamos     VERB
# 987           \n                    .    PUNCT
#
#                                  Children
# 0                    [comedor, ytenía, .]
# 1                                      []
# 2                          [el, cordobés]
# 3                             [prometido]
# 4                                      []
# 5                                    [al]
# 6                                      []
# 7                                      []
# 8                                      []
# 9    [que, Macri, le, había, ayuda, Luis]
# 10                                     []
# 11                             [Almadaes]
# 12                                     []
# 13                                     []
# 14                    [cordobés, comedor]
# 15                                     []
# 16           [un, comunitario, fundación]
# 17                                     []
# 18                                     []
# 19                                     []
# 20                       [y, una, ayudar]
# 21                                     []
# 22               [para, gente, situación]
# 23                                     []
# 24                                    [a]
# 25                                     []
# 26                            [en, calle]
# 27                                     []
# 28                                   [de]
# 29                                     []
# ..                                    ...
# 958                   [con, el, nacional]
# 959                                    []
# 960                                    []
# 961            [conjunto, trabajo, sacar]
# 962                                    []
# 963                          [el, juntos]
# 964                                    []
# 965                                    []
# 966               [para, personas, vivir]
# 967                                    []
# 968                                    []
# 969                               [todas]
# 970          [a, las, podamos, formación]
# 971                                    []
# 972                       [que, calle, ,]
# 973                                    []
# 974                                    []
# 975                              [de, la]
# 976                                    []
# 977                                    []
# 978                     [darles, trabajo]
# 979                                    []
# 980                                   [y]
# 981                                    []
# 982                                    []
# 983                                    []
# 984       [para, que, puedan, dignamente]
# 985                                    []
# 986                                  [\n]
# 987                                    []
#
# [988 rows x 5 columns]

# %% [markdown]
# ### Named entity recognition (NER)

# %%
for num, ent in enumerate(doc.ents):
    print ('Entity {}:'.format(num + 1),ent,'-', ent.label_,end='\n')
# Out:
# Entity 1: Macri - PER
# Entity 2: Luis Almadaes - PER
# Entity 3: Desesperado - LOC
# Entity 4: Mauricio Macri - PER
# Entity 5: Allí - PER
# Entity 6: Yo Te Ayudo Amigo del Alma - MISC
# Entity 7: Almada - LOC
# Entity 8: La Naciónque - LOC
# Entity 9: Puse - PER
# Entity 10: No llamé al Presidente - MISC
# Entity 11: Macri me dijo - MISC
# Entity 12: Los tiempos de Nación - MISC
# Entity 13: Puse - PER
# Entity 14: No pedí nada para mí - MISC
# Entity 15: Vino el Presidente - PER
# Entity 16: Almada - LOC
# Entity 17: Provincia - LOC
# Entity 18: Municipalidad - LOC
# Entity 19: El proyecto quedó rengo - MISC
# Entity 20: Hace - ORG
# Entity 21: Carolina Stanley - PER
# Entity 22: Presidente - PER
# Entity 23: Ahora - MISC
# Entity 24: Almada - LOC
# Entity 25: Cómo - MISC
# Entity 26: No tengo más plata - MISC
# Entity 27: Laburo - MISC
# Entity 28: El día de la visita presidencial - MISC
# Entity 29: Talleres - ORG
# Entity 30: Sin embargo - MISC
# Entity 31: Almada - LOC
# Entity 32: Estado Nacional - LOC
# Entity 33: Ayer - LOC
# Entity 34: Ello nos obliga a seguirlos - MISC
# Entity 35: Yo te ayudo Amigo del Alma - MISC
# Entity 36: Estado Nacional - LOC
# Entity 37: Córdoba - LOC
# Entity 38: Ayer - LOC
# Entity 39: Ello nos obliga a seguirlos - MISC
# Entity 40: Cuando hablamos con el gobierno - MISC
# Entity 41: El Ministerio de Desarrollo Social de la Nación - MISC
# Entity 42: Mientras no los tuvimos nosotros salimos por nuestra - MISC
# Entity 43: Le dimos Comida - MISC
# Entity 44: Le dimos Trabajo - MISC
# Entity 45: Le dimos Albergue - MISC
# Entity 46: Este flagelo esta contaminando gravemente nuestra población - MISC
# Entity 47: Entendimos que no alcanza con alimentarlos - MISC
# Entity 48: Ayer - LOC
# Entity 49: Le - LOC
# Entity 50: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido - MISC
# Entity 51: El gobierno nos acompaña - MISC
# Entity 52: Tanto nosotros - MISC
# Entity 53: Estado entendemos - LOC
# Entity 54: Entendemos - MISC
# Entity 55: Estado - LOC
# Entity 56: Nosotros - MISC
# Entity 57: Desde el Estado - MISC
# Entity 58: Por eso es necesario - MISC
# Entity 59: ES GENTE BUENA Y TODOS TENEMOS - MISC
# Entity 60: AYUDARLOS - LOC
# Entity 61: ESTAN SOLOS - MISC
# Entity 62: DESPROTEGIDOS - MISC
# Entity 63: Ratificamos - LOC
# Entity 64:
#  - MISC

# %% [markdown]
# ### Visualization with displaCy
# SpaCy has an integrated visualization library that can display the content in two styles: *dep* and *ent*.
# The *dep* style shows the dependency between words using arcs, the *ent* style prints out the text with colored NER labels wrapped around words.
#
# The method *.serve()* launches a local web server for visualization while the method *.render()* generates an image.
#
# __Note__: Style *dep* is not working well in Spanish because *tag* is used instead of *POS* for annotating words, but the *tag* field is much larger than *POS* thus causing overlapping.
#
# __Note2__: Style *ent* can't be viewed in Github, but in Jupyter is great.

# %%
from spacy import displacy
#displacy.serve(doc, style='dep')
options = {'distance':425, 'arrow_spacing':6}
displacy.render(doc,style='dep', jupyter=True, options=options)

# %%
#displacy.serve(doc,style='dep')
displacy.render(doc,style='ent', jupyter=True)

# %% [markdown]
# ### Text normalization: stemming, lemmatization and shape analysis
# Let's now move on to single token analysis. *Normalization* is a way of processing text that involves changing the words to make them less unique. We talk about *stemming* when we take the words and we remove the end part, producing a new token that often is not in the language dictionary. *Lemmatization* takes inflected words as input and tries to give the root word as output, so in some way is similar to stemming, but it produces meaningful (actually existing) words. The token *shape* is the de-capitalization char mask that gets applied to the original (orthodox) token.

# %%
token_lemma = [token.lemma_ for token in doc]
token_shape = [token.shape_ for token in doc]

pd.DataFrame(list(zip(token_text, token_lemma, token_shape)),columns=['token_text', 'token_lemma', 'token_shape'])
# Out:
#       token_text  token_lemma token_shape
# 0          Cerró        cerró       Xxxxx
# 1             el           el          xx
# 2        comedor      comedor        xxxx
# 3       cordobés     cordobés        xxxx
# 4             al           al          xx
# 5            que          que         xxx
# 6          Macri        macri       Xxxxx
# 7             le           le          xx
# 8          había        había        xxxx
# 9      prometido    prometido        xxxx
# 10         ayuda        ayuda        xxxx
# 11          Luis         luis        Xxxx
# 12      Almadaes     almadaes       Xxxxx
# 13      cordobés     cordobés        xxxx
# 14        ytenía       ytenía        xxxx
# 15            un           un          xx
# 16       comedor      comedor        xxxx
# 17   comunitario  comunitario        xxxx
# 18             y            y           x
# 19           una          una         xxx
# 20     fundación    fundación        xxxx
# 21          para         para        xxxx
# 22        ayudar       ayudar        xxxx
# 23             a            a           x
# 24         gente        gente        xxxx
# 25            en           en          xx
# 26     situación    situación        xxxx
# 27            de           de          xx
# 28         calle        calle        xxxx
# 29             .            .           .
# ..           ...          ...         ...
# 958     gobierno     gobierno        xxxx
# 959     nacional     nacional        xxxx
# 960            ,            ,           ,
# 961  retomaremos  retomaremos        xxxx
# 962           el           el          xx
# 963      trabajo      trabajo        xxxx
# 964       juntos       juntos        xxxx
# 965         para         para        xxxx
# 966        sacar        sacar        xxxx
# 967            a            a           x
# 968        todas        todas        xxxx
# 969          las          las         xxx
# 970     personas     personas        xxxx
# 971          que          que         xxx
# 972      podamos      podamos        xxxx
# 973           de           de          xx
# 974           la           la          xx
# 975        calle        calle        xxxx
# 976            ,            ,           ,
# 977       darles       darles        xxxx
# 978    formación    formación        xxxx
# 979            y            y           x
# 980      trabajo      trabajo        xxxx
# 981         para         para        xxxx
# 982          que          que         xxx
# 983       puedan       puedan        xxxx
# 984        vivir        vivir        xxxx
# 985   dignamente   dignamente        xxxx
# 986            .            .           .
# 987           \n           \n          \n
#
# [988 rows x 3 columns]

# %% [markdown]
# Too bad, lemmatization is actually not supported for the Spanish language model (for the English model however it has good support). We still have some normalization, as seen from the shape mask applied to every word.
#
# ### Token-level entity analysis
# The standard way to access entity annotations is the *doc.ents* property, but you can also access token entity annotations using the *token.ent_iob* and *token.ent_type* attributes; *token.ent_iob* indicates whether an entity starts, continues or ends on the tag.
#
# IOB Scheme:
# - *I* - Token is *inside* an entity.
# - *O* - Token is *outside* an entity.
# - *B* - Token is the *beginning* of an entity.

# %%
token_entity_type = [token.ent_type_ for token in doc]
token_entity_iob = [token.ent_iob_ for token in doc]

pd.DataFrame(list(zip(token_text, token_entity_type, token_entity_iob)), columns=['token_text', 'entity_type', 'inside_outside_begin'])
# Out:
#       token_text entity_type inside_outside_begin
# 0          Cerró                                O
# 1             el                                O
# 2        comedor                                O
# 3       cordobés                                O
# 4             al                                O
# 5            que                                O
# 6          Macri         PER                    B
# 7             le                                O
# 8          había                                O
# 9      prometido                                O
# 10         ayuda                                O
# 11          Luis         PER                    B
# 12      Almadaes         PER                    I
# 13      cordobés                                O
# 14        ytenía                                O
# 15            un                                O
# 16       comedor                                O
# 17   comunitario                                O
# 18             y                                O
# 19           una                                O
# 20     fundación                                O
# 21          para                                O
# 22        ayudar                                O
# 23             a                                O
# 24         gente                                O
# 25            en                                O
# 26     situación                                O
# 27            de                                O
# 28         calle                                O
# 29             .                                O
# ..           ...         ...                  ...
# 958     gobierno                                O
# 959     nacional                                O
# 960            ,                                O
# 961  retomaremos                                O
# 962           el                                O
# 963      trabajo                                O
# 964       juntos                                O
# 965         para                                O
# 966        sacar                                O
# 967            a                                O
# 968        todas                                O
# 969          las                                O
# 970     personas                                O
# 971          que                                O
# 972      podamos                                O
# 973           de                                O
# 974           la                                O
# 975        calle                                O
# 976            ,                                O
# 977       darles                                O
# 978    formación                                O
# 979            y                                O
# 980      trabajo                                O
# 981         para                                O
# 982          que                                O
# 983       puedan                                O
# 984        vivir                                O
# 985   dignamente                                O
# 986            .                                O
# 987           \n        MISC                    B
#
# [988 rows x 3 columns]

# %% [markdown]
# ### Token-level attributes
# Other useful metadata is provided, such as the relative frequency of tokens, and whether or not a token matches any of these categories:
# - stop-word
# - punctuation
# - whitespace
# - number
# - url
#
# ...and many more token [attributes](https://alpha.spacy.io/api/token#attributes)! If you are using the alpha version of spaCy, you can also add [custom attributes](https://explosion.ai/blog/spacy-v2-pipelines-extensions) to tokens.

# %%
token_attributes = [(token.orth_,token.prob,token.is_stop,token.is_punct,token.is_space,token.like_num,token.like_url) for token in doc]

df = pd.DataFrame(token_attributes,columns=['text','prob','stop?','punctuation?','whitespace?','number?','url?'])

df.loc[:, 'stop?':'url?'] = (df.loc[:, 'stop?':'url?'].applymap(lambda x: u'Yes' if x else u''))
                                               
df
# Out:
#             text  prob stop? punctuation? whitespace? number? url?
# 0          Cerró -20.0
# 1             el -20.0   Yes
# 2        comedor -20.0
# 3       cordobés -20.0
# 4             al -20.0   Yes
# 5            que -20.0   Yes
# 6          Macri -20.0
# 7             le -20.0   Yes
# 8          había -20.0   Yes
# 9      prometido -20.0
# 10         ayuda -20.0
# 11          Luis -20.0
# 12      Almadaes -20.0
# 13      cordobés -20.0
# 14        ytenía -20.0
# 15            un -20.0   Yes
# 16       comedor -20.0
# 17   comunitario -20.0
# 18             y -20.0
# 19           una -20.0   Yes
# 20     fundación -20.0
# 21          para -20.0   Yes
# 22        ayudar -20.0
# 23             a -20.0
# 24         gente -20.0
# 25            en -20.0   Yes
# 26     situación -20.0
# 27            de -20.0   Yes
# 28         calle -20.0
# 29             . -20.0                Yes
# ..           ...   ...   ...          ...         ...     ...  ...
# 958     gobierno -20.0
# 959     nacional -20.0
# 960            , -20.0                Yes
# 961  retomaremos -20.0
# 962           el -20.0   Yes
# 963      trabajo -20.0   Yes
# 964       juntos -20.0
# 965         para -20.0   Yes
# 966        sacar -20.0
# 967            a -20.0
# 968        todas -20.0   Yes
# 969          las -20.0   Yes
# 970     personas -20.0
# 971          que -20.0   Yes
# 972      podamos -20.0
# 973           de -20.0   Yes
# 974           la -20.0   Yes
# 975        calle -20.0
# 976            , -20.0                Yes
# 977       darles -20.0
# 978    formación -20.0
# 979            y -20.0
# 980      trabajo -20.0   Yes
# 981         para -20.0   Yes
# 982          que -20.0   Yes
# 983       puedan -20.0
# 984        vivir -20.0
# 985   dignamente -20.0
# 986            . -20.0                Yes
# 987           \n -20.0                            Yes
#
# [988 rows x 7 columns]

# %% [markdown]
# The relative frequency is not stored in the model, but that's not important since we don't intend to rely on it anyways.  We can see that there are some problems with stop-words, for example "trabajo" should not be considered a stop-word, thus in the next section we have to manually adjust this attribute.
#
# ## Text normalization, lemmatization, stop-words removal and sentence segmentation
# Now that we have explored all that spaCy can do for us, we can use it to parse our *text.txt* and generate a new *parsed_text.txt* that has the same text, normalized, lemmatized, deprived of stop-words and segmented in sentences.
#
# We first define a helper function that constructs a generator to loop over the *text.txt* and yield the posts one-by-one. A generator is similar to an iterator but it can be used only once because its content is generated on the fly and not stored in memory, saving precious computation.
#
# Then, we pass on the posts to spaCy using the *.pipe()* method via a generator function to parse the posts, lemmatize the text, and yield segmantized sentences. The standard way to initialize spaCy would be to call *nlp(text.txt)* on each post, but I will make use instead of the *.pipe()* method which allows efficient [multi-threading](https://spacy.io/docs/usage/processing-text#multithreading). Two [arguments](https://alpha.spacy.io/api/language#pipe) are given to *.pipe()*: *batch_size* is the number of posts to buffer and *n_threads* which is the number of worker threads to use (default is 2, if -1 OpenMP will decide how many to use at run time). You can also pass a *disable* option to turn off some components of the pipeline that is not needed to further optimize the processing. Note that all processing algorithms are linear-time in the length of the string.
#
# Luckily for us, spaCy makes it really easy to modify the pipeline. As explained in the former section, we are going to insert some custom stop-words that were missing in our vocabulary and remove some other ones. As you can see some tokens should be considered stop-words, such as "y" and "a" are not correctly identified, and, viceversa, words such as "trabajo" should not be classified as stop-words. To fix this, we have to list all stop-words present in our model and if they are not supposed to be stop-words we can manually remove them from the pipeline, while to include new stop-words we just have to see if they appear in our topic models and only then come back and label them as stop-words. Another thing we will add to spaCy's pipeline is a custom normalization that replaces accent characters such as *è* and *é* with regular characters such as a simpler *e*, because some people choose to use accents and some don't, and in topic modeling we don't want to have two separate entries for *macrì* and *macri*. We also fix some punctuation although it will be removed anyway by the lemmatizer.
#
# Finally, we write the sentences to a new txt file, *parsed_text.txt*.

# %%
# %%time

#Helper function that yields all posts via generator 
def get_post(filename):
    with codecs.open(filename,encoding='utf-8') as textfile:
        for post in textfile:
            post = post.replace('ó','o')            
            post = post.replace('ó','o')
            post = post.replace('Ó','o')
            post = post.replace('Ò','o')
            post = post.replace('í','i')
            post = post.replace('ì','i')
            post = post.replace('Ì','i')            
            post = post.replace('Í','i')            
            post = post.replace('à','a')
            post = post.replace('á','a')
            post = post.replace('À','a')
            post = post.replace('Á','a')
            post = post.replace('ù','u')
            post = post.replace('Ù','u')
            post = post.replace('Ú','u')
            post = post.replace('ú','u')
            post = post.replace('ü','u')
            post = post.replace('è','e')
            post = post.replace('é','e')
            post = post.replace('È','e')
            post = post.replace('É','e')
            post = post.replace('¿','')
            post = post.replace('“','\"')
            post = post.replace('”','\"') 
            post = post.replace('\’','\"') 
            yield post
            
#Add and remove custom stop words
nlp.vocab["A"].is_stop = True
nlp.vocab["a"].is_stop = True
nlp.vocab["Y"].is_stop = True
nlp.vocab["y"].is_stop = True
nlp.vocab["o"].is_stop = True
nlp.vocab["O"].is_stop = True
nlp.vocab["and"].is_stop = True
nlp.vocab["And"].is_stop = True
nlp.vocab["the"].is_stop = True
nlp.vocab["The"].is_stop = True
nlp.vocab["e"].is_stop = True
nlp.vocab["E"].is_stop = True
nlp.vocab["ciento"].is_stop = True
nlp.vocab["año"].is_stop = True
nlp.vocab["años"].is_stop = True
nlp.vocab["trabajo"].is_stop = False
nlp.vocab["Trabajo"].is_stop = False
nlp.vocab["Trabajar"].is_stop = False
nlp.vocab["trabajan"].is_stop = False
nlp.vocab["Trabaja"].is_stop = False
nlp.vocab["trabaja"].is_stop = False
nlp.vocab["tiempo"].is_stop = False
nlp.vocab["Tiempo"].is_stop = False
nlp.vocab["Respecto"].is_stop = False
nlp.vocab["respecto"].is_stop = False
nlp.vocab["primero"].is_stop = False
nlp.vocab["primera"].is_stop = False
nlp.vocab["PRIMERO"].is_stop = False
nlp.vocab["primeros"].is_stop = False
nlp.vocab["primer"].is_stop = False
nlp.vocab["Primero"].is_stop = False
nlp.vocab["Primera"].is_stop = False
nlp.vocab["Momento"].is_stop = False
nlp.vocab["momento"].is_stop = False
nlp.vocab["MOMENTO"].is_stop = False
nlp.vocab["Estado"].is_stop = False
nlp.vocab["estado"].is_stop = False
nlp.vocab["Estados"].is_stop = False
nlp.vocab["grandes"].is_stop = False
nlp.vocab["diferente"].is_stop = False
nlp.vocab["diferentes"].is_stop = False
nlp.vocab["realizar"].is_stop = False
nlp.vocab["realizado"].is_stop = False
nlp.vocab["REALIZAR"].is_stop = False
nlp.vocab["proximo"].is_stop = False
nlp.vocab["empleo"].is_stop = False
nlp.vocab["Empleo"].is_stop = False
nlp.vocab["acuerdo"].is_stop = False
nlp.vocab["pasado"].is_stop = False
nlp.vocab["pasada"].is_stop = False
nlp.vocab["Van"].is_stop = False
nlp.vocab["finally"].is_stop = False
nlp.vocab["General"].is_stop = False
nlp.vocab["general"].is_stop = False
nlp.vocab["Asi"].is_stop = False
nlp.vocab["misma"].is_stop = False
nlp.vocab["mismo"].is_stop = False
nlp.vocab["mismas"].is_stop = False
nlp.vocab["mismos"].is_stop = False
nlp.vocab["nuevo"].is_stop = False
nlp.vocab["nuevos"].is_stop = False
nlp.vocab["Nuevo"].is_stop = False
nlp.vocab["NUEVO"].is_stop = False
nlp.vocab["nuevas"].is_stop = False
nlp.vocab["Nueva"].is_stop = False
nlp.vocab["nueva"].is_stop = False
nlp.vocab["igual"].is_stop = False
nlp.vocab["Igual"].is_stop = False
nlp.vocab["Debido"].is_stop = False
nlp.vocab["debido"].is_stop = False
nlp.vocab["ejemplo"].is_stop = False
nlp.vocab["verdad"].is_stop = False
nlp.vocab["Verdad"].is_stop = False
nlp.vocab["valor"].is_stop = False
nlp.vocab["Valor"].is_stop = False
nlp.vocab["VALOR"].is_stop = False
nlp.vocab["HASTA"].is_stop = False
nlp.vocab["hasta"].is_stop = False
nlp.vocab["Hasta"].is_stop = False
nlp.vocab["Buenos"].is_stop = False
nlp.vocab["buenos"].is_stop = False
nlp.vocab["BUENOS"].is_stop = False
nlp.vocab["medio"].is_stop = False
nlp.vocab["Medio"].is_stop = False
nlp.vocab["lugar"].is_stop = False
nlp.vocab["mejor"].is_stop = False
nlp.vocab["buena"].is_stop = False
nlp.vocab["BUENA"].is_stop = False
nlp.vocab["Bueno"].is_stop = False
nlp.vocab["bueno"].is_stop = False
nlp.vocab["luego"].is_stop = False
nlp.vocab["Luego"].is_stop = False
nlp.vocab["mal"].is_stop = False
nlp.vocab["poco"].is_stop = False
nlp.vocab["Poco"].is_stop = False
nlp.vocab["Pocos"].is_stop = False
nlp.vocab["pocos"].is_stop = False
nlp.vocab["embargo"].is_stop = False
nlp.vocab["verdadero"].is_stop = False
nlp.vocab["verdadera"].is_stop = False
nlp.vocab["posible"].is_stop = False
nlp.vocab["intento"].is_stop = False

#List current stop words
stop_words = []
for parsed_post in nlp.pipe(get_post("data/text.txt"),batch_size=10, n_threads=3):
    for sent in parsed_post.sents:
        for token in sent:
            if token.is_stop:
                stop_words.append(token.orth_)
print("There are {} total stop words.".format(len(stop_words)))
stop_set = set(stop_words)
print("There are {} unique stop words.".format(len(stop_set)))
print(stop_set)
# Out:
# There are 66046 total stop words.
# There are 607 unique stop words.
# {'cerca', 'Dos', 'Despues', 'habla', 'conocer', 'manera', 'EL', 'Muchos', 'algunos', 'Las', 'pueda', 'QUE', 'ellas', 'largo', 'tu', 'esta', 'conmigo', 'Nunca', 'Sera', 'Ahi', 'mientras', 'Fueron', 'Ellos', 'NO', 'Dio', 'aproximadamente', 'un', 'tienen', 'propias', 'Les', 'menos', 'mayor', 'alli', 'eso', 'Nada', 'existen', 'emplean', 'aquellos', 'cual', 'Conseguir', 'Ahora', 'Tengo', 'Se', 'Aun', 'su', 'A', 'TODO', 'veces', 'este', 'pues', 'lleva', 'tres', 'Tambien', 'Nuestro', 'Fuera', 'Tres', 'fui', 'Ademas', 'ahi', 'Enseguida', 'Poder', 'cuatro', 'En', 'dan', 'unas', 'Desde', 'Hizo', 'USO', 'parece', 'eran', 'Yo', 'esa', 'arriba', 'e', 'eramos', 'Solamente', 'Podemos', 'los', 'nadie', 'parte', 'intentan', 'Tuvo', 'Todos', 'Creo', 'es', 'fue', 'otros', 'ninguna', 'varios', 'alguno', 'and', 'Tiene', 'dijeron', 'alguna', 'AuN', 'tampoco', 'nada', 'TODOS', 'Usted', 'Otras', 'tuvo', 'Hubo', 'Ustedes', 'sino', 'Toda', 'ciertos', 'vaya', 'somos', 'Mas', 'Nosotras', 'Tras', 'no', 'intentar', 'aquellas', 'hubo', 'Esa', 'final', 'saber', 'Algunas', 'Cuales', 'Bien', 'Solo', 'ALGUNA', 'DEL', 'Uno', 'informo', 'mio', 'Podrias', 'podriamos', 'sola', 'demasiado', 'partir', 'Apenas', 'Ese', 'pronto', 'Gran', 'muchas', 'ver', 'Cualquier', 'quiere', 'Hace', 'encima', 'sin', 'todas', 'ultimo', 'propia', 'DOS', 'mi', 'Sus', 'Aunque', 'han', 'para', 'tarde', 'POR', 'otras', 'Habla', 'tambien', 'Somos', 'ocho', 'CON', 'Podria', 'Saben', 'en', 'quizas', 'vamos', 'Mis', 'Cuando', 'Sabes', 'asi', 'Muchas', 'Ha', 'sera', 'Mientras', 'dicho', 'bastante', 'cuenta', 'tenga', 'Antes', 'cinco', 'DADO', 'Nuestra', 'estaba', 'UN', 'supuesto', 'pudo', 'te', 'LOS', 'SIN', 'despues', 'pais', 'ante', 'creo', 'The', 'poner', 'todo', 'cualquier', 'ha', 'dos', 'Esto', 'cierta', 'Hemos', 'dice', 'Soy', 'SE', 'enfrente', 'ese', 'Con', 'les', 'alrededor', 'O', 'Fue', 'NOS', 'cuales', 'dentro', 'Para', 'Ni', 'Va', 'ciertas', 'estar', 'Algunos', 'algunas', 'esto', 'o', 'mis', 'conseguir', 'Estan', 'de', 'Nadie', 'segun', 'toda', 'Esas', 'yo', 'muy', 'trata', 'Hoy', 'SOBRE', 'Claro', 'Estoy', 'fuera', 'Fui', 'Hacia', 'ademas', 'eras', 'estamos', 'ser', 'hacia', 'Incluso', 'Sin', 'solo', 'Vamos', 'horas', 'tuyos', 'Estas', 'Eso', 'que', 'Por', 'Han', 'decir', 'Actualmente', 'Alguna', 'ir', 'Otro', 'entonces', 'si', 'usar', 'Los', 'Cual', 'Voy', 'Cosas', 'Existe', 'considera', 'Lo', 'suyo', 'tiene', 'haciendo', 'Es', 'ex', 'y', 'hace', 'Debe', 'bajo', 'una', 'ESA', 'Aqui', 'Dicen', 'tenemos', 'aqui', 'todos', 'Ninguna', 'Pues', 'ciento', 'TODAS', 'TENEMOS', 'ya', 'Horas', 'apenas', 'SOLOS', 'menudo', 'total', 'mucho', 'siguiente', 'AL', 'hicieron', 'Estaba', 'Mucha', 'junto', 'suya', 'cierto', 'existe', 'debajo', 'ello', 'Usamos', 'Son', 'uno', 'Saber', 'principalmente', 'ellos', 'Segun', 'seis', 'esas', 'ES', 'LA', 'modo', 'nos', 'Cada', 'DURANTE', 'usted', 'las', 'CADA', 'siempre', 'incluso', 'Ya', 'la', 'Cuatro', 'Sean', 'solos', 'lo', 'tener', 'Tampoco', 'entre', 'podrian', 'dieron', 'Habia', 'cuanto', 'Ninguno', 'ni', 'mas', 'the', 'Esta', 'DESDE', 'todavia', 'cuantos', 'Dias', 'nuestra', 'Ser', 'podria', 'De', 'hoy', 'aunque', 'fin', 'otro', 'dio', 'donde', 'LE', 'mediante', 'años', 'Del', 'anterior', 'Estuvo', 'saben', 'Ambos', 'sido', 'uso', 'Ante', 'Mi', 'unos', 'Su', 'fueron', 'ambos', 'consigo', 'muchos', 'estaban', 'Queremos', 'Existen', 'mucha', 'era', 'Estamos', 'Y', 'sea', 'E', 'desde', 'Ello', 'mia', 'Dado', 'Algo', 'cosas', 'porque', 'son', 'algo', 'Salvo', 'aquello', 'da', 'Quizas', 'sus', 'DE', 'segundo', 'usan', 'Como', 'sabe', 'Tal', 'poca', 'temprano', 'siete', 'va', 'sean', 'nunca', 'adelante', 'LAS', 'Alli', 'No', 'esos', 'nuestros', 'PARA', 'UNA', 'del', 'hacerlo', 'Parece', 'casi', 'quienes', 'Le', 'encuentra', 'se', 'Quien', 'conseguimos', 'queremos', 'Muy', 'como', 'usa', 'Puede', 'propio', 'dia', 'ninguno', 'pesar', 'tan', 'tercera', 'sabes', 'Sobre', 'Ayer', 'buen', 'Dijo', 'soy', 'por', 'poder', 'al', 'salvo', 'podemos', 'Otra', 'vez', 'El' ...
# CPU times: user 38.8 s, sys: 43.5 s, total: 1min 22s
# Wall time: 23.9 s

# %% [markdown]
# We are now ready to lemmatize our corpus!

# %%
# %%time
#Parse posts and lemmatize each token sentence by sentence. Then Reassemble the sentences for every post. 
#WARNING: This task is computationally demanding, adjust batch_size and n_threads according to your machine

#All posts
for parsed_post in nlp.pipe(get_post("data/text.txt"),batch_size=10, n_threads=3):
    with codecs.open('data/parsed_text.txt','a',encoding='utf-8') as f:
        for sent in parsed_post.sents:
            for token in sent:
                if not (token.is_punct or token.is_space or token.is_stop or token.like_num or token.like_email or token.like_url):
                    f.write(''.join(token.lemma_) + ' ')
        f.write('\n') 
#Phrases        
    with codecs.open('data/parsed_phrases.txt','a',encoding='utf-8') as f:
        for sent in parsed_post.sents:
            for token in sent:
                if not (token.is_punct or token.is_space or token.is_stop or token.like_num or token.like_email or token.like_url):
                    f.write(''.join(token.lemma_) + ' ')
            f.write('\n')
        f.write('\n')
   

nest = []
for parsed_post in nlp.pipe(get_post("data/text.txt"),batch_size=10, n_threads=3):
    nested = []
    for sent in parsed_post.sents:
        for token in sent:
            if not (token.is_punct or token.is_space or token.is_stop or token.like_num or token.like_email or token.like_url):
                nested.append(token.lemma_)
    nest.append(nested)            
print(nested)

        
##Vecchia funzione
#def lemmatize_corpus(filename):
#    for parsed_review in nlp.pipe(get_review(filename),batch_size=10, n_threads=3):
#        for sent in parsed_review.sents:
#            yield u' '.join([token.lemma_ for token in sent if not (token.is_punct or token.is_space or token.is_stop or token.like_num or token.like_email or token.like_url)])
# Out:
# ['harvey', 'weinstein', 'caida', 'señor', 'hollywood', 'acusaciones', 'escandalosas', 'ashley', 'juddfue', 'primeras', 'denunciar', 'demoro', 'llego', 'hotel', 'hospedaba', 'weinstein', 'creyendo', 'asistia', 'reunion', 'negocios', 'productor', 'aparecio', 'bata', 'baño', 'pidio', 'masaje', 'viera', 'ducharse', 'gwyneth', 'paltrow', 'tenia', 'harvey', 'weinstein', 'manoseo', 'suite', 'hotel', 'beverly', 'hills', 'angelina', 'jolie', 'conto', 'avanzo', 'habitacion', 'hotel', 'rechazo', 'lucia', 'evansdijo', 'llegar', 'casting', 'weinstein', 'ataco', 'sexualmente', 'obligo', 'practicarle', 'sexo', 'oral', 'ambra', 'battilana', 'gutierrez', 'finalista', 'miss', 'italia', 'conto', 'weinstein', 'lanzo', 'toco', 'pechos', 'trato', 'meter', 'mano', 'minifalda', 'cara', 'delevingne', 'asegura', 'weinstein', 'pidio', 'trio', 'lea', 'seydoux', 'avalanzo', 'intento', 'besarla', 'katherine', 'kendallacompaño', 'productor', 'casa', 'llegaron', 'weinstein', 'desvistio', 'persiguio', 'desnudo', 'casa', 'asia', 'argentodenuncio', 'weinstein', 'quito', 'falda', 'forzo', 'practicar', 'sexo', 'oral', 'mira', 'sorvino', 'intento', 'sobrepasarse', 'actriz', 'rechazo', 'rosanna', 'arquette', 'conto', 'nego', 'masturbarlo']
# CPU times: user 1min 15s, sys: 1min 26s, total: 2min 41s
# Wall time: 47.1 s

# %%
print(nesting)
# Out:
# [['cerro', 'comedor', 'cordobes', 'macri', 'prometido', 'ayuda', 'luis', 'almadaes', 'cordobes', 'ytenia', 'comedor', 'comunitario', 'fundacion', 'ayudar', 'gente', 'situacion', 'calle', 'desesperado', 'mayo', 'envio', 'mensaje', 'redes', 'sociales', 'presidente', 'mauricio', 'macri', 'ayude', 'sostener', 'emprendimiento', 'mandatario', 'llamo', 'telefono', 'julio', 'vieron', 'personalmente', 'provincia', 'prometio', 'ayuda', 'llego', 'alternativa', 'bajar', 'persiana', 'fundacion', 'ayudo', 'amigo', 'alma', 'ayudaba', 'personas', 'situacion', 'calle', 'vendieran', 'golosinas', 'peatonal', 'pudieran', 'capacitarse', 'oficio', 'almada', 'nacionque', 'debio', 'cerrar', 'fundacion', 'puse', 'esfuerzo', 'cumpli', 'comprometi', 'llame', 'presidente', 'pedirle', 'alfajores', 'ayudara', 'tratamiento', 'adicciones', 'asistentes', 'sociales', 'macri', 'hagamos', 'tiempos', 'nacion', 'mismos', 'gente', 'pateando', 'primero', 'meses', 'semana', 'pasada', 'meses', '-continuo-', 'puse', 'plata', 'bolsillo', 'pedi', 'gente', 'vino', 'presidente', 'laburo', 'tendrian', 'almada', 'requisitos', 'requisitos', 'piden', 'salon', 'sale', '$', 'aparte', 'pagando', 'provincia', 'alojamiento', 'muchachos', 'municipalidad', 'permiso', 'venta', 'callejera', 'proyecto', 'quedo', 'rengo', 'conto', 'hablo', 'telefonicamente', 'ministra', 'carolina', 'stanley', 'señalo', 'envio', 'asesora', 'reuni', 'concejal', 'presidente', 'palabra', 'vale', 'almada', 'dijimos', 'empezara', 'contar', 'plata', 'positivo', 'muchachos', 'empece', 'trabajo', 'laburo', 'diez', 'sociedad', 'pelota', 'cancha', 'visita', 'presidencial', 'cordobes', 'conto', 'presidente', 'carancheamos', 'pollos', 'fuente', 'luego', 'regalo', 'camiseta', 'talleres', 'nombre', 'presidente', 'embargo', 'luego', 'anunciar', 'cese', 'actividades', 'fundacion', 'almada', 'emitio', 'comunicado', 'traves', 'redes', 'sociales', 'afirma', 'seguira', 'trabajando', 'estado', 'nacional', 'ayudar', 'personas', 'situacion', 'calle', 'recibimos', 'pedido', 'desesperado', 'gente', 'ayudabamos', 'comunicaron', 'personas', 'ganas', 'involucrarse', 'ayudar', 'obliga', 'seguirlos', 'ayudando', 'reevaluar', 'estrategia', 'explica', 'comunicado', 'ayudo', 'amigo', 'alma', 'ratifica', 'seguir', 'trabajando', 'estado', 'nacional', 'ayudar', 'personas', 'situacion', 'calle', 'cordoba', 'recibimos', 'pedido', 'desesperado', 'gente', 'ayudabamos', 'comunicaron', 'personas', 'ganas', 'involucrarse', 'ayudar', 'obliga', 'seguirlos', 'ayudando', 'reevaluar', 'estrategia', 'hablamos', 'gobierno', 'comprometieron', 'ayudarnos', 'ministerio', 'desarrollo', 'social', 'nacion', 'habian', 'pedido', 'requisitos', 'transparente', 'tuvimos', 'salimos', 'gente', 'pudimos', 'dimos', 'comida', 'dimos', 'trabajo', 'dimos', 'albergue', 'imposible', 'luchar', 'flagelo', 'droga', 'flagelo', 'contaminando', 'gravemente', 'poblacion', 'entendimos', 'alcanza', 'alimentarlos', 'darles', 'trabajo', 'posibilidad', 'dormir', 'albergue', 'tuvimos', 'parar', 'pelota', 'resolver', 'problema', 'fundacion', 'generamos', 'empleo', 'dinero', 'bolsillo', 'terminamos', 'dejando', 'pelea', 'droga', 'acordamos', 'meses', 'sirvieron', 'fortalecer', 'conocimiento', 'compartido', 'abordar', 'flagelo', 'gobierno', 'acompaña', 'tematica', 'recursos', 'economicos', 'conocimiento', 'aporte', 'utilizados', 'ayuden', 'verdad', 'gente', 'salir', 'problema', 'estado', 'entendemos', 'significa', 'importante', 'proceso', 'aprendizaje', 'servira', 'continuar', 'entendemos', 'estado', 'cuidar', 'dinero', 'argentinos', 'vimos', 'situacion', 'vulnerabilidad', 'quisimos', 'ayudar', 'estado', 'comprometieron', 'seguir', 'redoblando', 'esfuerzos', 'lograr', 'concretar', 'sueño', 'perjudicial', 'necesario', 'sepamos', 'historias', 'vida', 'facil', 'paciencia', 'trabajo', 'equipo', 'ayudar', 'necesitan', 'gente', 'situacion', 'calle', 'gente', 'buena', 'ayudarlos', 'desprotegidos', 'ratificamos', 'ganas', 'buscaremos', 'esten', 'dadas', 'condiciones', 'necesarias', 'conjunto', 'go ...

# %% [markdown]
# Let's see an excerpt of what we got out of it:

# %%
with codecs.open('data/parsed_text.txt',encoding='utf-8') as parsed_text:    
    print(parsed_text.read(1000))
# Out:
# cerro comedor cordobes macri prometido ayuda luis almadaes cordobes ytenia comedor comunitario fundacion ayudar gente situacion calle desesperado mayo envio mensaje redes sociales presidente mauricio macri ayude sostener emprendimiento mandatario llamo telefono julio vieron personalmente provincia prometio ayuda llego alternativa bajar persiana fundacion ayudo amigo alma ayudaba personas situacion calle vendieran golosinas peatonal pudieran capacitarse oficio almada nacionque debio cerrar fundacion puse esfuerzo cumpli comprometi llame presidente pedirle alfajores ayudara tratamiento adicciones asistentes sociales macri hagamos tiempos nacion mismos gente pateando primero meses semana pasada meses -continuo- puse plata bolsillo pedi gente vino presidente laburo tendrian almada requisitos requisitos piden salon sale $ aparte pagando provincia alojamiento muchachos municipalidad permiso venta callejera proyecto quedo rengo conto hablo telefonicamente ministra carolina stanley señalo envio asesora reuni concejal presidente palabra vale almada dijimos empezara contar plata positivo muchachos empece trabajo laburo diez sociedad pelota cancha visita presidencial cordobes conto presidente carancheamos pollos fuente luego regalo camiseta talleres nombre presidente embargo luego anunciar cese actividades fundacion almada emitio comunicado traves redes sociales afirma seguira trabajando estado nacional ayudar personas situacion calle recibimos pedido desesperado gente ayudabamos comunicaron personas ganas involucrarse ayudar obliga seguirlos ayudando reevaluar estrategia explica comunicado ayudo amigo alma ratifica seguir trabajando estado nacional ayudar personas situacion calle cordoba recibimos pedido desesperado gente ayudabamos comunicaron personas ganas involucrarse ayudar obliga seguirlos ayudando reevaluar estrategia hablamos gobierno comprometieron ayudarnos ministerio desarrollo social nacion habian pedido requisitos transparente tuvimos salimos gente pudimos dimos

# %%
with codecs.open('data/parsed_phrases.txt',encoding='utf-8') as parsed_text:    
    print(parsed_text.read(1000))
# Out:
# cerro comedor cordobes macri prometido ayuda luis almadaes cordobes ytenia comedor comunitario fundacion ayudar gente situacion calle
# desesperado mayo envio mensaje redes sociales presidente mauricio macri ayude sostener emprendimiento
# mandatario llamo telefono julio vieron personalmente provincia
# prometio ayuda
# llego alternativa bajar persiana
# fundacion ayudo amigo alma ayudaba personas situacion calle vendieran golosinas peatonal pudieran capacitarse oficio
# almada nacionque debio cerrar fundacion puse esfuerzo cumpli comprometi
# llame presidente pedirle alfajores ayudara tratamiento adicciones asistentes sociales
# macri hagamos
# tiempos nacion mismos gente
# pateando primero meses semana pasada meses -continuo-
# puse plata bolsillo
# pedi gente
# vino presidente laburo tendrian
# almada requisitos requisitos piden salon sale $ aparte pagando provincia alojamiento muchachos municipalidad permiso venta callejera
# proyecto quedo rengo conto
# hablo telefonicamente ministra carolina sta

# %% [markdown]
# ## Phrase Modeling with Gensim

# %% [markdown]
# __Phrase modeling__ is a form of text manipulation that consists in producing new one-word tokens from two or more token. As we saw in named entity recognition, there are groups of words that represent things that have nothing to do with the single words themselves that make up the group. For example *New York* is supposed to be different in meaning from *New* and *York*. We would like to have these single token words joined together in a single word, with an underscore instead of a space. We then repeat the process (__second-order phrase modeling__) to catch three-word tokens such as *New_York_City*.
#
# We will use [__gensim__](https://radimrehurek.com/gensim/index.html), an incredible Python library that implements several unsupervised machine learning algorithms designed for text analysis and also some useful text manipulation classes. To accomplish phrase modeling, gensim provides automatic common phrase detection (multiword expressions) from a stream of sentences. The phrases are identified as __collocations__ (frequently co-occurring tokens). In the built-in [*gensim.models.phrases.Phrases*](https://radimrehurek.com/gensim/models/phrases.html) class there are actually two ways ([formulas](https://radimrehurek.com/gensim/models/phrases.html#id2)) for measuring the co-occurrence of these composite words in the corpus, meaning the __frequency__ these words appear __together__ in sequence, compared to the frequency they appear __alone__. We will use the *default* mode, with a *threshold* set to *170*, just enough to catch *mauricio_macri* as a phrase.
#
# Gensim's [gensim.models.word2vec.LineSentence](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.LineSentence) class provides a convenient iterator for working with other gensim components. It streams the sentences from the disk, so that you never have to hold the entire corpus in RAM at once. This allows you to scale your modeling pipeline up to potentially very large corpora.
#
# Finally, we write the sentences to a new txt file, *bigram_sents.txt*, and we snip the head to check the result.

# %%
# %%time
import warnings
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

#Supress useless warning
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    
    #Creates iterable of sentences
    unigram_sents = LineSentence('data/parsed_phrases.txt')

    #Initialize the model with our dataset
    bigram_model = Phrases(unigram_sents, threshold=170)

    #Save and load trained model in data directory (optional)
    bigram_model.save('data/bigram_model')
    bigram_model = Phrases.load('data/bigram_model')

    #Write processed sentences to the new file 
    with codecs.open('data/bigram_sents.txt','w',encoding='utf-8') as f:
        for sent in unigram_sents:
            bigram_sent = u' '.join(bigram_model[sent])
            f.write(bigram_sent + '\n')
 #   for sent in unigram_sents:
 #       print(sent)
    #Write processed sentences to the new file 
    with codecs.open('data/bigram_posts.txt','w',encoding='utf-8') as f:
        for sent in unigram_sents:
            bigram_sent = u' '.join(bigram_model[sent])
            f.write(bigram_sent + '\n')
for sent in unigram_sents:
    print(sent)
 #Print the first 3000 characters
    #with codecs.open('data/bigram_posts.txt',encoding='utf-8') as f:    
    #    print(f.read(3000))
# Out:
# ['cerro', 'comedor', 'cordobes', 'macri', 'prometido', 'ayuda', 'luis', 'almadaes', 'cordobes', 'ytenia', 'comedor', 'comunitario', 'fundacion', 'ayudar', 'gente', 'situacion', 'calle']
# ['desesperado', 'mayo', 'envio', 'mensaje', 'redes', 'sociales', 'presidente', 'mauricio', 'macri', 'ayude', 'sostener', 'emprendimiento']
# ['mandatario', 'llamo', 'telefono', 'julio', 'vieron', 'personalmente', 'provincia']
# ['prometio', 'ayuda']
# ['llego', 'alternativa', 'bajar', 'persiana']
# ['fundacion', 'ayudo', 'amigo', 'alma', 'ayudaba', 'personas', 'situacion', 'calle', 'vendieran', 'golosinas', 'peatonal', 'pudieran', 'capacitarse', 'oficio']
# ['almada', 'nacionque', 'debio', 'cerrar', 'fundacion', 'puse', 'esfuerzo', 'cumpli', 'comprometi']
# ['llame', 'presidente', 'pedirle', 'alfajores', 'ayudara', 'tratamiento', 'adicciones', 'asistentes', 'sociales']
# ['macri', 'hagamos']
# ['tiempos', 'nacion', 'mismos', 'gente']
# ['pateando', 'primero', 'meses', 'semana', 'pasada', 'meses', '-continuo-']
# ['puse', 'plata', 'bolsillo']
# ['pedi', 'gente']
# ['vino', 'presidente', 'laburo', 'tendrian']
# ['almada', 'requisitos', 'requisitos', 'piden', 'salon', 'sale', '$', 'aparte', 'pagando', 'provincia', 'alojamiento', 'muchachos', 'municipalidad', 'permiso', 'venta', 'callejera']
# ['proyecto', 'quedo', 'rengo', 'conto']
# ['hablo', 'telefonicamente', 'ministra', 'carolina', 'stanley', 'señalo', 'envio', 'asesora']
# ['reuni', 'concejal', 'presidente', 'palabra', 'vale', 'almada', 'dijimos', 'empezara']
# ['contar']
# ['plata', 'positivo', 'muchachos', 'empece', 'trabajo']
# ['laburo', 'diez', 'sociedad', 'pelota', 'cancha']
# ['visita', 'presidencial', 'cordobes', 'conto', 'presidente', 'carancheamos', 'pollos', 'fuente']
# ['luego', 'regalo', 'camiseta', 'talleres', 'nombre', 'presidente']
# ['embargo', 'luego', 'anunciar', 'cese', 'actividades', 'fundacion', 'almada', 'emitio', 'comunicado', 'traves', 'redes', 'sociales', 'afirma', 'seguira', 'trabajando', 'estado', 'nacional', 'ayudar', 'personas', 'situacion', 'calle']
# ['recibimos', 'pedido', 'desesperado', 'gente', 'ayudabamos', 'comunicaron', 'personas', 'ganas', 'involucrarse', 'ayudar']
# ['obliga', 'seguirlos', 'ayudando', 'reevaluar', 'estrategia', 'explica', 'comunicado']
# ['ayudo', 'amigo', 'alma', 'ratifica', 'seguir', 'trabajando', 'estado', 'nacional', 'ayudar', 'personas', 'situacion', 'calle', 'cordoba']
# ['recibimos', 'pedido', 'desesperado', 'gente', 'ayudabamos', 'comunicaron', 'personas', 'ganas', 'involucrarse', 'ayudar']
# ['obliga', 'seguirlos', 'ayudando', 'reevaluar', 'estrategia']
# ['hablamos', 'gobierno', 'comprometieron', 'ayudarnos']
# ['ministerio', 'desarrollo', 'social', 'nacion', 'habian', 'pedido', 'requisitos', 'transparente']
# ['tuvimos', 'salimos', 'gente', 'pudimos', 'dimos', 'comida', 'dimos', 'trabajo', 'dimos', 'albergue', 'imposible', 'luchar', 'flagelo', 'droga']
# ['flagelo', 'contaminando', 'gravemente', 'poblacion']
# ['entendimos', 'alcanza', 'alimentarlos', 'darles', 'trabajo', 'posibilidad', 'dormir', 'albergue']
# ['tuvimos', 'parar', 'pelota', 'resolver', 'problema', 'fundacion']
# ['generamos', 'empleo', 'dinero', 'bolsillo', 'terminamos', 'dejando', 'pelea', 'droga']
# ['acordamos', 'meses', 'sirvieron', 'fortalecer', 'conocimiento', 'compartido', 'abordar', 'flagelo']
# ['gobierno', 'acompaña', 'tematica', 'recursos', 'economicos', 'conocimiento', 'aporte', 'utilizados', 'ayuden', 'verdad', 'gente', 'salir', 'problema']
# ['estado', 'entendemos', 'significa', 'importante', 'proceso', 'aprendizaje', 'servira', 'continuar']
# ['entendemos', 'estado', 'cuidar', 'dinero', 'argentinos']
# ['vimos', 'situacion', 'vulnerabilidad', 'quisimos', 'ayudar']
# ['estado', 'comprometieron', 'seguir', 'redoblando', 'esfuerzos', 'lograr', 'concretar', 'sueño', 'perjudicial']
# ['necesario', 'sepamos', 'historias', 'vida', 'facil', 'paciencia', 'trabajo', 'equipo', 'ayudar', 'necesitan']
# ['gente', 'situacion', 'calle', 'gente', 'buena', 'ayudarlos']
# ['desprotegidos']
# ['ratificamos', 'ganas', 'buscaremos', 'esten', 'dadas', 'condiciones', 'necesarias', 'conjunto', 'gobierno', 'nacional', 'retomaremos', 'trabajo', 'juntos', 'sacar', 'personas', 'podamos', 'calle', 'darles', 'formacion', 'trabajo', 'puedan', 'vivir', 'dignamente']
# ['detuvieron', 'profesor', 'universitario', 'acusado', 'tirarle', 'huevos', 'macri', 'profesor', 'universitario', 'anibal', 'prina', 'acusado', 'tirado', 'huevos', 'comitiva', 'presidencial', 'marco', 'visita', 'jueves', 'jefe', 'estado', 'mauricio', 'macri', 'santa', 'rosa', 'detenido', 'viernes', 'policia', 'federal']
# ['prina', 'tercer', 'candidato', 'diputado', 'nacional', 'kirchnerista', 'frente', 'peronista', 'barrial', 'quedo', 'arrestado', 'facultad', 'agronomia']
# ['docente', 'acusado', 'cometer', 'delito', 'intimidacion', 'publica', 'estipulado', 'articulo', 'codigo', 'penal']
# ['principio', 'prina', 'demorado', 'facultad', 'agronomia', 'ubicada', 'ruta', 'kilometros', 'capital', 'provincial', 'juez', 'federal', 'facundo', 'cubas', 'orden', 'telefonica', 'redactado', 'escrito', 'formal']
# ['pasadas', 'patrullero', 'policia', 'federal', 'llevo', 'escrito', 'dispuso', 'detencion', 'traslado', 'docente', 'sede', 'fuerza', 'pleno', 'centro', 'capitalino']
# ['organizaba', 'manifestacion', 'frente', 'peronista', 'barrial', 'organizaciones', 'politicas', 'repudiar', 'detencion']
# ['presidente', 'recibido', 'militantes', 'peronistas', 'esperaron', 'paso', 'comitiva', 'oficial', 'lanzar', 'huevos', 'zona', 'rotonda', 'avion', 'referente', 'mapuche', 'desalojado', 'recinto', 'realizaba', 'acto', 'denuncio', 'golpeado', 'personal', 'seguridad']
# ['pasar', 'unico', 'acceso', 'habilitado', 'militantes', 'peronistas', 'tiraron', 'huevos', 'auto', 'presidente', 'macri', 'vehiculos', 'delegacion', 'gobierno', 'nacional']
# ['esperando', 'carteles', 'preguntaban', 'santiago', 'maldonado']
# ['afirmaban', 'tarifazos', 'igual', 'pobreza']
# ['macri', 'generacion', 'vino', 'cambiar', 'historia']
# ['witolda', 'busqueda', 'universo', 'gombrowicz', 'apu', 'reunido', 'crear', 'revista', 'dedicada', 'witold', 'gombrowicz']
# ['nicolas', 'hochman', 'proyecto', 'arranco', 'hicimos', 'congreso', 'internacional', 'witold', 'gombrowicz', 'escritor', 'polaco', 'aca', 'prestigio', 'afuera', 'recontra', 'conocido']
# ['gano', 'premio', 'formentor', 'premio', 'importante', 'gano', 'borges', 'afuera', 'escritores', 'vanguardia', 'importantes', 'siglo', 'xx', 'aca', 'tuvimos', 'cuarto', 'siglo', 'basicamente']
# ['acciones', 'venimos', 'desarrollando', 'equipo', 'congerso', 'gombrowicz', 'vida', 'obra', 'generar', 'nuevos', 'lectores', 'lectores', 'tengan', 'material', 'fresco', 'nuevo', 'den', 'ganas', 'retomarlo']
# ['apu', 'formato', 'revista', 'numero', 'libro', 'compilacion']
# ['nh', 'venimos', 'tiempo']
# ['hicimos', 'libro', 'antologia', 'ilustraciones', 'textos', 'pasado', 'antologia', 'articulos', 'ineditos', 'gombrowicz']
# ['idea', 'vuelta', 'tuerca']
# ['surge', 'poco', 'capricho', 'especie', 'continuacion', 'cumplen', 'aparicion', 'revista', 'promocionaba', 'ferdydurke']
# ['revista', 'llamo', 'aurora', 'revista', 'resistencia', 'revista', 'numero', 'amigo', 'virginio', 'piñeira', 'traductores', 'ferdydurke', 'saco', 'revista', 'llamo', 'victrola', 'revista', 'insistencia']
# ['venimos', 'witolda', 'revista', 'persistencia', 'continuando', 'linea', 'risas']
# ['apu', 'siguiendo', 'linea', 'humor', 'tenia', 'witold', 'realmente', 'importante', 'humor', 'delirio', 'juventud']
# ['nh', 'juventud', 'inmadurez', 'ruptura', 'formas']
# ['gombrowicz', 'provocador', 'seria', 'tuitero', 'risas']
# ['queriamos', 'retomar', 'provocacion', 'formato', 'contenidos', 'revista', 'objeto']
# ['obra', 'arte', 'colores', 'negro', 'rosa', 'fluor', 'verde', 'fluor', 'estridente', 'leer', 'perfecto', 'causa', 'incomodidad', 'impacto', 'incial', 'queriamos', 'transmitir']
# ['apu', 'pensando', 'poco', 'relacion', 'vida', 'obra', 'aspectos', 'destacas']
# ['nh', 'gombrowicz', 'vida', 'obra', 'completamente', 'unidas', 'dificil', 'distinguir', 'escribe', 'ficcion', 'pasa', 'escritor', 'evidente']
# ['novelas', 'cuentos', 'obras', 'teatro', 'aparecen', 'tiempo', 'elementos', 'escritura', 'primera', 'persona', 'absolutamente', 'verosimil', 'concuerda', 'paso', 'paso', 'biografia', 'cartas', 'diarios', 'aparecen', 'literalmente', 'tomadas', 'obras', 'ficcion']
# ['ejemplo', 'vuelve', 'argentina', 'europa', 'toma', 'transatlantico', 'narrando', 'pasa', 'llega', 'cubierta', 'poco', 'descubrimos', 'fragmentos', 'tomados', 'literalmente', 'cuento', 'publicado']
# ['apu', 'revista', 'participan', 'monton', 'autores']
# ['nh', 'colaboradores', 'pensando', 'traductores', 'escritores', 'ilustradores']
# ['gente', 'afuera', 'enrique', 'vila', 'matas', 'juan', 'villoro', 'especialistas', 'gombrowicz', 'importantes', 'nivel', 'internacional', 'traducidos', 'especialmente', 'adelanto', 'clementina', 'sujanov', 'polaca', 'viene', 'aca', 'seguido', 'acaba', 'publicar', 'primera', 'biografia', 'witold', 'gombrowicz', 'mundo']
# ['aca', 'cesar', 'aira', 'noe', 'jitrik', 'hernan', 'ronsino', 'german', 'garcia', 'ricardo', 'bartis']
# ['monton', 'personas', 'llena', 'alegria', 'encontrar']
# ['pasan', 'encontrar', 'lectores', 'gombrowicz', 'mundo', 'formando', 'lectores']
# ['paradigmatico', 'cierre', 'evento', 'cargo', 'ricardo', 'tapia', 'mississippi']
# ['secciones', 'revista', 'preguntarle', 'diferentes', 'personas', 'leyeron', 'gombrowicz']
# ['tapia', 'lector', 'explico', 'leido', 'surgio', 'cierre', 'guitarra', 'cantando', 'cancion', 'basada', 'textos', 'gombrowicz']
# ['apu', 'obra', 'gombrowicz', 'surgido', 'autores', 'obras', 'interesantisimas', 'ejemplo', 'minga', 'jorge', 'di', 'paola', 'autores', 'referenciada', 'obra', 'gombrowicz']
# ['nh', 'textos', 'interesantes', 'autora', 'polaca', 'eva', 'kovietzka', 'tesis', 'influencia', 'gombrowicz', 'escritores', 'locales']
# ['encontro', 'mayoria', 'escritores', 'locales', 'influencia', 've', 'risas', 'influencia', 'aparece', 'tapado']
# ['veo', 'monton', 'escritores', 'influenciados']
# ['gombrowicz', 'empezo', 'transitar', 'camino', 'iban', 'transitar', 'pienso', 'perlongher', 'aira', 'copi', 'inicio', 'literatura', 'gombrowicz', 'puig', 'mismo', 'aparece', 'gombrowicz', 'rayuela', 'citado', 'explicitamente']
# ['alla', 'autores', 'explicitamente', 'influenciados', 'interesante', 'literatura', 'gombrowicz', 'surco', 'transitamos', 'sepamos', 'no.']
# ['casa', 'dalma', 'maradona']
# ['anuncio', 'padre', 'diego', 'maradona']
# ['diez', 'facebook', 'anuncio', 'tierna', 'foto', 'dalma', 'bebe', 'brazos']
# ['joven', 'llamado', 'andres', 'caldarelli', 'llamo', 'padre', 'novia', 'pedirle', 'mano']
# ['caballeros', 'yerno']
# ['feliz', 'orgulloso', 'contarles', 'casa', 'hija', 'dalma', 'escribio', 'diego', 'red', 'social']
# ['perfil', 'dalma', 'novia', 'andres']
# ['pareja', 'igual', 'evita', 'exposicion', 'mediatica']
# ['caldarelli', 'dalma', 'noviazgo', 'exposicion', 'fiel', 'estilo']
# ['re', 'novia']
# ['tema', 'casamiento', 'jodido']
# ['divierte']
# ['convencer', 'mes', 'dalma', 'entrevista', 'programa', 'morfi']
# ['bono', 'pregunto', 'maldonado', 'comunidad', 'internacional', 'darle', 'descanso', 'presidente', 'mauricio', 'macri']
# ['cautelares', 'advertencias', 'declaraciones', 'viene', 'recibiendo', 'naciones', 'unidas', 'cidh', 'amnistia', 'internacional', 'presidente', 'mauricio', 'macri', 'interpelado', 'bono', 'lider', 'banda', 'u2']
# ['suelen', 'mandatarios', 'viene', 'estrella', 'rock', 'macri', 'recibio', 'cantante', 'sonrisas', 'intercambio', 'regalos', 'recibio', 'libro', 'poeta', 'irlandes']
# ['bono', 'obstante', 'pregunto', 'avance', 'causa', 'maldonado', 'hablo', 'sexismo', 'educacion']
# ['comentaron', 'adlateres', 'macri', 'encuentro', 'cordial']
# ['gobierno', 'difusion', 'encuentro', 'favor', 'salir', 'bono', 'conto', 'hablamos', 'santiago', 'maldonado', 'senti', 'presidente', 'tomando', 'caso', 'seriamente', 'miembro', 'amnesty', 'internacional', 'puso', 'feliz']
# ['costumbre', 'presidentes', 'recibir', 'figuras', 'internacionales', 'rock', 'vienen', 'argentina', 'caso', 'funcionarios', 'destacaron', 'existido', 'conversacion', 'previa', 'bono', 'foro', 'davos', 'interlocutores', 'jefe', 'gabinete', 'marcos', 'peña', 'secretario', 'asuntos', 'estrategicos', 'fulvio', 'pompeo']
# ['casualmente', 'funcionarios', 'acompañaron', 'macri', 'responsable', 'g20', 'natalia', 'zang']
# ['bono', 'encuentro', 'previo', 'macri', 'nueva', 'york', 'presidente', 'asistio', 'apertura', 'clinton', 'global', 'initiative']
# ['bono', 'llego', 'argentina', 'recitales', 'marco', 'gira', 'joshua', 'tree', 'world', 'tour', 'visito', 'casa', 'rosada', 'congrego', 'grupo', 'fans', 'saludarlo']
# ['cantante', 'paso', 'pasillos', 'saludando', 'empleados', 'dedos', 've']
# ['principio', 'encuentro', 'pensado', 'hablar', 'educacion', 'caso', 'santiago', 'maldonado', '–que', 'teniendo', 'repercusion', 'internacional', 'gobierno', 'gustaria–', 'colo', 'encuentro']
# ['reunion', 'macri', 'duro', 'minutos', 'cantante', 'comentario', 'formulas', 'cortesia', 'caso', 'hablamos', 'santiago', 'maldonado', 'senti', 'presidente', 'tomando', 'caso', 'seriamente', 'miembro', 'amnesty', 'internacional', 'puso', 'feliz', 'sostuvo']
# ['macri', 'publico', 'declaracion', 'twitter', 'titulo', 'adelanto', 'comunicado', 'oficial', 'encuentro', 'gobierno', 'leyeron', 'respaldo', 'bono', 'presidente', 'caso', 'maldonado']
# ['comunicado', 'indicaron', 'macri', 'explico', 'bono', 'acciones', 'llevadas', 'cabo', 'paradero', 'joven', 'tarea', 'permanente', 'colaboracion', 'gobierno', 'brindando', 'justicia', 'esclarecer', 'causa', 'investiga', 'desaparicion']
# ['privado', 'arriesgaron', 'asegurar', 'bono', 'quedo', 'conforme', 'explicaciones']
# ['hablaron', 'educacion']
# ['bono', 'tuve', 'reunion', 'presidente']
# ['digo', 'gran’', 'sentido', 'cubrimos', 'temas']
# ['hablamos', 'educacion', 'especificamente', 'educacion', 'mujeres']
# ['presidente', 'sentara', 'cabeza', 'encuentro', 'g-20', 'viene']
# ['pobreza', 'sexista', 'tomas', 'mujeres', 'serio', 'educacion', 'mujeres', 'serio', 'progresar']
# ['agradecido', 'recibieron', 'tiempo', 'jefe', 'gabinete', 'sostuvo', 'salir', 'firmar', 'autografos', 'fans', 'esperaban', 'rejas', 'rosada']
# ['comunicado', 'oficial', 'cantante', 'irlandes', 'elogio', 'compromiso', 'jefe', 'estado', 'convertir', 'educacion', 'prioridades', 'presidencia', 'argentina', 'g20', 'invito', 'proxima', 'conferencia', 'obtener', 'financiamiento', 'organizara', 'alianza', 'global', 'educacion', 'global', 'partnership', 'for', 'education', 'convocada', 'presidentes', 'francia', 'senegal', 'emmanuel', 'macron', 'macky', 'sall', 'realizara', 'dakar', 'senegal', 'febrero']
# ['macristas', 'agregaron', 'bono', 'comparo', 'macri', 'angela', 'merkel', 'alemania', 'emmanuel', 'macron', 'francia']
# ['gobierno', 'insistieron', 'buena', 'onda', 'bono', 'informaron', 'piensan', 'fundacion', 'one']
# ['bono', 'invito', 'macri', 'recitales']
# ['revancha', 'huevo', 'alimento', 'lleno', 'propiedades', 'saludables', 'huevo', 'considerado', 'alimento', 'clave', 'mujeres', 'embarazadas', 'contener', 'gramos', 'mejor', 'proteina', 'unidad']
# ['huevos', 'fuente', 'vitaminas', 'minerales', 'vitaminas', 'b2', 'd', 'folato', 'hierro', 'especialmente', 'colina', 'nutriente', 'semiesencial', 'embarazo', 'interviene', 'desarrollo', 'cerebro', 'bebe', 'gestacion']
# ['huevos', 'contienen', 'pigmentos', 'amarillos', 'tipo', 'carotenoides', 'denominados', 'luteina', 'zeaxantina', 'potentes', 'antioxidantes']
# ['publicaran', 'nuevo', 'libro', 'cincuenta', 'sombras', 'prometen', 'oscuro', 'anteriores']
# ['nuevo', 'round', 'diego', 'brancatelli', 'maria', 'eugenia', 'vidal', 'gobernadora', 'provincia', 'buenos', 'aires', 'maria', 'eugenia', 'vidal', 'panelista', 'ultra', 'kirchnerista', 'intratables', 'diego', 'brancatelli', 'estuvieron', 'nuevamente', 'cara', 'cara', 'estudios', 'america', 'protagonizaron', 'nuevo', 'round', 'luego', 'mitico', 'cruce', 'tuvieron', 'previo', 'paso']
# ['tono', 'tranquilo', 'ironias', 'chicanas', 'estuvieron', 'flor', 'piel']
# ['periodista', 'apunto', 'vidal', 'acusaciones', 'licitacion', 'polemica', 'servicio', 'penitenciario', 'incluye', 'millones', 'pesos', 'victor', 'lusardi']
# ['siguiendo', 'postura', 'brancatelli', 'pregunto', 'conocia', 'caso', 'personaje', 'acusaba', 'comprobo', 'falsas', 'referencia', 'primer', 'cruce', 'programa']
# ['conozco', 'general', 'conozco', 'proveedores', 'provincia']
# ['bueno', 'conocerlo', 'atenderlos']
# ['licitacion', 'hablas', 'firme', 'pliego', 'pocos', 'adjudicada', 'quehablar', 'irregularidades', 'licitacion', 'siquiera', 'adjudico', 'tendencioso', 'respondio', 'vidal']
# ['conozco', 'recibo', 'preocuparme', 'agrego', 'mandataria', 'bonaerense']
# ['turno', 'vidal', 'ataco', 'brancatelli', 'dichos', 'ocurrido', 'escrache', 'presidente', 'pampa']
# ['hablemos', 'agresiones', 'hablar', 'campaña', 'hablemos', 'decide', 'encantaria', 'haga', 'sostuvo', 'referente', 'cambiemos']
# ['bueno', 'podamos', 'mostrar', 'equipo', 'voz', 'cambiemos', 'candidata', 'acompañaba', 'mauricio', 'programa', 'sentencio', 'clara', 'alusion', 'cristina', 'kirchner']
# ['brancatelli', 'caldeado', 'ambiente', 'chicaneo', 'frente', 'campaña', 'candidata', 'tildo', 'tendencioso']
# ['sorprendido', 'gratamente', 'presencia', 'gobernadora', 'candidata']
# ['acompañando', 'candidatos', 'raro']
# ['frente', 'renovador', 'sergio', 'massa', 'unidad', 'ciudadana', 'cristina', 'kirchner', 'candidata', 'cumplir', 'florencio', 'randazzo', 'ironizo', 'brancatelli', 'comenzo', 'turno', 'preguntar']
# ['enaltece', 'gobernadora', 'salga', 'cara', 'candidatos']
# ['disfruten', 'aprovechen', 'mirando', 'candidatos', 'esteban', 'bullrich', 'graciela', 'ocaña', 'gladys', 'gonzalez', 'guillermo', 'montenegro', 'toti', 'flores', 'saliendo', 'maria', 'eugenia', 'frente', 'campaña']
# ['positivo', 'numeros', 'agrego', 'forma', 'provocativa']
# ['periodista', 'hablaba', 'esteban', 'bullrich', 'decia', 'silla', 'hablo', 'gladys', 'graciela']
# ['metio', 'santiago', 'moro']
# ['fernanda', 'vallejos', 'candidata', 'disparo', 'conductor', 'programa', 'referencia', 'candidata', 'kirchnerista']
# ['contestaciones', 'brancatelli', 'siguio', 'referencia', 'escrache', 'sufrio', 'presidente', 'pampa']
# ['hablar', 'pampa', 'imagino', 'estaran', 'detenidos', 'faciles', 'identificar', 'estaran', 'detenidos', 'violentos', 'atentaron', 'presidente', 'detenerlos']
# ['quieren', 'instalar', 'agresividad', 'hablar', 'realidad', 'lanzo', 'panelista']
# ['muertos', 'chocar', 'camiones', 'micro', 'santa', 'fe']
# ['matan', 'drone', 'viuda', 'blanca', 'britanica', 'reclutadora', 'isis']
# ['corte', 'confirmo', 'embargo', 'flor', 'kirchner', 'u$s', 'millones', 'desestimo', 'recurso', 'queja', 'florencia', 'kirchner', 'corte', 'suprema', 'nacion', 'embargo', 'millones', 'dolares', 'atesoraba', 'caja', 'seguridad', 'banco', 'galicia']
# ['fuentes', 'judiciales', 'informaron', 'maximo', 'tribunal', 'fundamento', 'rechazo', 'recurso', 'hija', 'presidentes', 'nestor', 'kirchner', 'cristina', 'fernandez', 'equiparable']
# ['fortuna', 'florencia', 'kirchner', 'guardo', 'caja', 'seguridad', 'pasado', 'juez', 'federal', 'julian', 'ercolini', 'marco', 'causa', 'denominada', 'hotesur']
# ['polemica', 'brasil', 'combatir', 'hambre', 'alcalde', 'propone', 'alimento', 'balanceado', 'pobres', 'alcalde', 'san', 'pablo', 'joao', 'doria', 'considerado', 'presidenciable', 'defendio', 'viernes', 'entrega', 'alimento', 'balanceado', 'productos', 'fecha', 'vencimiento', 'cercana', 'familias', 'carenciadas', 'afirmar', 'mismo', 'consumen', 'astronautas', 'misiones', 'espacio']
# ['alimento', 'desarrollado', 'cientificos', 'elaborado', 'enorme', 'cuidado', 'sometido', 'municipalidad', 'san', 'pablo', 'respaldos', 'academicos', 'cientificos']
# ['alimento', 'dura', 'mismo', 'consumen', 'astronautas', 'espacio', 'doria', 'milan', 'italia']
# ['alcalde', 'oficialista', 'partido', 'social', 'democracia', 'brasileña', 'psdb', 'aliado', 'presidente', 'michel', 'temer', 'afirmo', 'criticas', 'especialistas', 'nutricion', 'combate', 'hambre', 'personas', 'falta', 'conocimiento']
# ['nueva', 'politica', 'municipal', 'forma', 'programa', 'doria', 'instalar', 'resto', 'brasil', 'combatir', 'hambre']
# ['brasil', 'salido', 'primera', 'mapa', 'hambre', 'onu', 'elaborado', 'fao', 'luego', 'reduccion', 'subnutricion', 'ultimos']
# ['gobierno', 'municipal', 'san', 'pablo', 'ciudad', 'grande', 'america', 'sur', 'lanzo', 'plan', 'alimentos', 'objetivo', 'reducir', 'impuestos', 'supermercados', 'restaurantes', 'adhieran', 'entregar', 'alimentos', 'perecer', 'confeccion', 'alimento', 'balanceado', 'empresa', 'privada']
# ['consejo', 'regional', 'nutricionistas', 'estado', 'san', 'pablo', 'divulgo', 'comunicado', 'afirma', 'politica', 'alimento', 'balanceado', 'pobres', 'enfrenta', 'principios', 'derecho', 'humano', 'alimentacion', 'adecuada', 'guia', 'alimentaria', 'poblacion', 'brasileña', 'rectores', 'combate', 'hambre']
# ['falta', 'respeto', 'avances', 'ultimas', 'decadas', 'campo', 'seguridad', 'alimentaria', 'respecta', 'politicas', 'hambre', 'desnutricion', 'consejo', 'comunicado']
# ['apunta', 'ultimos', 'politicas', 'publicas', 'subsidios', 'l', 'aagricultura', 'familiar', 'produccon', 'adquisicion', 'alimentos', 'programas', 'transferencia', 'renta', 'vinculados', 'atencion', 'medica', 'educacion', 'niños', 'lograron', 'brasil', 'saliera', 'mapa', 'hambre', 'onu', 'elabora', 'fao']
# ['distribucion', 'alimento', 'balanceado', 'realizara', 'centros', 'comunitarios']
# ['doria', 'insistio', 'italia', 'feriado', 'brasil', 'motivo', 'octubre', 'virgen', 'aparecida', 'patrona', 'nacional']
# ['alimento', 'bueno', 'comi', 'sabores', 'ejercito', 'situaciones', 'emergencia', 'enfatizo', 'magnate', 'empresario', 'financio', 'campaña', 'descarta', 'buscar', 'lugar', 'liza', 'electoral']
# ['presidenta', 'plataforma', 'sinergia', 'rossana', 'perrotta', 'encargada', 'fabricar', 'alimento', 'balanceado', 'humanos', 'cadena', 'globo', 'alimentos', 'seran', 'procesados', 'producto', 'granulado', 'llamado', 'farinata', 'stock', 'carbohidratos', 'fibras']
# ['oposicion', 'doria', 'san', 'pablo', 'apunta', 'politica', 'alcalde', 'redujo', 'productos', 'saludables', 'merienda', 'escolar', 'instituciones', 'publicas', 'disminuyo', 'adquisicion', 'organicos', 'consumen', 'escuelas']
# ['daniel', 'bandoni', 'universidad', 'federal', 'san', 'pablo', 'unifesp', 'entregar', 'racion', 'humana', 'descontextualiza', 'acto', 'comer', 'alla', 'nutrientes']
# ['nutricionista', 'granulados', 'cuestiones', 'emergencia']
# ['doria', 'ultraliberal', 'posiciono', 'presidenciable', 'popularidad', 'baja', 'encuesta', 'datafolha']
# ['popularidad', 'empresario', 'magnate', 'asumio', 'enero', 'cayo', 'apoyo', 'respalda', 'posible', 'renuncia', 'alcaldia', 'suerte', 'ambito', 'nacional']
# ['partido', 'vicepresidente', 'psdb', 'alberto', 'goldman', 'critico', 'video', 'redes', 'sociales', 'afirmar', 'san', 'pablo', 'alcalde', 'precandidato', 'presidencia']
# ['militante', 'escracho', 'macri', 'pampa', 'recagamos', 'huevazos', 'coche', 'presidente', 'mauricio', 'macri', 'sufrio', 'escrache', 'jueves', 'grupo', 'personas', 'arrojo', 'huevos', 'vehiculo', 'trasladabaen', 'provincia', 'pampa']
# ['hombre', 'identificado', 'anibal', 'prina', 'docente', 'universitario', 'militante', 'kirchnerista', 'jacto', 'perfil', 'redes', 'sociales', 'autores']
# ['serie', 'imagenes', 'hombre', 'publico', 'facebook', 've', 'zona', 'rotonda', 'avion', 'unico', 'acceso', 'habilitado', 'permitia', 'acercarse', 'caravana', 'presidencial', 'dirigia', 'acto', 'campaña', 'ciudad', 'santa', 'rosa']
# ['esperando', 'gato', 'titulo', 'serie', 'fotos', 'alusion', 'insulto', 'tiempo', 'puso', 'moda', 'referirse', 'presidente']
# ['prina', 'dicta', 'clases', 'botanica', 'facultad', 'agronomia', 'pampa', 'celebro', 'misma', 'red', 'social', 'tirarle', 'huevos', 'auto', 'mandatario']
# ['llego', 'gente', 'grupos', 'esperaban', 'macri', 'centro', 'putearlo']
# ['recagamos', 'huevazos', 'coche', 'sostuvo', 'docente', 'responder', 'comentario']
# ['chicanas', 'pases', 'factura', 'reencuentro', 'vidal', 'brancatelli', 'gobernadora', 'intratables', 'volvio', 'intercambiar', 'acusaciones', 'periodista', 'fuerte', 'cruce', 'tuvieron', 'paso', 'chicanas', 'pases', 'factura']
# ['tercer', 'round', 'maria', 'eugenia', 'vidal', 'periodista', 'diego', 'brancatelli', 'tension', 'rispidez', 'comienzo', 'saga', 'previa', 'primarias', 'abiertas', 'simultaneas', 'obligatorias', 'paso']
# ['invitada', 'intratables', 'principales', 'candidatos', 'senadores', 'diputados', 'octubre', 'vidal', 'ciclo', 'contestando', 'preguntas', 'panelistas', 'incluidos', 'ferviente', 'defensor', 'cristina', 'kirchner']
# ['sorprendido', 'gratamente', 'presencia', 'gobernadora', 'candidata']
# ['acompañando', 'candidatos', 'raro']
# ['arranco', 'brancatelli', 'comparo', 'frente', 'renovador', 'massa']
# ['unidad', 'ciudadana', 'cristina', 'candidata', 'cumplir', 'randazzo']
# ['respuesta', 'alocucion', 'llego', 'candidato', 'senador', 'esteban', 'bullirch', 'aseguro', 'hablaban']
# ['sumo', 'conductor', 'programa', 'santiago', 'moro', 'fernanda', 'vallejos', 'primera', 'candidata', 'diputada', 'kirchnerismo', 'hablaba']
# ['brancatelli', 'siguio', 'chicanas', 'mirando', 'candidatos', 'cambiemos', 'enaltece', 'gobernadora', 'salga', 'cara', 'candidatos']
# ['disfruten', 'aprovechen', 'saliendo', 'maria', 'eugenia', 'frente', 'campaña']
# ['positivo', 'numeros']
# ['luego', 'panelista', 'metio', 'tema', 'escrache', 'presidente', 'pampa', 'hablar', 'pampa', 'imagino', 'estaran', 'detenidos', 'faciles', 'identificar']
# ['estaran', 'detenidos', 'violentos', 'atentaron', 'presidente', 'detenerlos']
# ['quieren', 'instalar', 'agresividad', 'hablar', 'realidad']
# ['bueno', 'podamos', 'mostrar', 'equipo', 'voz', 'cambiemos', 'candidata', 'acompañaba', 'mauricio', 'programa', 'respondio', 'criticas', 'presencia', 'candidatos', 'clara', 'contraposicion', 'espiritu', 'frente', 'victoria']
# ['pedido', 'hablar', 'ataque', 'presidente', 'hablemos', 'agresiones', 'hablar', 'campaña', 'hablemos', 'decide', 'encantaria', 'haga']
# ['muerte', 'video', 'topless', 'fallecio', 'imprudente', 'amigas', 'ivanna', 'boirachuk', 'natalia', 'borodina', 'llegaron', 'punta', 'cana', 'pocos', 'disfrutar', 'vacaciones']
# ['borodina', 'llevo', 'hijo']
# ['niño', 'quedo', 'hotel', 'hospedaban', 'amigas', 'decidieron', 'salir', 'recorrer', 'zona', 'auto', 'termino', 'tragedia']
# ['aprovechando', 'menor', 'jovenes', 'decidieron', 'tomar', 'alcohol', 'policia', 'sospecha', 'drogas', 'momento', 'natalia', 'quita', 'superior', 'traje', 'baño', 'saca', 'torso', 'ventana', 'auto', 'semidesnuda', 'amiga', 'conducia', 'filamaba']
# ['prestando', 'atencion', 'camino', 'conductora', 'pozo', 'agua', 'perdio', 'control', 'vehiculo']
# ['natalia', 'cayo', 'auto', 'trasladada', 'urgencia', 'centro', 'salud', 'murio', 'causa', 'heridas', 'recibidas', 'cabeza']
# ['ivanna', 'mejor', 'amiga', 'enfrenta', 'causa', 'judicial', 'conducir', 'ebria', 'involucrada', 'muerte', 'natalia']
# ['paralelamente', 'familia', 'repatriar', 'cuerpo', 'recursos', 'suficientes']
# ['unico', 'hermanos', 'cagar', 'trompadas', 'papa', 'exitoina', 'cantante', 'revivio', 'violencia', 'sufrio', 'infancia', 'conto', 'supero', 'relacion', 'papa']
# ['mira', 'video']
# ['asi', 'referente', 'musical', 'artistas', 'cantan', 'amor', 'esperanza', 'axelconto', 'vivio', 'infancia', 'violenta']
# ['entrevistado', 'veronica', 'lozano', 'musico', 'revivio', 'debio', 'pasar']
# ['casa', 'vivi', 'muchisima', 'violencia', 'hermanos', 'mama']
# ['sometida', 'podia', 'salir', 'circulo', 'vicioso']
# ['papa', 'adentro', 'persona', 'super', 'violenta', 'afuera', 'cobarde']
# ['patron', 'tipico', 'relato', 'corta', 'lozano']
# ['igualmente', 'guarde', 'rencor', 'papa', 'pasado', 'lleve', 'recorrer', 'europa', 'copa', 'davis']
# ['sostengo', 'fundamental', 'vida', 'cachetada', 'guante', 'blando', 'mejilla']
# ['golpe', 'amor', 'busca', 'trascender', 'explico', 'cantante']
# ['entrevista', 'lozano', 'frente', 'ganas', 'cagarlo', 'trompadas']
# ['axel', 'respondio', 'sinceridad', 'unico', 'hermanos']
# ['pegue', 'solucion']
# ['corte', 'suprema', 'confirmo', 'embargo', 'cuentas', 'florencia', 'kirchner', 'corte', 'suprema', 'nacion', 'desestimo', 'recurso', 'queja', 'florencia', 'kirchner', 'embargo', 'millones', 'dolares', 'atesoraba', 'caja', 'seguridad', 'banco', 'galicia']
# ['fuentes', 'judiciales', 'informaron', 'maximo', 'tribunal', 'fundamento', 'rechazo', 'recurso', 'hija', 'presidentes', 'nestor', 'kirchner', 'cristina', 'fernandez', 'dirige', 'sentencia', 'definitiva', 'equiparable']
# ['fortuna', 'florencia', 'kirchner', 'guardo', 'caja', 'seguridad', 'embargada', 'julio', 'pasado', 'juez', 'federal', 'julian', 'ercolini', 'marco', 'causa', 'denominada', 'hotesur']
# ['detuvieron', 'docente', 'adjudico', 'ataque', 'huevazos', 'macri', 'pampa', 'justicia', 'ordeno', 'detencion', 'docente', 'universitario', 'responsables', 'ataque', 'huevazos', 'santa', 'rosa', 'auto', 'iba', 'presidente', 'mauricio', 'macri']
# ['anibal', 'prina', 'profesor', 'biologia', 'integra', 'agrupacion', 'kirchnerista', 'frente', 'peronista', 'barrial', 'precandidato', 'diputado', 'nacional', 'propuesta', 'saco', 'votos', 'quedo', 'afuera', 'elecciones', 'octubre']
# ['ja', 'ja', 'ja', 'llego', 'gente', 'esperaban', 'centro', 'putearlo']
# ['recagamos', 'huevazos', 'coche', 'tuiteo', 'prina']
# ['informa', 'diariotextual', 'pampa', 'juez', 'federal', 'facundo', 'cubas', 'ordeno', 'detencion', 'delito', 'intimidacion', 'publica', 'pena', 'prision']
# ['enemigo', 'principal', 'gobierno', 'neoliberal', 'macri', 'esfuerzos', 'estaran', 'destinados', 'enfrentarlo', 'frenarlo', 'publicado', 'prina', 'campaña']
# ['creer']
# ['mapa', 'calor', 'messi', 'ecuador', 'forma']
# ['redes', 'sociales', 'viralizo', 'imagen']
# ['lionel', 'messi', 'jugo', 'nivel', 'altisimo', 'ecuador']
# ['motivo', 'opta', 'detalla', 'movimiento', 'jugadores', 'campo', 'juego', 'publico', 'mapa', 'calor', 'pulga']
# ['particularidad', 'hilando', 'fino', 'formas', 'queda', 'movimientos', 'grafico', 'asemeja', 'pene', 'usuarios', 'redes', 'sociales', 'dejaron', 'pasar']
# ['conoce', 'jenny', 'personaje', 'mendocino', 'revoluciona', 'redes', 'mendocina', 'stand', 'up', 'personaje', 'polemico']
# ['hablar']
# ['jennifer', 'brittany', 'shodrigue', 'alias', 'rocha']
# ['rien', 'ocurrencias', 'totalmente', 'discriminatoria']
# ['canal', 'youtube', 'escribio', 'humorada', 'animo', 'ofender', 'contrario']
# ['idea', 'robarte', 'sonrisa', 'gustos', 'escrito']
# ['agradeceria', 'ahorren', 'comentarios', 'mala', 'vibra']
# ['besos']
# ['jenni', 'version', 'tema', 'tonta', 'jimena', 'baron']
# ['vuelvo', 'rocha', 'copa', 'vida', 'espera', 'requisan', 'pone', 'violenta', 've', 'mujer', 'canta']
# ['ocurrencias', 'verse', 'perfil', 'facebook']
# ['partido', 'cordobes', 'devolvio', '$', 'millones', 'campaña', 'encuentro', 'vecinal', 'reintegro', 'paso', '$', 'millones', 'cordoba']
# ['encuentro', 'vecinal', 'partido', 'politico', 'cordobes', 'provoco', 'impacto', 'conducta', 'deberia', 'habitual', 'devolvieron', '$', 'entregaron', 'legislativa']
# ['recibieron', '$', 'sobro', 'reintegrado', 'paso', '$']
# ['tuvieron', 'misma', 'conducta', 'reintegraron', '$']
# ['aurelio', 'garcia', 'elorrio', 'legislador', 'provincial', 'cabeza', 'lista', 'diputados', 'nacionales', 'partido', 'absolutamente', 'normal']
# ['paso', 'fuerza', 'quedo', 'quinta', 'compite', 'domingo']
# ['ministerio', 'interior', 'recibio', '$', 'impresion', 'votos', 'millones', 'boletas', 'gastaron', '$', 'regresaron', 'resto', 'fondos']
# ['domingo', 'imprimieron', 'millones', 'boletas', 'doble', 'grande', 'insumen', 'dinero']
# ['partido', 'nacio', 'fusion', 'encuentro', 'cordoba', 'union', 'vecinal', 'cordoba', 'presentaron', 'lista', 'legisladores', 'provinciales', 'ingreso', 'unicameral', 'garcia', 'elorrio']
# ['autodefinen', 'grupo', 'ciudadanos', 'cordobeses', 'ajenos', 'actividad', 'politica', 'decidimos', 'meternos', 'politica', 'cambiar', 'politica']
# ['encuentro', 'vecinal', 'tesorero', 'fernando', 'rombaldi', 'explico', 'nacion', 'logico', 'devolver', 'dinero', 'sobro', 'interior', 'entrega', 'impresion', 'boletas', 'malversacion', 'fondos']
# ['pagina', 'web', 'fuerza', 'ofrecen', 'distintas', 'opciones', 'donar', 'fondos', 'via', 'deposito', 'bancario', 'debito', 'recuerdan', 'esquema', 'posibilita', 'deducir', 'donacion', 'pagar', 'ganancias', 'hasta', 'monto', 'tributar']
# ['dudas', 'telefono', 'movil', 'tesorero', 'hablar', 'directamente']
# ['rendiciones', 'cuentas', 'exige', 'ley', 'presentacion', 'balances']
# ['poco', 'dinero', 'viene', 'afuera', 'partido', 'chico', 'epoca', 'campaña', 'acerca', 'gente', 'comparte', 'principios', 'describe', 'rombaldi']
# ['legislador', 'garcia', 'elorrio', 'presento', 'defensor', 'normas', 'antiabortos', 'plataforma', 'partido', 'remarca', 'respeto', 'excepciones', 'condicionamiento', 'dignidad', 'humano', 'comienzo', 'vida', 'concepcion', 'hasta', 'muerte', 'natural']
# ['creadores', 'fundacion', 'portal', 'belen', 'albergue', 'madres', 'solteras']
# ['legislador', 'denunciante', 'activo', 'bandas', 'narcotrafico', 'puntos', 'venta', 'cocinas', 'droga', 'cordoba', 'presento', 'justicia', 'policia', 'antinarcoticos', 'cordobesa', 'lista', 'cabecillas', '-segun', 'datos-', 'manejan', 'pasta', 'base', 'cocinas']
# ['critico', 'politica', 'provincial', 'area']
# ['legisladores', 'liliana', 'montero', 'juan', 'pablo', 'quintero', 'viene', 'denunciando', 'supuestas', 'irregularidades', 'accionar', 'odebrecht', 'cordoba', 'solicitaron', 'fiscal', 'brasileño', 'delton', 'dellagnol', 'acusacion', 'mega', 'causa', 'lava', 'jato', 'justicia', 'brasil', 'interrogue', 'alberto', 'youssef', 'personas', 'seudonimos', 'mencionadas', 'relacion', 'pagos', 'sobornos', 'obras', 'provincia']
# ['pagina12']
# ['precios', 'saltan', 'meta', 'aumento', 'promedio', 'precios', 'consumidor', 'septiembre', 'medidos', 'indec', 'ubica', 'inflacion', 'acumulada', 'nueve', 'meses', 'transcurridos']
# ['faltando', 'trimestre', 'completo', 'completar', 'quedo', 'superado', 'techo', 'rango', 'aumento', 'precios', 'gobierno', 'cambiemos', 'aspiraba', 'alcanzar', 'mandato']
# ['meta', 'inflacion', 'oficial', 'ubicaba', 'aumento', 'precios', 'punta', 'punta', 'enero', 'diciembre']
# ['supero', 'techo', 'piso', 'hasta', 'duplicarse', 'teniendo', 'incidencia', 'indices', 'noviembre', 'diciembre', 'proximos', 'subas', 'combustibles', 'electricidad', 'gas', 'gobierno', 'proyecta', 'aplicar', 'pasadas', 'elecciones', 'legislativas']
# ['pese', 'politica', 'monetaria', 'contractiva', 'banco', 'central', 'apertura', 'comercial', 'facilitar', 'oferta', 'productos', 'importados', 'politica', 'desinflacion', 'resultados', 'esperados']
# ['contrario', 'nivel', 'general', 'precios', 'retomo', 'tendencia', 'alcista', 'inicio', 'presente', 'luego', 'semestre', 'observado', 'relativo', 'aquietamiento', 'inflacion']
# ['datos', 'reflejan', 'distancia', 'postulados', 'gobierno', 'cambiemos', 'resultados', 'indice', 'general', 'precios', 'aumento', 'septiembre']
# ['rubro', 'aumento', 'mes', 'prendas', 'vestir', 'calzado']
# ['area', 'metropolitana', 'ciudad', 'autonoma', 'conurbano', 'bonaerense', 'region', 'volumen', 'consumo', 'dichos', 'productos', 'inflacion', 'rubro', 'alcanzo']
# ['rubro', 'castigados', 'nivel', 'industrial', 'caida', 'consumo', 'interno', 'impacto', 'importacion']
# ['renglon', 'textil', 'indumentaria', 'importaciones', 'ubican', 'volumen', 'niveles']
# ['calzados', 'incremento', 'oferta', 'importada', 'orden', 'marroquineria']
# ['pese', 'invasion', 'importados', 'reduccion', 'demanda', 'precios', 'internos', 'siguen', 'subiendo']
# ['industriales', 'textiles', 'niegan', 'incidencia', 'aumentos', 'estacionales', 'cambio', 'temporada', 'voceros', 'mismo', 'sector', 'señalan', 'demuestra', 'desplazamiento', 'industria', 'local', 'importacion', 'sirvio', 'bajar', 'precios', 'entran', 'productos', 'baratos', 'aumentan', 'margenes', 'comercializacion', 'beneficio', 'consumidores']
# ['achicamiento', 'demanda', 'induce', 'comercio', 'aumente', 'margenes', 'compensar', 'menor', 'cantidad', 'unidades', 'vendidas']
# ['controles', 'oficiales', 'seguimiento', 'canales', 'comercializacion']
# ['contrario', 'recientemente', 'direccion', 'aduanas', 'dependiente', 'afip', 'dispuso', 'entregue', 'informacion', 'identidad', 'importador', 'detalles', 'productos', 'ingresados', 'despacho', 'considerarlo', 'violatorio', 'secreto', 'fiscal']
# ['impide', 'industria', 'nacional', 'seguimiento', 'importaciones', 'medir', 'ejemplo', 'maniobras', 'dumping', 'precio', 'productos', 'ingresados']
# ['rubros', 'señalados', 'indec', 'aumentos', 'nivel', 'general', 'inflacion', 'septiembre', 'educacion', 'recreacion', 'cultura', 'salud']
# ['ubica', 'rubro', 'vivienda', 'agua', 'electricidad', 'gas', 'aumento', 'mes', 'principales', 'ajustes', 'tarifas', 'domiciliarias', 'postergados', 'elecciones', 'legislativas', 'proximo', 'domingo']
# ['alimentos', 'bebidas', 'ubico', 'escalon', 'aumento', 'precios', 'consumidor', 'nivel', 'general']
# ['fracaso', 'receta', 'apertura', 'contraccion', 'demanda', 'interna', 'contener', 'inflacion', 'complementa', 'consecuencias', 'ajuste', 'cambios', 'estructurales', 'favor', 'sectores', 'concentrados', 'operan', 'factores', 'alimentan', 'inflacion']
# ['fuerte', 'impacto', 'devaluacion', 'quita', 'retenciones', 'exportaciones', 'simultaneo', 'inicio', 'mandato', 'mauricio', 'macri', 'diciembre', 'provoco', 'shock', 'inflacionario', 'prolongo', 'primeros', 'meses']
# ['posteriormente', 'calma', 'inflacionaria', 'duro', 'hasta', 'ultimos', 'meses', 'mismo', 'presiones', 'sectores', 'dominantes', 'mercado', 'volvieron', 'impulsar', 'aumentos', 'recomponer', 'margenes', 'ganancias']
# ['aumentos', 'previstos', 'bimestre', 'tarifas', 'combustibles', 'proyeccion', 'inflacion', 'ubica', 'suponiendo', 'impacto', 'moderado']
# ['acuerdos', 'salariales', 'pactados', 'mitad', 'volveran', 'quedar', '–como', '2016–', 'inflacion', 'visperas', 'perspectivas', 'negociaciones', 'paritarias', 'alentadoras']
# ['procesan', 'gils', 'carbo', 'administracion', 'fraudulenta', 'procuradora', 'general', 'nacion', 'alejandra', 'gils', 'carbo', 'jefa', 'fiscales', 'quedo', 'procesada', 'administracion', 'fraudulenta', 'luego', 'juez', 'entendio', 'urdio', 'plan', 'funcionario', 'cargo', 'direccionar', 'compra', 'nuevo', 'edificio', 'procuracion', 'millones', 'pesos', 'permitir', 'intermediario', 'cobrara', 'desmedida', 'comision', 'millones', 'pesos']
# ['decision', 'firmada', 'juez', 'federal', 'julian', 'ercolini', 'embargo', 'bienes', 'gils', 'carbo', 'hasta', 'suma', 'millones', 'pesos']
# ['fallo', 'oficialismo', 'retomo', 'idea', 'impulsar', 'juicio', 'politico', 'procuradora']
# ['resolucion', 'esperaba', 'gobierno', 'forzar', 'alejamiento', 'mandato', 'vitalicio']
# ['gobierno', 'entiende', 'gils', 'carbo', 'encumbrada', 'operadora', 'kirchnerismo', 'conserva', 'fiscales', 'leales', 'impulsar', 'denuncias', 'funcionarios', 'cambiemos']
# ['gil', 'carbo', 'reacciono', 'cambio', 'anoche', 'comunicado', 'abogado', 'leon', 'arslanian', 'apelara', '-sostiene-', 'perjudicar', 'estado', 'compra', 'edificio', 'beneficio', 'señala', 'provoca', 'suspicacia', 'fallo', 'conozca', 'elecciones']
# ['gils', 'carbo', 'juez', 'proceso', 'guillermo', 'alfredo', 'bellingi', 'subdirector', 'general', 'procuracion', 'llevo', 'compra', 'juan', 'carlos', 'thill', 'medio', 'hermano', 'actuo', 'intermediario', 'inmobiliaria', 'jaureguiberry', 'asociados', 'intervino', 'operacion']
# ['poster', '°', 'temporada', 'vikings', 'adelanta', 'futuro']
# ['noviembre', 'vikingos', 'vuelven', 'accion', 'estreno', 'quinta', 'temporada']
# ['empezar', 'palpitar', 'espera', 'history', 'channel', 'presento', 'poster', 'oficial', 'serie']
# ['imagen', 'poderosa', 'ensangrentada', 'decora', 'incognita', 'llegara', 'alto']
# ['ejemplo', 'katheryn', 'winnick', 'lagertha', 'alex', 'høgh', 'andersen', 'ivar', 'boneless', 'alexander', 'ludwig', 'bjorn']
# ['espadas', 'sangre', 'miradas', 'complices', 'poster', 'primer', 'adelanto', 'espera', 'quinta', 'temporada']
# ['habra', 'alianzas', 'traiciones']
# ['llegara', 'alto', 'reinado', 'vikingo']
# ['podran', 'hijos', 'ragnar', 'mantenerse', 'unidos']
# ['recien', 'develado', 'noviembre', 'primero', 'nuevos', 'episodios', 'vea', 'luz', 'history', 'channel']
# ['amazon', 'ampliara', 'negocio', 'brasil', 'accion', 'mercadolibre', 'cayo', 'amazon', 'gigante', 'tambalear', 'paso']
# ['conocio', 'noticia', 'lider', 'e-', 'commerce', 'planea', 'ampliar', 'presencia', 'brasil', 'firma', 'argentina', 'mercadolibre', 'sintio', 'efectos']
# ['wall', 'street', 'papel', 'unicornio', 'local', 'desplomo', 'efectos', 'negativos', 'llegada', 'amazon', 'causar', 'principales', 'plazas']
# ['diario', 'brasileño', 'valor', 'llegar', 'brasil', 'amazon', 'comenzara', 'vender', 'productos', 'tecnologicos', 'vecino', 'proximas', 'semanas']
# ['expandiria', 'lista', 'volcar', 'gama', 'productos', 'servicios', 'ofrece', 'ee.uu']
# ['afectaria', 'directamente', 'proyecciones', 'ganancias', 'empresa', 'creada', 'marcos', 'galperin', 'mercado', 'obtiene', 'revenue']
# ['inversores', 'manifestaron', 'preocupacion', 'papel', 'mercadolibre', 'inicio', 'rueda', 'rojo', 'progresando', 'hasta', 'finalizar', 'desplome']
# ['principal', 'mercado', 'hasta', 'lider', 'regional', 'ventas', 'internet', 'brasil', 'plaza', 'codiciada', 'comercio', 'electronico', 'movera', 'u$s', 'millones', 'datos', 'compañia', 'procesamiento', 'pagos', 'on', 'line', 'pagbrasil']
# ['desembarco', 'grande', 'sudamerica', 'firma', 'dirigida', 'jeff', 'bezos', 'destronar', 'plataforma', 'comercio', 'electronico', 'argentina', 'jacta', 'lider', 'paises', 'opera']
# ['jugador', 'commerce', 'brasil', 'compañia', 'b2w', 'perdio', 'bolsa', 'brasileña', 'conocerse', 'noticia']
# ['primer', 'golpe', 'recibe', 'papel', 'mercado', 'libre', 'wall', 'street']
# ['poco', 'meses', 'accion', 'desplomado', 'anunciar', 'resultados', 'trimestre', 'cumplieron', 'estimaciones', 'inversores']
# ['frente', 'competencia', 'mercado', 'libre', 'iniciado', 'principios', 'politica', 'envios', 'gratuitos', 'paises', 'mexico', 'brasil']
# ['tradujo', 'caida', 'proyectada', 'ebitda', 'plazo']
# ['pese', 'reves', 'mercadolibre', 'empresas', 'cotizan', 'wall', 'street', 'forma', 'adr']
# ['contexto', 'papeles', 'frances', 'crecieron', 'u$s', 'encabezaron', 'subas']
# ['avances', 'importantes', 'registraron', 'adr', 'galicia', 'ganaron', 'finalizaron', 'u$s']
# ['accion', 'globant', 'subio', 'hasta', 'u$s', 'ternium', 'sumo']
# ['plaza', 'local', 'merval', 'volvio', 'subas', 'gano', 'rueda', 'comercial', 'plata', 'destaco']
# ['test', 'indescifrable', 'acertijo', 'obligatorio', 'ingresar', 'universidad', 'oxford', 'alice', 'sentada', 'fila', 'sombrero', 'bob', 'sentado', 'medio', 'charlie', 'sentado', 'primer', 'lugar']
# ['bob', 'sombrero', 'charlie', 'porta']
# ['charlie', 'sombreros']
# ['personajes', 'conscientes', 'reglas']
# ['escenarios', 'descubrir', 'color', 'gorro']
# ['laura', 'alonso', 'afirmo', 'mejor', 'opcion', 'gils', 'carbo', 'renunciar', 'titular', 'oficina', 'anticorrupcion', 'laura', 'alonso', 'advirtio', 'renunciar', 'mejor', 'opcion', 'tomar', 'jefa', 'fiscales', 'alejandra', 'gils', 'carbo', 'procesamiento', 'considerar', 'situacion', 'judicial', 'daño', 'justicia']
# ['procuradora', 'procesada', 'administracion', 'fraudulenta', 'compra', 'edificio', 'publico', 'alonso', 'cargo', 'zafar', 'empresario', 'vinculado', 'kirchnerismo', 'lazaro', 'baez', 'causa', 'lavado', 'dinero']
# ['alonso', 'preciso', 'llamados', 'gils', 'carbo', 'titular', 'unidad', 'informacion', 'financiera', 'uif', 'jose', 'sbatella', 'zafar', 'lazaro', 'baez', 'empleado', 'presidencial', 'existieron', 'remato', 'mejor', 'opcion', 'renunciar']
# ['responsable', 'oficina', 'anticorrupcion', 'recordo', 'diputada', 'pidio', 'juicio', 'politico', 'gils', 'carbo', 'considerar', 'pieza', 'esencial', 'impunidad', 'corruptos', 'hechos', 'demuestran']
# ['jefa', 'fiscales', 'procesada', 'corrupcion', 'daño', 'justicia', 'sentencio', 'alonso', 'mensajes', 'publicados', 'mañana', 'twitter', 'decision', 'juez', 'federal', 'julian', 'ercolini', 'procesar', 'gils', 'carbo', 'fraude', 'estado', 'raiz', 'compra', 'inmueble', 'centro', 'porteño']
# ['coro', 'macrismo', 'reclama', 'gils', 'carbo', 'deje', 'cargo', 'procuracion', 'unisono', 'macrismo', 'reclamo', 'procuradora', 'general', 'nacion', 'alejandra', 'gils', 'carbo', 'deje', 'cargo', 'procesamiento', 'supuesta', 'administracion', 'fraudulenta', 'compra', 'edificio', 'organismo']
# ['ministro', 'justicia', 'derechos', 'humanos', 'german', 'garavano', 'considero', 'logico', 'pida', 'licencia']
# ['crea', 'situacion', 'crisis', 'institucional', 'cabeza', 'debiera', 'garante', 'persecucion', 'penal', 'justicia', 'argentina', '-planteo-', 'seria', 'logico', 'pida', 'licencia', 'resuelva', 'situacion', 'judicial', 'afirmo', 'titular', 'cartera']
# ['diputado', 'nacional', 'cambiemos', 'pablo', 'tonelli', 'decision', 'ercolini', 'deja', 'funcionaria', 'borde', 'condena']
# ['corre', 'serio', 'riesgo', 'condenada']
# ['escandalo', 'increible', 'decision', 'apartarse', 'pedir', 'licencia', 'enfatizo', 'constitucionalista']
# ['juez', 'federal', 'julian', 'ercolini', 'proceso', 'causa', 'adquisicion', 'edificio', 'calle', 'peron', '$', 'millones', 'pesos', 'actuo', 'intermediario', 'medio', 'hermano', 'subdirector', 'organismo']
# ['operacion', 'cuestion', 'pagaron', '$', 'millones', 'concepto', 'comision']
# ['marco', 'tonelli', 'expediente', 'irregularidades', 'manifiestas', 'considero', 'grave', 'tratarse', 'funcionaria', 'dirige', 'cuerpo', 'fiscales']
# ['legislador', 'oficialista', 'gils', 'carbo', 'maniobras', 'igualmente', 'responsable', 'omision']
# ['oficina', 'anticorrupcion', 'laura', 'alonso', 'considero', 'mejor', 'opcion', 'renunciar']
# ['jefa', 'fiscales', 'procesada', 'corrupcion', 'daño', 'justicia', 'señalo', 'titular', 'oa', 'traves', 'twitter']
# ['diputada', 'pedi', 'juicio', 'politico', 'gils', 'carbo']
# ['pieza', 'esencial', 'impunidad', 'corruptos']
# ['hechos', 'demuestran', 'afirmo', 'alonso']
# ['turno', 'presidente', 'interbloque', 'cambiemos', 'camara', 'diputados', 'radical', 'mario', 'negri', 'reconocio', 'faltan', 'instancias', 'apelacion', 'procesamiento', 'sobran', 'motivos', 'aparte']
# ['faltan', 'instancias', 'revision', 'judicial', 'cargo', 'gils', 'carbo', 'ostenta', 'procesamiento', 'merito', 'suficiente', 'paso', 'costado']
# ['miembro', 'comision', 'bicameral', 'seguimiento', 'ministerio', 'publico', 'fiscal', 'pedire', 'presidencia', 'misma', 'solicite', 'justicia', 'auto', 'procesamiento', 'urgente', 'examinarlo', 'procuradora', 'rendir', 'cuentas', 'congreso', 'remarco', 'jefe', 'macrismo', 'camara', 'baja']
# ['negri', 'dificil', 'seguir', 'sosteniendo', 'gils', 'carbo', 'frente', 'procuracion']
# ['evidencias', 'crecen', 'dificil', 'seguir', 'sosteniendola', 'cargo', 'sentencio']
# ['ercolini', 'firmo', 'fallo', 'paginas', 'considero', 'procuradora', 'coautora', 'delito', 'administracion', 'fraudulenta', 'perjuicio', 'administracion', 'publica', 'presunto', 'direccionamiento', 'licitacion', 'compra', 'edificio', 'dicto', 'embargo', 'hasta', 'cubrir', 'suma', '$', 'millones']
# ['edificio', 'funciona', 'sede', 'principal', 'procuracion', 'despacho', 'gils', 'carbo', 'adquirido', 'empresa', 'arfinsa', 'argentina', 'financiera', 's.a', 'operacion', 'intervino', 'inmobiliaria', 'jaureguiberry', 'asesores', 's.a.', 'jaureguiberry', 'cobro', 'comision', '$', 'millones', 'suma', 'juez', 'ercolini', 'exorbitante', 'totalmente', 'inusual', 'mercado', 'inmobiliario', 'oscila', 'valor', 'propiedad']
# ['bitcoin', 'boom', 'peligro', 'colapso', 'seguro', 'convencido', 'estaremos', 'mundial']
# ['salvai', 'pedimos', 'gente', 'elija', 'seguir', 'mirando', 'futuro', 'volver', 'pasado', 'optica', 'gobierno', 'nacional', 'proximas', 'elecciones', 'legislativas', 'celebraran', 'proximo', 'octubre', 'clave']
# ['resultado', 'deseo', 'macri', 'vidal', 'significar', 'consolidacion', 'rumbo', 'politico', 'economico', 'cambiemos']
# ['contentos']
# ['entusiasmo', 'optimistas', 'federico', 'salvai', 'jefe', 'gabinete', 'gobierno', 'bonaerense', 'marco', 'coloquio', 'idea']
# ['espacios', 'positivos', 'intercambiar', 'informacion', 'perspectivas', 'futuro']
# ['agenda', 'intensa', 'proxima', 'semana', 'remarco', 'funcionario']
# ['consultado', 'nacion', 'salvai']
# ...
# ['cambiemos', 'minoria', 'sufrio', 'dictamenes', 'oposicion', 'unio', 'ambas', 'camara', 'ratificarlos']
# ['paso', 'macri', 'aplica', 'decretos', 'problemas']
# ['andres', 'ibarra', 'actor', 'protagonico', 'paritarias', 'empleados', 'publicos', 'tendra', 'silla', 'comision', 'tecnica', 'asesora', 'politica', 'salarial', 'jefatura', 'gabinete', 'secretaria', 'hacienda']
# ['comision', 'creada', 'controla', 'gasto', 'personal', 'organismos', 'publicos', 'haberes', 'acordados', 'paritarias', 'suplementos', 'adicionales']
# ['llego', 'ibarra', 'mano', 'hierro', 'personal', 'estado']
# ['titubeo', 'despedir', 'mil', 'agentes', 'impuso', 'planes', 'capacitacion', 'anuncio', 'recuperacion', 'carreras', 'administrativas', 'olvidadas']
# ['viene', 'revisara', 'recibos', 'sueldo', 'tarea', 'hasta', 'reservada', 'ministerios', 'hacienda', 'trabajo']
# ['sergio', 'massa', 'florencio', 'randazzo', 'izquierda', 'diferencian', 'cristina', 'kirchner']
# ['sauces', 'afip', 'detecto', 'inconsistencias', 'declaraciones', 'juradas', 'cristina', 'kirchner', 'hijos', 'informe', 'afip', 'detecto', 'inconsistencias', 'declaraciones', 'juradas', 'presidenta', 'hijos', 'presentado', 'juez', 'federal', 'claudio', 'bonadio', 'procesada', 'cristina', 'kirchner', 'jefa', 'asociacion', 'ilicita', 'alquiler', 'complejos', 'habitacionales', 'empresa', 'sauces', 'lazaro', 'baez', 'empresarios']
# ['sospecha', 'justicia', 'empresarios', 'alquilaron', 'inmuebles', 'suerte', 'reembolso', 'dinero', 'recibieron', 'via', 'obras', 'viales', 'licitaciones', 'kirchnerismo']
# ['informe', 'afip', 'detecto', 'dinero', 'gasto', 'ingreso', 'manos', 'presidenta', 'hijos', 'refiere', 'diferencias', 'exhorbitantes']
# ['causa', 'cristina', 'kirchner', 'embargo', 'bienes', 'millones', 'pesos', 'inhibicion', 'generla', 'bienes', 'decretada']
# ['fiscales', 'gerardo', 'pollicita', 'ignacio', 'mahiques', 'pidieron', 'embargo', 'distintos', 'bienes', 'cristina', 'kirchner', 'hijos', 'exministro', 'planificacion', 'federal', 'julio', 'vido', 'funcionarios']
# ['pedido', 'juez', 'federal', 'julian', 'ercolini', 'causa', 'defraudacion', 'obra', 'publica', 'mandataria', 'procesada', 'igual', 'empresario', 'lazaro', 'baez']
# ['alcalde', 'san', 'pablo', 'entregara', 'alimento', 'balanceado', 'familias', 'pobres', 'alcalde', 'san', 'pablo', 'joao', 'doria', 'entregara', 'familias', 'carecientes', 'alimento', 'balanceado', 'producido', 'comida', 'punto', 'vencer', 'decision', 'desato', 'polemica', 'rechazo', 'nutricionistas', 'expertos', 'politicas', 'combatir', 'hambre']
# ['decision', 'forma', 'plan', 'social', 'alimentos', 'municipalidad', 'san', 'pablo', 'acuerdo', 'empresa', 'privada', 'plataforma', 'sinergia', 'alimento', 'llegara', 'forma', 'granulados', 'poblacion', 'pobre']
# ['fabricacion', 'alimento', 'balanceado', 'responde', 'programa', 'incentivo', 'economico', 'supermercados', 'restaurantes', 'entreguen', 'cargo', 'alimentos', 'fecha', 'vencimiento', 'cercana', 'evitar', 'desperdicio', 'nueva', 'ley', 'municipal']
# ['doria', 'empresario', 'millonario', 'asumio', 'alcalde', 'enero', 'considerado', 'presidenciable', 'oficialista', 'partido', 'social', 'democracia', 'brasileña', 'psdb', 'cuya', 'dirigencia', 'enfrento', 'abiertamente', 'semana', 'raiz', 'dedicado', 'viajar', 'promocionarse', 'candidato', 'jefatura', 'estado']
# ['presidenta', 'plataforma', 'sinergia', 'rossana', 'perrotta', 'cadena', 'globo', 'alimentos', 'seran', 'procesados', 'producto', 'granulado', 'llamado', 'farinata', 'stock', 'carbohidratos', 'fibras']
# ['accion', 'forma', 'politica', 'municipal', 'erradicacion', 'hambre', 'semana', 'lanzo', 'doria', 'principales', 'aliados', 'presidente', 'brasileño', 'michel', 'temer']
# ['alcalde', 'paulista', 'descarta', 'candidato', 'presidencial']
# ['especialistas', 'situacion', 'alimento', 'balanceado', 'pobres', 'genera', 'rechazo', 'caso', 'nutricionista', 'universidad', 'estado', 'rio', 'janeiro', 'uerj', 'ana', 'carolina', 'feldenheimer', 'miembro', 'alianza', 'alimentacion', 'adecuada', 'saludable']
# ['alimentacion', 'nutriente', 'granulado']
# ['alimentos', 'saludables', 'frescos', 'buena', 'calidad', 'diferenciados']
# ['salida', 'sociedad', 'alimentar', 'poblacion', 'pobres', 'feldeheimer']
# ['oposicion', 'paulista', 'doria', 'apunta', 'politica', 'alcalde', 'redujo', 'productos', 'saludables', 'merienda', 'escolar', 'instituciones', 'publicas', 'compra', 'alimentos', 'organicos', 'consumen', 'escuelas']
# ['daniel', 'bandoni', 'universidad', 'federal', 'san', 'pablo', 'sostuvo', 'entregar', 'racion', 'humana', 'descontextualiza', 'acto', 'comer', 'alla', 'nutrientes']
# ['nutricionista', 'granulados', 'cuestiones', 'emergencia']
# ['doctora', 'alimentos', 'universidad', 'campinas', 'unicamp', 'elke', 'stedefeldt', 'politica', 'doria', 'contraria', 'iniciativa', 'nacional', 'alimentacion', 'nutricion']
# ['polemica', 'alcaldia', 'emitio', 'comunicado', 'indico', 'politica', 'elaborada', 'aprobada', 'siguiendo', 'normas', 'nacionales', 'conjunto', 'deseos', 'poblacion']
# ['doria', 'orientacion', 'politica', 'ultraliberal', 'nivel', 'popularidad', 'tendencia', 'baja', 'encuesta', 'datafolha']
# ['sentido', 'estadisticas', 'encuestadora', 'marcan', 'popularidad', 'alcalde', 'paulista', 'cayo', 'respalda', 'posible', 'renuncia', 'cargo', 'tentar', 'suerte', 'ambito', 'nacional']
# ['alberto', 'goldman', 'vicepresidente', 'psdb', 'critico', 'correligionario', 'video', 'difundido', 'redes', 'sociales', 'afirma', 'san', 'pablo', 'alcalde', 'precandidato', 'presidencia']
# ['overoles', 'cascos', 'fotos', 'gustan', 'mauricio', 'macri', 'imagenes', 'publicadas', 'casa', 'rosada', 'presidente', 'protagonista', 'muestran', 'inaugurando', 'obras']
# ['pocos', 'funcionarios', 'mariu', 'vidal', 'horacio', 'rodriguez', 'larreta', 'guillo', 'dietrich', 'repiten', 'operarios', 'overoles', 'azules', 'naranjas', 'cascos', 'amarillos', 'blancos', 'mauricio', 'macri', 'muestra', 'sonriente']
# ['discurso', 'repite', 'latiguillos', 'campaña', 'verdad', 'cambio', 'equipo', 'foco', 'puesto', 'obras']
# ['distinto', 'escenario', 'elegia', 'cristina', 'kirchner', 'hasta', 'inauguraba', 'obras', 'via', 'skype', 'dialogo', 'operarios']
# ['presidente', 'repitio', 'mecanica', 'semana', 'primera', 'videoconferencia']
# ['jujuy', 'jefe', 'gabinete', 'marcos', 'peña', 'gobernador', 'gerardo', 'morales']
# ['cascos', 'obreros', 'puestos', 'anuncio', 'comienzo', 'obras', 'parque', 'fotovoltaico', 'cauchari', 'planta', 'energia', 'solar', 'grande', 'latinoamerica']
# ['momento', 'macri', 'presidente', 'apela', 'orgullo', 'macri', 'ingeniero']
# ['cuadro', 'repite', 'ultimos', 'meses', 'semana']
# ['casos', 'semana', 'pasada', 'raid', 'contrarreloj', 'macri', 'inauguro', 'obras']
# ['mauricio', 'macri', '-"el', 'sueño', 'macri', 'separar', 'sindicatos', 'partidos', '-"que', 'gastos', 'ajustara', 'gobierno', 'macri', 'proximo', '-"prat', 'gay', 'macri', 'echo', 'ministro', 'estrella', 'septiembre', 'presidente', 'acumula', 'media', 'docena', 'ejemplos', 'sitio', 'casa', 'rosada', 'inicio', 'obras', 'viaducto', 'ferrocarril', 'mitre', 'beneficiaria', 'mil', 'usuarios', 'pasando', 'recorrida', 'instalaciones', 'central', 'termica', 'anchoris', 'lujan', 'cuyo', 'terminando', 'inauguracion', 'tramo', 'viaducto', 'puente', 'noria']
# ['traslada', 'inaugurar', 'obra', 'macri', 'obrero', 'overol', 'pa', 'fondo', 'casa', 'septiembre', 'observo', 'comienzo', 'trabajos', 'abrir', 'integrar', 'quinta', 'presidencial', 'barrio', 'olivos', 'valor', 'patrimonio', 'paisajistico', 'favorecer', 'desarrollo', 'nuevos', 'espacios', 'verdes']
# ['semana', 'proyecto', 'termina', 'macri']
# ['ventaja', 'maravilloso', 'equipo', 'decirnos', 'verdad', 'obras', 'empiezan', 'terminan', 'fechas', 'comprometidas', 'afirmo', 'presidente', 'semana', 'inauguracion', 'planta', 'depuradora', 'lomas', 'zamora', 'incorporara', 'mil', 'habitantes', 'sistema', 'cloacal']
# ['apelacion', 'gestion', 'consagra', 'discipulos', 'encuestas', 'capital', 'provincia', 'buenos', 'aires']
# ['economistas', 'apuntaron', 'bcra', 'fracaso', 'meta', 'oficial', 'inflacion', 'luego', 'indec', 'difundiera', 'dato', 'inflacion', 'septiembre', 'arrojo', 'aumento', 'respecto', 'mes', 'agosto', 'marca', 'ruptura', 'techo', 'gobierno', 'estimado', 'dialogo', 'economistas', 'analizaron', 'situacion', 'ofrecieron', 'distintas', 'perspectivas', 'cara', 'comienzo', '2018.aldo', 'abram', 'director', 'consultora', 'libertad', 'progreso', 'alerto', 'efectos', 'depreciacion', 'peso', 'bcra', 'permitio', 'mayo', 'previos', 'paso']
# ['aprender', 'central']
# ['festejan', 'suba', 'tipo', 'cambio', 'real']
# ['tarda', 'pasar', 'precios', 'ocurre', 'proceso', 'simplemente', 'coyuntural', 'destaco']
# ['asimismo', 'abram', 'analizo', 'federico', 'sturzenegger', 'cambiar', 'metas', 'mismo', 'existieran', 'cumplirlas', 'implica', 'mismo']
# ['gobierno', 'depreciacion', 'peso', 'iba', 'impacto', 'precios', 'podes', 'mirar', 'evolucion', 'indice', 'canasta', 'basica', 'ultimos', 'meses', 'darte']
# ['economista', 'afirmo', 'bcra', 'cumplio', 'objetivo', 'bajar', 'inflacion', 'llevando', 'politica', 'expansiva', 'pese', 'contractiva']
# ['rato', 'pensaba', 'pudiera', 'cumplir', 'meta']
# ['principio', 'creian', 'posible', 'volvieron', 'repetir', 'errores', 'pasado', 'lanzo']
# ['fanatico', 'metas', 'inflacion', 'central', 'prioriza', 'cuestiones', 'cumplirlas']
# ['venimos', 'contexto', 'elevada', 'inflacion', 'datos', 'certeros', 'necesitamos', 'gente', 'aprenda', 'brujula', 'comun', 'metas', 'concluyo']
# ['rodrigo', 'alvarez', 'señalo', 'dato', 'alto', 'muestra', 'gobierno', 'bcra', 'cuesta', 'perforar', 'bajar', 'inflacion', 'llevarla', 'hablar']
# ['asimismo', 'puntualizo', 'problema', 'primer', 'momento', 'metas', 'bajas', 'genero', 'expectativa', 'cumplir']
# ['remarco', 'proceso', 'desinflacion', 'desestimado', 'bcra', 'exclusiva', 'responsabilidad']
# ['maneras', 'critico', 'estrategia', 'tomada', 'hasta', 'momento', 'sostener', 'baja', 'tasa', 'interes', 'imposible']
# ['alvarez', 'gobierno', 'revisar', 'dichas', 'herramientas', 'medidas', 'tomadas', 'problema', 'serio', 'coordinacion', 'distintas', 'areas', 'inflacion', 'cruzada', 'bcra', 'interpelar', 'secretaria', 'comercio', 'energia']
# ['considero', 'aumentos', 'tarifas', 'servicios', 'publicos', 'previstos', 'elecciones', 'inflacion', 'anual', 'ubicara', 'limite', 'entorno']
# ['consultado', 'medio', 'exdiputado', 'claudio', 'lozano', 'aseguro', 'gobierno', 'erra', 'enfoque', 'toma', 'tematica']
# ['exito', 'decian', 'iba']
# ['gestion', 'terminado', 'tasa', 'inflacion', 'mensual', 'logro', 'analizo']
# ['lozano', 'sostuvo', 'inflacion', 'ningun', 'momento', 'desaceleracion', 'precios', 'momento', 'recesivo', 'atraveso', 'primeros', 'signos', 'reactivacion', 'economica', 'logico', 'precios', 'disparen']
# ['modos', 'lozano', 'expreso', 'causantes', 'salida', 'shock', 'inflacionario', 'cambiemos', 'generado', 'produjo', 'baja', 'relativa', 'termino', 'invertirse', 'primeros', 'signos', 'reactivacion', 'economica']
# ['embargo', 'especialista', 'asegura', 'repunte', 'inversion', 'productiva', 'elevados', 'niveles', 'endeudamiento']
# ['futuro', 'inmediato', 'economista', 'preve', 'inflacion', 'llegara', 'puntos', 'estipulaba', 'macrismo']
# ['hasta', 'aca', 'venimos', 'sosteniendo', 'unicamente', 'endeudamiento', 'vistas', 'presupuesto', 'pretende', 'sostenerse', 'tiempo']
# ['combinatoria', 'renta', 'financiera', 'contramano', 'inversion', 'precio', 'alimentos', 'caros', 'salario', 'real', 'barato', 'consumo', 'sector', 'industrial', 'combinacion', 'preocupante', 'alerto']
# ['afirmo', 'seguimos', 'estancados', 'problemas', 'precios', 'agravante', 'alimentos', 'servicios', 'caros', 'consecuentemente', 'salarios', 'reales', 'caida', 'nivel', 'demanda', 'sector', 'industrial']
# ['produccion', 'periodistica', 'gonzalo', 'zanotti', 'joaquin', 'rodriguez', 'freire']
# ['cristina', 'kirchner', 'volvio', 'carga', 'gobierno', 'saqueando', 'bolsillos', 'candidata', 'senadora', 'nacional', 'provincia', 'buenos', 'aires', 'unidad', 'ciudadana', 'cristina', 'kirchner', 'afirmo', 'gobierno', 'mauricio', 'macri', 'saqueando', 'bolsillos']
# ['destaco', 'papel', 'intendente', 'hurligham', 'juan', 'zabaleta', 'dejo', 'espacio', 'florencio', 'randazzo', 'apoyar', 'kirchnerismo']
# ['encabezar', 'acto', 'villa', 'tesei', 'exmandataria', 'planteo', 'cambiemos', 'saqueando', 'bolsillos', 'finanzas', 'estado', 'posibilidades', 'desarrollo', 'futuro']
# ['marco', 'cristina', 'señalo', 'cambiemos', 'meses', 'gestion', 'importo', 'petroleo', 'gobierno']
# ['aumento', 'tarifas', 'dueños', 'empresas', 'acuso']
# ['insistio', 'mandato', 'existia', 'desabastecimiento', 'energetico', 'apetito', 'voraz', 'vaciar', 'bolsillos', 'argentinos', 'empresas', 'electricidad', 'gas', 'impacto']
# ['asimismo', 'cuestiono', 'oposicion', 'pone', 'enfasis', 'tiempo', 'prensa', 'criticar', 'unidad', 'ciudadana', 'denunciar', 'pasando', 'pueblo']
# ['quiero', 'agradecerte', 'actitud', 'compañero', 'significa', 'arrepentirse', 'obtenido', 'voluntad', 'popular', 'reconocidos', 'zabaleta', 'considerar', 'necesario', 'canalizar', 'espacio', 'lugar', 'limite', 'ajuste']
# ['exmandataria', 'hablo', 'elecciones', 'presidenciales', 'necesidad', 'buscar', 'alternativa', 'modelo', 'oficialismo', 'cierren', 'encaprichen']
# ['inteligentes', 'grandeza', 'construir', 'opcion', 'diferente']
# ['aca', 'ponemos', 'cuerpo', 'alma', 'escuchando', 'gente']
# ['aca', 'dudamos', 'juntos', 'ganarle', 'macri', 'arengo', 'zabaleta']
# ['destitucion', 'gils', 'carbo', 'tema', 'central', 'gobierno', 'elecciones', 'pregunta', 'influir', 'derrota', 'kirchnerismo', 'elecciones', 'legislativas', 'frente', 'proceso', 'destitucion', 'procuradora', 'impulsa', 'ejecutivo', 'indico', 'importancia', 'eleccion', 'composicion', 'congreso', 'hasta', 'kirchnerismo', 'minoria', 'bloqueado', 'juicio']
# ['sitio', 'television', 'cartelera', 'cine', 'musica', 'moda', 'entretenimiento', 'voz', 'interior', 'infama', 'consultaron', 'barbie', 'velez', 'supuesta', 'relacion', 'empresario', 'patricio', 'silberman', 'karina', 'jelinek', 'nego', 'vinculacion', 'sentimental']
# ['verdad', 'declaraciones', 'salen', 'revista', 'dije', 'susana', 'tiempo', 'medio', 'pusieron', 'fuesen', 'actuales', 'denuncio', 'joven']
# ['consultaron', 'romance', 'armado', 'desviar', 'atencion', 'amorio', 'hijo', 'fabian', 'rodriguez', 'marido', 'madre', 'guachada', 'sinceramente']
# ['estuviera', 'saliendo', 'lucas', 'fuere', 'saliendo', 'alguien', 'casado', 'hijos', 'familia']
# ['sinceramente', 'contenta', 'alguien', 'realmente', 'momento', 'blanquearlo']
# ['ocultarlo', 'esconderlo', 'armando', 'pareja', 'locura']
# ['mira', 'video', 'aca']
# ['atacan', 'huevazos', 'mauricio', 'macri', 'pampa']
# ['harvey', 'weinstein', 'caida', 'señor', 'hollywood', 'acusaciones', 'escandalosas', 'ashley', 'juddfue', 'primeras', 'denunciar', 'demoro']
# ['llego', 'hotel', 'hospedaba', 'weinstein', 'creyendo', 'asistia', 'reunion', 'negocios']
# ['productor', 'aparecio', 'bata', 'baño', 'pidio', 'masaje', 'viera', 'ducharse']
# ['gwyneth', 'paltrow', 'tenia', 'harvey', 'weinstein', 'manoseo', 'suite', 'hotel', 'beverly', 'hills']
# ['angelina', 'jolie', 'conto', 'avanzo', 'habitacion', 'hotel', 'rechazo']
# ['lucia', 'evansdijo', 'llegar', 'casting', 'weinstein', 'ataco', 'sexualmente', 'obligo', 'practicarle', 'sexo', 'oral']
# ['ambra', 'battilana', 'gutierrez', 'finalista', 'miss', 'italia', 'conto', 'weinstein', 'lanzo', 'toco', 'pechos', 'trato', 'meter', 'mano', 'minifalda']
# ['cara', 'delevingne', 'asegura', 'weinstein', 'pidio', 'trio']
# ['lea', 'seydoux', 'avalanzo', 'intento', 'besarla']
# ['katherine', 'kendallacompaño', 'productor', 'casa', 'llegaron', 'weinstein', 'desvistio', 'persiguio', 'desnudo', 'casa']
# ['asia', 'argentodenuncio', 'weinstein', 'quito', 'falda', 'forzo', 'practicar', 'sexo', 'oral']
# ['mira', 'sorvino', 'intento', 'sobrepasarse', 'actriz', 'rechazo']
# ['rosanna', 'arquette', 'conto', 'nego', 'masturbarlo']
# CPU times: user 781 ms, sys: 56.6 ms, total: 837 ms
# Wall time: 772 ms

# %% [markdown]
# We can see that gensim has picked up some composite __phrases__ that we __expected__ such as *mauricio_macri*, *policia_federal*, *codigo_penal* etc. and some __unexpected__ ones such as *acusado_cometer*, *universitario_anibal* etc. With a correct lemmatization this process is far more accurate because inflections in the words account for a larger number of tokens and the co-occurrence model produces more __false positives__. Still, adjusting the threshold to *170* has somewhat mitigated the false processing, producing a functional text.
#
# At this point this step is replicated another time, to join three word tokens (second-order phrase modeling). For example if the first pass has joined words like *new* and *york*, producing *new_york*, with a second pass we would expect to join *new_york* and *city*, getting *new_york_city*.

# %%
# %%time
#Supress useless warning
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    
    #Creates iterable of sentences from our two-word token dataset
    bigram_sents = LineSentence('data/bigram_sents.txt')

    #Initialize the model with our dataset
    trigram_model = Phrases(bigram_sents, threshold=500)

    #Save and load trained model in data directory (optional)
    trigram_model.save('data/trigram_model')
    trigram_model = Phrases.load('data/trigram_model')
    
    #Write processed sentences to the new file
    with codecs.open('data/trigram_sents.txt','w',encoding='utf-8') as f:
        for sent in bigram_sents:
            trigram_sentence = u' '.join(trigram_model[sent])
            f.write(trigram_sentence + '\n')
# Out:
# CPU times: user 329 ms, sys: 611 µs, total: 330 ms
# Wall time: 327 ms

# %% [markdown]
# This is actually really useful in our case, because in Argentina people usually have either a middle name or two last names, and in these cases we are left with a one-word token! For example you see appearing in our corpus words such as *maría_eugenia_vidal* and *alejandra_gils_carbó*. Notice that I chose a higher threshold, *400*, to reduce the number of false positives.
#
# Our corpus is actually ready for topic modeling, but before proceding let's see how the text changed. Let's print the same post before and after text processing:

# %%
print("Before:")
with codecs.open('data/text.txt',encoding='utf-8') as f:
    print(f.read(845))
print("________________________________________________\nAfter:")
with codecs.open('data/trigram_sents.txt',encoding='utf-8') as f:
    print(f.read(1000))
# Out:
# Before:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macri para que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. El proyecto quedó rengo", contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley
# ________________________________________________
# After:
# cerro comedor cordobes macri prometido ayuda luis almadaes cordobes ytenia comedor comunitario fundacion ayudar gente situacion calle
# desesperado mayo envio mensaje redes_sociales presidente mauricio_macri ayude sostener emprendimiento
# mandatario llamo telefono julio vieron personalmente provincia
# prometio ayuda
# llego alternativa bajar persiana
# fundacion ayudo amigo alma ayudaba personas situacion calle vendieran golosinas peatonal pudieran capacitarse oficio
# almada nacionque debio cerrar fundacion puse esfuerzo cumpli comprometi
# llame presidente pedirle alfajores ayudara tratamiento adicciones asistentes sociales
# macri hagamos
# tiempos nacion mismos gente
# pateando primero meses semana pasada meses -continuo-
# puse plata bolsillo
# pedi gente
# vino presidente laburo tendrian
# almada requisitos requisitos piden salon sale $ aparte pagando provincia alojamiento muchachos municipalidad permiso venta callejera
# proyecto quedo rengo conto
# hablo telefonicamente ministra carolina stanley señalo envio asesora
# reuni concejal presidente palabra vale almada dijimos empezara
# contar
# plata positivo muchachos empece trabajo
# laburo diez sociedad pelota cancha
# visita presidencial cordobes conto presidente carancheamos pollos fuente
# luego regalo camiseta talleres nombre presidente
# embargo luego anunciar cese actividades fundacion almada emitio comunicado traves redes_sociales afirma seguira trabajando estado nacional ayudar personas situacion calle
# recibimos pedido desesperado gente ayudabamos comunicaron personas ganas involucrarse ayudar
# obliga seguirlos ayudando reevaluar estrategia explica comunicado
# ayudo amigo alma ratifica seguir trabajando estado nacional ayudar personas situacion calle cordoba
# recibimos pedido desesperado gente ayudabamos comunicaron personas ganas involucrarse ayudar
# obliga seguirlos ayudando reevaluar estrategia
# hablamos gobierno comprometieron ayudarnos
# ministerio desarrollo social nacion habian pedido requisitos transparente
# tuvimos salimos gente pudimos dimos

# %% [markdown]
# ## Training a dictionary with Gensim
# Now that our text is ready to go we can use it to build a gensim [*dictionary*](https://radimrehurek.com/gensim/corpora/dictionary.html), which, in gensim's jargon, consists in a mapping between *words* and their integer *ids*. Dictionaries created from a corpus can later be pruned according to document frequency (removing (un)common words), save/loaded from disk (via *Dictionary.save()* and *Dictionary.load()* methods), merged with other dictionary (*Dictionary.merge_with()*) etc.
#
# Dictionary keys in gensim, like in python, constitute a set, thus contain one instance of every word. There are some words that we are not interested in for topic modeling, such as too common or too uncommon words. We can remove them from our dictionary via the *Dictionary.filter_extremes()* method. After some tokens have been removed via there are gaps in the id series. Calling this *Dictionary.compactify()* method will remove these gaps and reassign integer ids.
#
# Then we call the *doc2bow()* function to parse our posts and yield a bag-of-words set. In this "casting" the sequential relationship between words is lost, but the number of occurrences of each word of the post is stored in a [vector](https://radimrehurek.com/gensim/tut1.html). We pass the bow set to the [*MmCorpus.serialize()*](https://radimrehurek.com/gensim/corpora/mmcorpus.html) function that iterates through the document stream corpus and saves the bow representation in a simple [Market Matrix](http://math.nist.gov/MatrixMarket/formats.html) format to the disk. Gensim also supports [other formats](https://radimrehurek.com/gensim/tut1.html) such as [Joachim's *SVMlight* format](http://svmlight.joachims.org/), [Blei's LDA-C](http://www.cs.columbia.edu/~blei/lda-c/) format and [GibbsLDA++](http://gibbslda.sourceforge.net/) format.
#
# We then easily load the matrix in a variable calling *MmCorpus()*, we will use this variable for topic modeling.

# %%
# %%time
from gensim.corpora import Dictionary, MmCorpus

#Set up sentence streaming
trigram_posts = LineSentence('data/trigram_sents.txt')

#Learn the dictionary by iterating over all of the posts
trigram_dictionary = Dictionary(trigram_posts)

#Get infos about our dict before filtering
print("Before filtering:")
print(trigram_dictionary)

#Filter out words that appear in less than 6 posts or more than 80% posts
trigram_dictionary.filter_extremes(no_below=1, no_above=0.8)

#Get infos about our dict after filtering
print("\nAfter filtering")
print(trigram_dictionary,'\n')

#Print tokens after filtering
#print(trigram_dictionary.token2id)

#Generate new ids 
trigram_dictionary.compactify()
   
#Save and load the finished dictionary from in data directory (optional)
trigram_dictionary.save('data/trigram_dict.dict')
trigram_dictionary = Dictionary.load('data/trigram_dict.dict')

#Read the posts and generate bag-of-words representation
corpus = [trigram_dictionary.doc2bow(post) for post in trigram_posts]

#Print post vectors
#print(corpus)

#Save the bow corpus as a matrix
MmCorpus.serialize('data/trigram_bow_corpus_all.mm',corpus)

#Load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus('data/trigram_bow_corpus_all.mm')
# Out:
# Before filtering:
# Dictionary(14209 unique tokens: ['cerro', 'comedor', 'cordobes', 'macri', 'prometido']...)
#
# After filtering
# Dictionary(14209 unique tokens: ['cerro', 'comedor', 'cordobes', 'macri', 'prometido']...)
#
# CPU times: user 470 ms, sys: 3.4 ms, total: 474 ms
# Wall time: 468 ms

# %% [markdown]
# ## Topic modeling with Gensim
# What is a topic model? Why would you want to create? Gensim's creator, Radim Rehurek, gives two reasonable answers:
# - To bring out hidden structure in the corpus, discover relationships between words and use them to describe the documents in a new and (hopefully) more semantic way.
# - To make the document representation more compact. This both improves efficiency (new representation consumes less resources) and efficacy (marginal data trends are ignored, noise-reduction).
#
# As a matter of fact, the main problem with topic modeling (and other NLP task) is that we represent documents (posts) as vector spaces of tokens, and since the __dimension__ of the document vectors is the number of tokens in the corpus vocabulary, it ends up being very __large__. Furthermore every document contains only a small fraction of all tokens in the vocabulary, thus they also tend to be very __sparse__. What we can do is create a new conceptual layer built in our model. Instead of using tokens directly in documents, we describe everything in term of topics: documents are represented as a mixture of a pre-defined number of topics, and the topics are represented as a mixture of the individual tokens in the vocabulary.
#
# Gensim provides different algorithms for training a topic model. Now that we created a corpus of documents represented as a stream of vectors we can treat it with different transformations. We are going to try all the transformations available in gensim, starting from the simpler ones and building on them, because [transformation](https://radimrehurek.com/gensim/tut2.html) can be stacked. In order we will train our corpus using:
# - [__Tf-idf__](https://radimrehurek.com/gensim/models/tfidfmodel.html) (Term frequency - inverse document frequency)
# - [__LSI__](https://radimrehurek.com/gensim/models/lsimodel.html) (Latent Semantic Indexing) aka LSA
# - [__RP__](https://radimrehurek.com/gensim/models/rpmodel.html) (Random Projections)
# - [__HDP__](https://radimrehurek.com/gensim/models/hdpmodel.html) (Hierarchical Dirichlet Process)
# - [__LDA__](https://radimrehurek.com/gensim/models/ldamodel.html) (Latent Dirichlet Allocation)

# %% [markdown]
# ### Tf-idf (Term frequency - inverse document frequency)
# [__Tf-idf__](https://radimrehurek.com/gensim/models/tfidfmodel.html) is the naivest form of training we can do. The way it works is somewhat similar to what we have already done when we created the bag-of-words, but this time the frequencies computed will be a real number:
# - __Term frequency__: Counts the number of occurencies (frequency) of each term appearing in the dictionary.
# - __Inverse document frequency__: Introduces a factor that diminishes the weight of terms that occur very frequently in the corpus and increases the weight of terms that occur rarely.
#
# In gensim transformations are standard Python objects, typically initialized by means of a training corpus. In case of tf-idf, the "training" consists simply of going through the supplied corpus once and computing document frequencies of all its items, increasing the value of rare tokens. In this particular case, we are transforming the same corpus that we used for training, but this is only incidental. Once the transformation model has been initialized, it can be used on any vectors (provided they come from the same vector space, of course), even if they were not used in the training corpus at all.

# %%
# %%time
from gensim.models.tfidfmodel import TfidfModel

#Count the frequencies of all tokens in the corpus (training)
tfidf = TfidfModel(trigram_bow_corpus)

#Save and load trained tf-idf corpus
tfidf.save('data/trainedcorpus.tfidf_model')
tfidf = tfidf.load('data/trainedcorpus.tfidf_model')

#Transform our corpus using trained corpus
#print(tfidf)
corpus_tfidf = tfidf[trigram_bow_corpus]
#for doc in corpus_tfidf:
#    print(doc)
# Out:
# CPU times: user 242 ms, sys: 6.61 ms, total: 249 ms
# Wall time: 358 ms

# %% [markdown]
# So we see *tf-idf* has correctly parsed our corpus, transforming from a bag-of-words __integer__ frequency representation to a tf-idf __real-valued__ frequency weighted matrix, increasing the frequency of rare tokens.
#
# We can now use this new *corpus_tfidf* to train other topic mining algorithms instead of the simpler bag-of-words representation.

# %% [markdown]
# ### LSI (Latent Semantic Indexing)
# [__LSI__](https://radimrehurek.com/gensim/models/lsimodel.html) transforms our corpus from Tf-Idf weighted space into a latent space of a lower dimensionality. The "latency" is supposed to represent a hidden connection between words (topics, indeed) and can be set at runtime via the *num_topics* parameter. We also turn *onepass* parameter off to force a multi-pass stochastic algorithm and increase *power_iters* and *extra_samples* that represent the number of power iterations  and an oversampling factor respectively, to improve accuracy.

# %%
# %%time
from gensim.models.lsimodel import LsiModel

#Train our corpus with lsi
lsi = LsiModel(corpus_tfidf,id2word=trigram_dictionary,num_topics=15,onepass=False,power_iters=100)#extra_samples=100)

#Save and load the finished LDA model from disk
lsi.save('data/lsi_model')
lsi = LsiModel.load('data/lsi_model')

# Accept a user-supplied topic number and print out a formatted list of the top terms
def explore_topic(topic_number, topn=25):
    print ('\n' + '{:20} {}'.format('term','frequency'))
    for term, frequency in lsi.show_topic(topic_number, topn=15):
        print ('{:20} {:.3f}'.format(term,round(frequency, 3)))
print(trigram_dictionary)
explore_topic(topic_number=0)
explore_topic(topic_number=1)
explore_topic(topic_number=2)
explore_topic(topic_number=3)
explore_topic(topic_number=4)
explore_topic(topic_number=5)
explore_topic(topic_number=6)
explore_topic(topic_number=7)
explore_topic(topic_number=8)
explore_topic(topic_number=9)
explore_topic(topic_number=10)
explore_topic(topic_number=11)
explore_topic(topic_number=12)
explore_topic(topic_number=13)
explore_topic(topic_number=14)
# Out:
# Dictionary(14209 unique tokens: ['cerro', 'comedor', 'cordobes', 'macri', 'prometido']...)
#
# term                 frequency
# macri                0.238
# pampa                0.200
# presidente           0.159
# huevazos             0.138
# mauricio             0.125
# gils                 0.125
# carbo                0.123
# inflacion            0.115
# huevos               0.115
# docente              0.115
# cristina             0.107
# federal              0.104
# policia              0.103
# gobierno             0.102
# santa                0.099
#
# term                 frequency
# gils                 -0.403
# carbo                -0.400
# pampa                0.199
# huevazos             0.143
# macri                0.143
# edificio             -0.141
# compra               -0.133
# procuracion          -0.124
# procuradora          -0.121
# docente              0.115
# huevos               0.115
# procesamiento        -0.111
# alejandra            -0.110
# rosa                 0.094
# licitacion           -0.088
#
# term                 frequency
# gils                 0.266
# carbo                0.264
# inflacion            -0.245
# pampa                0.169
# cristina             -0.154
# huevazos             0.126
# docente              0.125
# kirchner             -0.110
# coloquio             -0.109
# mar                  -0.105
# federal              0.100
# edificio             0.097
# huevos               0.095
# idea                 -0.095
# plata                -0.092
#
# term                 frequency
# maldonado            0.415
# bono                 0.344
# santiago             0.291
# carta                0.200
# inflacion            -0.199
# familia              0.157
# u2                   0.142
# cantante             0.115
# banda                0.093
# amnistia             0.093
# rindan               0.089
# desaparicion_forzada 0.087
# carrio               0.087
# vivo                 0.085
# sergio               0.084
#
# term                 frequency
# vivo                 -0.423
# trabajando_tengas    -0.340
# experiencia_radios_tienes -0.340
# problemas_reproduccion_audio -0.340
# favor_refresca_pagina -0.340
# transmision          -0.211
# hd                   -0.190
# mejor                -0.176
# fm                   -0.162
# queres               -0.153
# momento              -0.138
# musica               -0.134
# radio                -0.127
# maldonado            0.112
# mitre                -0.080
#
# term                 frequency
# inflacion            0.235
# vivo                 -0.202
# trabajando_tengas    0.173
# problemas_reproduccion_audio 0.173
# favor_refresca_pagina 0.173
# experiencia_radios_tienes 0.173
# florencia            -0.139
# mapuche              0.134
# pueblo               0.125
# transmision          -0.120
# vidal                -0.110
# radio                -0.102
# maldonado            0.100
# brancatelli          -0.099
# precios              0.097
#
# term                 frequency
# cristina             0.204
# kirchner             0.196
# inflacion            -0.167
# vidal                0.147
# brancatelli          0.146
# precios              -0.146
# vivo                 -0.145
# experience_please_fill_out -0.122
# have_been_receiving_large -0.122
# for_interruption_we  -0.122
# continue_with_your_youtube -0.122
# is_starting_sorry    -0.122
# form_below           -0.122
# volume_of_requests_from -0.122
# next                 -0.122
#
# term                 frequency
# is_starting_sorry    -0.298
# form_below           -0.298
# experience_please_fill_out -0.298
# continue_with_your_youtube -0.298
# your_network_to      -0.298
# volume_of_requests_from -0.298
# have_been_receiving_large -0.298
# for_interruption_we  -0.298
# next                 -0.298
# video                -0.161
# vivo                 0.090
# cristina             -0.084
# kirchner             -0.071
# transmision          0.058
# trabajando_tengas    -0.056
#
# term                 frequency
# vivo                 0.521
# transmision          0.322
# radio                0.171
# trabajando_tengas    -0.136
# experiencia_radios_tienes -0.136
# problemas_reproduccion_audio -0.136
# favor_refresca_pagina -0.136
# cristina             0.104
# pueblo               0.100
# afirmacion_aseguraron_vergüenza 0.091
# tucuman_olga_ramon   0.091
# mapuche              0.087
# docente              -0.086
# apuntar              0.085
# mejor                -0.085
#
# term                 frequency
# florencia            0.359
# kirchner             0.265
# vidal                -0.192
# brancatelli          -0.174
# peña                 0.144
# seguridad            0.113
# corte_suprema        0.113
# eugenia              -0.109
# millones             0.101
# diego                -0.097
# felipe               0.096
# intratables          -0.096
# embargo              0.096
# maria                -0.095
# desestimo_recurso_queja 0.093
#
# term                 frequency
# docente              0.214
# mapuche              -0.208
# bono                 0.176
# pueblo               -0.157
# inflacion            0.149
# ataque               0.141
# kirchnerista         0.128
# detuvieron           0.113
# florencia            -0.111
# maldonado            0.107
# carta                0.107
# peña                 -0.105
# comitiva             -0.102
# integrante           -0.096
# anibal_prina         0.095
#
# term                 frequency
# brancatelli          -0.211
# coloquio             0.184
# ley                  0.171
# empresarios          0.170
# idea                 0.168
# vidal                -0.149
# haga_respetar        0.144
# garantiza            0.138
# reforma              0.122
# macri                0.118
# eugenia              -0.116
# candidatos           -0.110
# volver               0.110
# mar                  0.103
# intratables          -0.103
#
# term                 frequency
# vuelos               0.171
# seleccion            -0.143
# gremios              0.140
# mundial              -0.140
# inflacion            -0.135
# peña                 -0.128
# messi                -0.125
# jugadores            -0.121
# incremento           0.119
# rusia                -0.116
# transporte           0.108
# pasajes              0.108
# felipe               -0.108
# aeronauticos         0.103
# semana               0.101
#
# term                 frequency
# vuelos               0.301
# gremios              0.235
# aeronauticos         0.171
# aerolineas           0.162
# salarial             0.160
# conflicto            0.129
# asambleas            0.122
# aerolineas_argentinas 0.116
# paro                 0.113
# medida               0.108
# ley                  -0.107
# ezeiza               0.103
# aires                -0.102
# aeroparque           0.100
# haga_respetar        -0.099
#
# term                 frequency
# peña                 0.186
# brancatelli          0.180
# seleccion            -0.177
# mundial              -0.158
# kirchner             -0.153
# radio                -0.148
# rusia                -0.145
# messi                -0.144
# jugadores            -0.141
# chile                -0.119
# felipe               0.114
# eugenia              0.110
# sampaoli             -0.110
# intratables          0.103
# vidal                0.097
# CPU times: user 1min 31s, sys: 31.2 s, total: 2min 3s
# Wall time: 55.1 s

# %%
# %%time
from gensim.models.ldamulticore import LdaMulticore

import pyLDAvis
import pyLDAvis.gensim
#import cPickle as pickle

#Supress useless warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    
    # workers => sets the parallelism, and should be set to your number of physical cores minus one
    lda = LdaMulticore(corpus_tfidf,num_topics=15,id2word=trigram_dictionary,workers=3, passes=100)

    #Save and load the finished LDA model from disk
    lda.save('data/lda_model_all')
    lda = LdaMulticore.load('data/lda_model_all')

# Accept a user-supplied topic number and print out a formatted list of the top terms
def explore_topic(topic_number, topn=25):
    print ('{:20} {}'.format('term','frequency') + '\n')
    for term, frequency in lda.show_topic(topic_number, topn=15):
        print ('{:20} {:.3f}'.format(term,round(frequency, 3)))
print(trigram_dictionary)
explore_topic(topic_number=0)
explore_topic(topic_number=1)
explore_topic(topic_number=2)
explore_topic(topic_number=3)
explore_topic(topic_number=4)
explore_topic(topic_number=5)
explore_topic(topic_number=6)
explore_topic(topic_number=7)
explore_topic(topic_number=8)
explore_topic(topic_number=9)
explore_topic(topic_number=10)
explore_topic(topic_number=11)
explore_topic(topic_number=12)
explore_topic(topic_number=13)
explore_topic(topic_number=14)
# Out:
# Dictionary(5840 unique tokens: ['cerro', 'comedor', 'cordobes', 'macri', 'prometido']...)
# term                 frequency
#
# coloquio             0.004
# vos                  0.004
# reforma              0.004
# idea                 0.003
# radio                0.003
# hotel                0.003
# gobierno             0.003
# google               0.003
# urtubey              0.003
# cuerpo               0.003
# mariela              0.003
# aplicaciones         0.002
# resolver             0.002
# play                 0.002
# cavallo              0.002
# term                 frequency
#
# brancatelli          0.005
# movil                0.004
# we_are_sorry_but     0.004
# vidal                0.004
# intratables          0.004
# mujeres              0.003
# eugenia              0.003
# farmacia             0.003
# hd                   0.003
# audio                0.003
# round                0.003
# santiago             0.003
# maria                0.003
# robar                0.002
# encapuchado          0.002
# term                 frequency
#
# chile                0.004
# maldonado            0.003
# carrio               0.003
# incremento           0.003
# cancer               0.003
# seleccion            0.003
# pasajes              0.003
# argentina            0.002
# sampaoli             0.002
# empresarios          0.002
# circulo_rojo         0.002
# gente                0.002
# aires                0.002
# santiago             0.002
# empresas             0.002
# term                 frequency
#
# to                   0.004
# carrio               0.004
# diario               0.004
# noticias             0.004
# crecimiento          0.004
# argentina            0.003
# fmi                  0.003
# instante             0.003
# do                   0.003
# barcelona            0.003
# tribuno              0.003
# or                   0.003
# mercado              0.003
# viene                0.003
# seleccion            0.002
# term                 frequency
#
# avanza               0.004
# cajeros_automaticos  0.003
# ypf                  0.003
# delito               0.003
# imaginario           0.003
# docente              0.003
# defensa              0.003
# juicio               0.003
# foto                 0.003
# web                  0.003
# sede                 0.002
# peronismo            0.002
# ola                  0.002
# enferma              0.002
# perra                0.002
# term                 frequency
#
# seguro_convencido_estaremos 0.006
# problemas_reproduccion_audio 0.006
# experiencia_radios_tienes 0.006
# favor_refresca_pagina 0.006
# trabajando_tengas    0.006
# momento              0.004
# mejor                0.004
# pablo                0.003
# mundial              0.003
# mujer                0.003
# queres               0.003
# kilometros           0.003
# fm                   0.003
# musica               0.003
# donante              0.003
# term                 frequency
#
# florencia            0.007
# kirchner             0.005
# peña                 0.004
# produjo              0.003
# felipe               0.003
# corte                0.003
# experience_please_fill_out 0.003
# continue_with_your_youtube 0.003
# your_network_to      0.003
# for_interruption_we  0.003
# form_below           0.003
# next                 0.003
# have_been_receiving_large 0.003
# is_starting_sorry    0.003
# volume_of_requests_from 0.003
# term                 frequency
#
# gils                 0.012
# carbo                0.012
# pagina12             0.004
# justicia             0.004
# edificio             0.004
# procuradora          0.004
# procuracion          0.004
# compra               0.004
# gobierno             0.004
# alejandra            0.003
# fiscales             0.003
# procesamiento        0.003
# cargo                0.003
# proceso              0.003
# licitacion           0.003
# term                 frequency
#
# radio                0.004
# tren                 0.004
# lomas_zamora         0.004
# dalma                0.004
# instagram            0.004
# mujer                0.003
# videos               0.003
# cristina             0.003
# an                   0.003
# it                   0.003
# casa                 0.003
# vivo                 0.003
# is                   0.003
# estacion             0.003
# cabeza               0.002
# term                 frequency
#
# perro                0.004
# sindicalismo         0.003
# verbitsky            0.003
# animales             0.003
# italia               0.002
# latorre              0.002
# natacha_jaitt        0.002
# izquierda            0.002
# diego                0.002
# florencio_randazzo   0.002
# yanina               0.002
# animal               0.002
# maria                0.002
# lista                0.002
# entrevista           0.002
# term                 frequency
#
# vivo                 0.008
# transmision          0.008
# haga_respetar        0.006
# ley                  0.005
# garantiza            0.005
# volver               0.004
# brujo_manuel         0.004
# lanata               0.004
# unico                0.004
# frases               0.003
# estreno              0.003
# +                    0.003
# viuda                0.003
# britanica            0.003
# emilio               0.003
# term                 frequency
#
# macri                0.009
# pampa                0.009
# presidente           0.007
# huevazos             0.007
# mauricio             0.005
# huevos               0.005
# rosa                 0.004
# santa                0.004
# policia              0.004
# docente              0.004
# auto                 0.004
# personas             0.004
# comitiva             0.004
# acto                 0.004
# mapuche              0.003
# term                 frequency
#
# cristina             0.003
# afip                 0.003
# kirchner             0.002
# monotributistas      0.002
# chocolate            0.002
# recetas              0.002
# celulares            0.002
# macri                0.002
# veia                 0.002
# matar                0.002
# busca                0.002
# critico              0.002
# peronismo            0.002
# siente               0.002
# barcelona            0.002
# term                 frequency
#
# inflacion            0.010
# precios              0.004
# septiembre           0.004
# gobierno             0.003
# cristina             0.003
# ciudadana            0.003
# meta                 0.003
# puntos               0.003
# vuelos               0.003
# unidad               0.003
# mes                  0.003
# semana               0.002
# meses                0.002
# presidenta           0.002
# kirchner             0.002
# term                 frequency
#
# bono                 0.010
# maldonado            0.007
# carta                0.006
# $                    0.004
# u2                   0.004
# santiago             0.004
# familia              0.004
# manifestacion        0.003
# anuncio              0.003
# san                  0.003
# cantante             0.003
# encuentro            0.003
# banda                0.003
# españa               0.002
# gendarmeria          0.002
# CPU times: user 8min 35s, sys: 1min 21s, total: 9min 57s
# Wall time: 8min 26s
