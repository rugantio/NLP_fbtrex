# %% [markdown]
# # Argentine Election Analysis

# %% [markdown]
# ## Introduction
# In this notebook I analyze a Spanish dataset set up during the [Argentine legislative election](https://en.wikipedia.org/wiki/Argentine_legislative_election,_2017) of 2017.
# This dataset contains the data of 9 facebook bots, crawled over a period of 16 days, following 45 sources.
#
# __Note__: If you haven't done it already, go through the set up in the *README* of [this repo](https://github.com/rugantio/nlp_fbtrex/).
#
# ### Roadmap
# Download dataset -> cast JSON to txt -> tokenization -> normalization -> phrase modeling -> topic mining -> burst the bubble -> word2vec algebra & predictive analysis
#
# ## Dataset
# The dataset was prepared by the [__Facebook Tracking Exposed__](https://facebook.tracking.exposed/) project and can be retrieved in a convenient JSON format from the specific GitHub [__repo__](https://github.com/tracking-exposed/experiments-data/tree/master/silver).
# There are two separate files that we'll try to breakdown:
# * __fbtrex-data-\*.json__ - Contains all impressions relative to single users
# * __semantic-entities.json__ - Contains all available metadata regarding posts
#
# The text field of every posts is enclosed in *semantic-entities.json*, while I can use *fbtrex-data-\*.json* to correlate which user has visualized this content, thus providing an easy way to investigate the Facebook filter bubble.
# Given a ready working environment, as explained is the *README* of this repo, just go ahead and download the files:

# %%
# %%bash
# #Download Argentine dataset in a data subdir
# mkdir data && cd data
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/fbtrex-data-1.json.zip
# wget https://github.com/tracking-exposed/experiments-data/raw/master/silver/semantic-entities.json.zip

# %% [markdown]
# __Note__: This commands are supposed to be executed in a bash environment, not in the notebook itself. The operation may fail due to permissions.
#
# Extract the content from the zip archive:

# %%
# %%bash
# #Extract JSON from zipped archives
# cd data
# unzip fbtrex-data-1.json.zip
# unzip semantic-entities.json.zip

# %% [markdown]
# __Note__: To try out this notebook I made a shorter version of the JSON, I highly recommend to do the same

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Now that we have the dataset in JSON format, we can use the [JSON Python library](https://docs.python.org/3/library/json.html) to decode its content and store it in a Python variable. The variable type depends on the actual content of the provided file, by [default](https://docs.python.org/3/library/json.html#json-to-py-table) a JSON object is decoded to a dict and an arrays to a list. The recommended approach for working with encoded text files, is to use the [codecs Python library](https://docs.python.org/3/library/codecs.html):

# %%
import codecs
import json

with codecs.open('data/semantic-entities.json',encoding='utf-8') as data_json:    
    data = json.load(data_json)

# %% [markdown]
# To print to stdout the content of the parsed JSON file just use [pprint](https://docs.python.org/3/library/pprint.html), the data pretty printer:

# %%
import pprint
pprint.pprint(data)

# %% [markdown]
# It's useful to check if the casting was performed correctly before proceding, the resulting decoded type can be inspected with:

# %%
print(type(data))
# Out:
# <class 'list'>

# %% [markdown]
# __Note__: If you are using Spyder IDE you can keep track of variable simply looking at the variable explorer window.
#
# So the JSON is now a list. How many entities do we have?

# %%
data_len = len(data)
print('There are {} total elements to analyze.'.format(data_len+1))
# Out:
# There are 438 total elements to analyze.

# %% [markdown]
# Let's go deeper. We decoded the JSON to a list, but what kind of list is it? What happened to JSON objects?

# %%
for i in range(data_len):
    print(type(data[i]))

# %% [markdown]
# Of course, *data* is not a simple list, it's a nested list of dictionaries! Let's print the *dict_keys*:

# %%
for i in range(data_len):
    print(data[i].keys())

# %% [markdown]
# This is interesting: in the provided dataset there are some entities that don't have a *text* field. So let's first take only the elements that have a text field and put them in a new non-nested list:

# %%
tex = []
for i in range(data_len):
    if 'text' in data[i]:
        tex.append(data[i]['text'])

# %% [markdown]
# This is better. We now have an actual working list. Again, how many entities do we have?

# %%
tex_len = len(tex)
print('There are actually {} text elements to analyze!'.format(tex_len+1))
# Out:
# There are actually 430 text elements to analyze!

# %% [markdown]
# This is good enough for now, later we can make a deeper analysis, associating each *text* key with its *id* key and its *time* key to correlate which user visualizes which entity and when.
#
# It's good practice to have a new txt file for every step in NLP processing. So let's create a new txt file populated with the *text keys* of the *tex list*, __one per line__.
#
# Since some of the text values are made of more than one paragraphs, we need to substitute linebreaks (newline character) with a space character. Some caution is needed because some paragraphs have a double linebreak.

# %%
#Swap linebreaks with a space
for i in range(tex_len):
    tex[i] = tex[i].replace('\n\n','\n')
    tex[i] = tex[i].replace('\n',' ')

#Create new txt with text keys (one per line)
with codecs.open('data/text.txt','w',encoding='utf-8') as text:
    for i in range(tex_len):
        text.write('%s\n' % tex[i])

# %% [markdown]
# To view the file and check that everything was executed as it should you don't need another editor:

# %%
#Print the first 5000 characters
with codecs.open('data/text.txt',encoding='utf-8') as text:    
    print(text.read(5000))
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. , contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo. El gobierno nos acompañ ...
# Detuvieron a un profesor universitario acusado de tirarle huevos a Macri El profesor universitario Aníbal Prina, acusado de haber tirado huevos contra la comitiva presidencial, en el marco de la visita que hizo el jueves el jefe de Estado Mauricio Macri a Santa Rosa, fue detenido este viernes por la Policía Federal. Prina fue el tercer candidato a diputado nacional por el kirchnerista Frente Peronista Barrial y quedó arrestado en la Facultad de Agronomía. El docente está acusado de cometer el delito de intimidación publica estipulado por el artículo 211 del Código Penal. En principio, Prina estuvo demorado durante dos horas en la Facultad de Agronomía, ubicada en la ruta 5, a 10 kilómetros de la capital provincial porque el juez federal Facundo Cubas dio la orden de manera telefónica pero no estaba redactado el escrito formal. Pasadas las 12, un patrullero de la Policía Federal llevó el escrito y se dispuso la detención y el traslado del docente a la sede de la fuerza, en pleno centro capitalino. Allí se organizaba una manifestación del Frente Peronista Barrial y otras organizaciones políticas para repudiar la detención. Ayer, el Presidente fue recibido por militantes peronistas que esperaron el paso de la comitiva oficial para lanzar huevos, en la zona de la "rotonda del avión", mientras que un referente mapuche fue desalojado del recinto donde se realizaba el acto y denunció que fue "golpeado" por personal de seguridad. Al pasar por el único acceso habilitado, militantes peronistas tiraron huevos al auto del presidente Macri y a otros vehículos de la delegación del gobierno nacional. Allí lo estaban esperando con carteles que preguntaban "¿Dónde está Santiago Maldonado?" y otros que afirmaban "tarifazos es igual a pobreza". - Macri: "Queremos ser la generación que vino a cambiar la historia para siempre"
# Witolda: una búsqueda por el universo Gombrowicz APU: Se han reunido para crear una revista dedicada a Witold Gombrowicz. Nicolás Hochman: El proyecto arrancó en 2013, hicimos un congreso internacional sobre Witold Gombrowicz que es un escritor polaco que estuvo acá 24 años y que tiene mucho prestigio afuera, es recontra conocido. Ganó el premio Formentor que es el premio más importante que ganó Borges y que afuera es uno de los escritores de vanguardia más importantes del siglo XX y acá, que lo tuvimos un cuarto de siglo, no, básicamente. Las acciones que venimos desarrollando con el equipo del Congerso Gombrowicz tienen que ver con dar a conocer su vida, su obra, con intentar generar nuevos lectores y con hacer que los lectores que ya tiene tengan material fresco, nuevo, que les den ganas de retomarlo. APU: Algo que tiene que ver con el formato, es una revista de un solo número, ¿por qué eso y no un libro, una compilación? NH: Venimos haciendo cosas hace tiempo. En 2014 hicimos un libro de antología de ilustraciones a partir de textos de él, el año pasado una antología con 37 artículos inéditos sobre Gombrowicz. La idea de este año era dar una vuelta de tuerca. Surge un poco como un capricho, como una especie de continuación: se cumplen 70 años de la aparición de una revista que promocionaba Ferdydurke. Esa revista se llamó Aurora, revista de la resistencia, que también fue una revista de un solo número y un amigo suyo, Virginio Piñeira que era uno de los traductores de Ferdydurke, al otro día sacó una revista que se llamó Victrola, revista de la insistencia. 70 años después venimos a hacer Witolda, revista de la Persistencia, continuando con esa línea (risas). APU: Siguiendo también con la línea de humor que tenía Witold, donde realmente es importante el humor y el delirio sobre todo en la juventud. NH: La juventud, la inmadurez, la ruptura con las formas. Gombrowicz era un gran provocador, hoy sería un gran tuitero (risas). Queríamos retomar algo de esa provocación, tanto con el formato como con los contenidos y con la revista como objeto. Es una obra de arte, tiene tres colores: negro, rosa flúor y verde flúor, es estridente aunque se puede leer perfecto, pero causa una incomodidad en el impacto incial que es algo que queríamos transmitir. APU: Pensando un poco en la relación vida/obra ¿qué aspectos destacás? NH: En Gombrowicz, vida y obra están completamente unidas, de hecho es muy difícil distinguir cuando escribe ficción, algo que pasa con cualquier escritor pero que en él es mucho más evidente. En sus novelas, cuentos y obras de teatro aparecen todo el tiempo elementos de una escritura del yo, una primera persona absolutamente verosímil que concuerda casi paso a paso con su biografía y por otro lado las cartas, sus diarios aparece

# %% [markdown]
# Data preprocessing is over, we now have a txt ready to feed our NLP modules!
# ## Language processing with SpaCy

# %% [markdown]
# Text mining tasks have become incredibly easy thanks to [spaCy](http://alpha.spacy.io/), a NLP Python module which provides:
# * Non-destructive tokenization
# * Syntax-driven sentence segmentation
# * Pre-trained word vectors
# * Part-of-speech tagging
# * Named entity recognition
# * Labelled dependency parsing
# * A built-in visualizer
#
# ...and much more, all with just one function!
#
# SpaCy also provides some already trained [models](https://alpha.spacy.io/models/) which you can use out-of-the-box to process different languages. SpaCy's core is written in pure C (via Cython), it's currently the [fastest](https://alpha.spacy.io/usage/facts-figures) parser available and makes [multithreading](https://explosion.ai/blog/multithreading-with-cython) profitable by virtue of Cython.
#
# Follow the *README* of this repo and install the Spanish language model. Now import the model, open text.txt file and store content in a single string:

# %%
# %%time 
import spacy

#Initialize SpaCy's pipeline
nlp = spacy.load('es_core_web_sm')

#Open text file and store content in a single str
with codecs.open('data/text.txt',encoding='utf-8') as text:
    full_txt = text.read()
# Out:
# CPU times: user 802 ms, sys: 400 ms, total: 1.2 s
# Wall time: 2.51 s

# %% [markdown]
# Now that we have a processing pipeline, we can call a *nlp* instance as if it were a function on a string of text. This will produce a [Doc](https://alpha.spacy.io/api/doc) object, a special container that holds all linguistic annotations of the text fed in.
#
# Let's first explore how SpaCy processes a single entity, before diving into the dataset:

# %%
# %%time
#Snip single line of text
with codecs.open('data/text.txt',encoding='utf-8') as text:
    line_txt = text.readline()

#Standard way of processing text 
doc = nlp(line_txt)
# Out:
# CPU times: user 446 ms, sys: 744 ms, total: 1.19 s
# Wall time: 601 ms

# %%
print(doc)
# Out:
# Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle. Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento. El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia. Allí, le prometió ayuda. Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana. Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio. Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo. No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales. Macri me dijo que lo hagamos.Los tiempos de Nación no son los mismos que los de la gente". "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-. Puse plata de mi bolsillo, pero no puedo más. No pedí nada para mí, era para la gente. Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".  Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera. , contó. Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.  No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'. ¿Cómo me van a contar eso? . No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo. Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos". El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”. Luego, le regaló una camiseta de Talleres con el nombre del presidente. Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle". "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado. “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba. Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar. Ello nos obliga a seguirlos ayudando y reevaluar la estrategia. Cuando hablamos con el gobierno se comprometieron a ayudarnos. El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente. Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga. Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen. Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue. Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación. Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga. Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo. El gobierno nos acompañ ...

# %% [markdown]
# Looks exactly the same! But what happened under the hood? Have a look at how [spaCy's pipeline](https://alpha.spacy.io/usage/processing-pipelines) is made:
#
# Text -> tokenizer -> tagger -> parser -> ner -> Doc
#
# Text analysis is built in from bottom-up. The *tokenizer* creates a Doc data structure, breaking the text in tokens and storing their metadata in a tensor. The *tagger* takes these tokens (and their context) and uses the information to make predictions of the part-of-speech tags. The *parser* assigns dependency labels between tokens and segments text in sentences. The *ner*, named entity recognizer, detects and labels named entities.
# ### Sentence detection and segmentation

# %%
for num, sent in enumerate(doc.sents):
    print ('Sentence {}:'.format(num + 1),sent,end='\n')
# Out:
# Sentence 1: Cerró el comedor cordobés al que Macri le había prometido ayuda Luis Almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle.
# Sentence 2: Desesperado, en mayo le envió un mensaje por redes sociales al presidente Mauricio Macripara que lo ayude a sostener el emprendimiento.
# Sentence 3: El mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia.
# Sentence 4: Allí, le prometió ayuda.
# Sentence 5: Pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana.
# Sentence 6: Su fundación "Yo Te Ayudo Amigo del Alma" ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio.
# Sentence 7: Almada dijo a La Naciónque debió cerrar la fundación: "Puse mi esfuerzo,cumplí con lo que me comprometí pero solo no puedo.
# Sentence 8: No llamé al Presidente para pedirle alfajores, sino para que nos ayudara con tratamiento de adicciones, con asistentes sociales.
# Sentence 9: Macri me dijo que lo hagamos.
# Sentence 10: Los tiempos de Nación no son los mismos que los de la gente".
# Sentence 11: "Me fueron pateando primero dos meses, después tres y la semana pasada me dijeron cuatro meses -continuó-.
# Sentence 12: Puse plata de mi bolsillo, pero no puedo más.
# Sentence 13: No pedí nada para mí, era para la gente.
# Sentence 14: Vino el Presidente; estamos haciendo un laburo donde tendrían que estar ellos".
# Sentence 15: Almada dijo que son "requisitos, y más requisitos, y nos piden un salón que sale $20.000 aparte del que estamos pagando; la Provincia nos dio alojamiento para los muchachos y la Municipalidad nos dio el permiso para la venta callejera.
# Sentence 16: , contó.
# Sentence 17: Hace unos días habló telefónicamente con la ministra Carolina Stanley y, según señaló, envió a una asesora.
# Sentence 18: No me reuní con un concejal, sino con el Presidente y para mí su palabra vale "Ahora me dicen 'Almada no le dijimos que empezara'.
# Sentence 19: ¿Cómo me van a contar eso? .
# Sentence 20: No tengo más plata, lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo.
# Sentence 21: Laburo diez horas por día para la sociedad, pero no puedo más; ahora la pelota está en la cancha de ellos".
# Sentence 22: El día de la visita presidencial, el cordobés contó: “Con el presidente carancheamos unos pollos de la fuente”.
# Sentence 23: Luego, le regaló una camiseta de Talleres con el nombre del presidente.
# Sentence 24: Sin embargo, luego de anunciar el cese de actividades de la fundación, Almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando "con el Estado Nacional" para ayudar a las personas "en situación de calle".
# Sentence 25: "Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 26: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia", explica el comunicado.
# Sentence 27: “Yo te ayudo Amigo del Alma” ratifica que va a seguir trabajando con el Estado Nacional para ayudar a personas en situación de calle en Córdoba.
# Sentence 28: Ayer recibimos el pedido desesperado de la gente a la que ayudábamos, también se comunicaron con nosotros personas con ganas de involucrarse y ayudar.
# Sentence 29: Ello nos obliga a seguirlos ayudando y reevaluar la estrategia.
# Sentence 30: Cuando hablamos con el gobierno se comprometieron a ayudarnos.
# Sentence 31: El Ministerio de Desarrollo Social de la Nación nos habían pedido algunos requisitos para que todo sea de manera transparente.
# Sentence 32: Mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos Le dimos Comida, Le dimos Trabajo y Le dimos Albergue, pero se nos hizo imposible luchar contra el flagelo de la droga.
# Sentence 33: Este flagelo esta contaminando gravemente nuestra población, principalmente a los que menos tienen.
# Sentence 34: Entendimos que no alcanza con alimentarlos, darles trabajo y la posibilidad de dormir en un albergue.
# Sentence 35: Ayer tuvimos que parar la pelota, no podemos resolver este problema desde la fundación.
# Sentence 36: Le generamos un empleo, dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga.
# Sentence 37: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo.
# Sentence 38: El gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema.
# Sentence 39: Tanto nosotros cómo el Estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer.
# Sentence 40: Entendemos, además, que el Estado debe cuidar el dinero de los argentinos.
# Sentence 41: Nosotros vimos una situación de vulnerabilidad y quisimos ayudar.
# Sentence 42: Desde el Estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie.
# Sentence 43: Por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida, que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan.
# Sentence 44: Esta gente en situación de calle, ES GENTE BUENA Y TODOS TENEMOS QUE AYUDARLOS.
# Sentence 45: ESTAN SOLOS Y DESPROTEGIDOS.
# Sentence 46: Ratificamos nuestras ganas, buscaremos la manera y cuando estén dadas todas las condiciones necesarias, en conjunto con el gobierno nacional, retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle, darles formación y trabajo para que puedan vivir dignamente.

# %% [markdown]
# ### Part-of-speech (POS) tagging and grammar analysis
# Using [Pandas](http://pandas.pydata.org/), Python Data Analysis library, we can have a clean table visualization.
# - Text: The original word text.
# - POS: The simple part-of-speech tag.
# - Tag: The detailed part-of-speech tag, with full morphology!
# - Dep: Syntactic dependency, i.e. the relation between tokens.

# %%
import pandas as pd

token_text = [token.orth_ for token in doc]
token_pos = [token.pos_ for token in doc]
token_tag = [token.tag_ for token in doc]
token_dep = [token.dep_ for token in doc]

pd.DataFrame(list(zip(token_text,token_pos,token_tag,token_dep)), columns=['Text', 'POS','Tag','Dep'])
# Out:
#             Text    POS                                                Tag  \
# 0          Cerró   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past...
# 1             el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 2        comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 3       cordobés    ADJ                                   ADJ__Number=Sing
# 4             al    ADP      ADP__AdpType=Preppron|Gender=Masc|Number=Sing
# 5            que   PRON                                 PRON__PronType=Rel
# 6          Macri  PROPN                                           PROPN___
# 7             le   PRON   PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs
# 8          había    AUX  AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|V...
# 9      prometido   VERB  VERB__Gender=Masc|Number=Sing|Tense=Past|VerbF...
# 10         ayuda   NOUN                       NOUN__Gender=Fem|Number=Sing
# 11          Luis  PROPN                                           PROPN___
# 12      Almadaes  PROPN                                           PROPN___
# 13      cordobés    ADJ                                   ADJ__Number=Plur
# 14        ytenía   VERB  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|...
# 15            un    DET  DET__Definite=Ind|Gender=Masc|Number=Sing|Pron...
# 16       comedor   NOUN                      NOUN__Gender=Masc|Number=Sing
# 17   comunitario    ADJ                       ADJ__Gender=Masc|Number=Sing
# 18             y   CONJ                                           CCONJ___
# 19           una    DET  DET__Definite=Ind|Gender=Fem|Number=Sing|PronT...
# 20     fundación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 21          para    ADP                                  ADP__AdpType=Prep
# 22        ayudar   VERB                                 VERB__VerbForm=Inf
# 23             a    ADP                                  ADP__AdpType=Prep
# 24         gente   NOUN                       NOUN__Gender=Fem|Number=Sing
# 25            en    ADP                                  ADP__AdpType=Prep
# 26     situación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 27            de    ADP                                  ADP__AdpType=Prep
# 28         calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 29             .  PUNCT                              PUNCT__PunctType=Peri
# ..           ...    ...                                                ...
# 952     gobierno   NOUN                      NOUN__Gender=Masc|Number=Sing
# 953     nacional    ADJ                                   ADJ__Number=Sing
# 954            ,  PUNCT                              PUNCT__PunctType=Comm
# 955  retomaremos   VERB  VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres...
# 956           el    DET  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 957      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 958       juntos    ADJ                       ADJ__Gender=Masc|Number=Plur
# 959         para    ADP                                  ADP__AdpType=Prep
# 960        sacar   VERB                                 VERB__VerbForm=Inf
# 961            a    ADP                                  ADP__AdpType=Prep
# 962        todas    DET           DET__Gender=Fem|Number=Plur|PronType=Ind
# 963          las    DET  DET__Definite=Def|Gender=Fem|Number=Plur|PronT...
# 964     personas   NOUN                       NOUN__Gender=Fem|Number=Plur
# 965          que   PRON                                 PRON__PronType=Rel
# 966      podamos    AUX  AUX__Mood=Sub|Number=Plur|Person=1|Tense=Pres|...
# 967           de    ADP                                  ADP__AdpType=Prep
# 968           la    DET  DET__Definite=Def|Gender=Fem|Number=Sing|PronT...
# 969        calle   NOUN                       NOUN__Gender=Fem|Number=Sing
# 970            ,  PUNCT                              PUNCT__PunctType=Comm
# 971       darles    ADJ                                   ADJ__Number=Plur
# 972    formación   NOUN                       NOUN__Gender=Fem|Number=Sing
# 973            y   CONJ                                           CCONJ___
# 974      trabajo   NOUN                      NOUN__Gender=Masc|Number=Sing
# 975         para    ADP                                  ADP__AdpType=Prep
# 976          que  SCONJ                                           SCONJ___
# 977       puedan    AUX  AUX__Mood=Sub|Number=Plur|Person=3|Tense=Pres|...
# 978        vivir   VERB                                 VERB__VerbForm=Inf
# 979   dignamente    ADV                                             ADV___
# 980            .  PUNCT                              PUNCT__PunctType=Peri
# 981           \n  SPACE
#
#         Dep
# 0      ROOT
# 1       det
# 2     nsubj
# 3      amod
# 4      case
# 5       obj
# 6     nsubj
# 7       obj
# 8       aux
# 9       acl
# 10      obj
# 11    nsubj
# 12     flat
# 13    nsubj
# 14    advcl
# 15      det
# 16      obj
# 17     amod
# 18       cc
# 19      det
# 20     conj
# 21     mark
# 22      acl
# 23     case
# 24      obj
# 25     case
# 26      obl
# 27     case
# 28     nmod
# 29    punct
# ..      ...
# 952    nmod
# 953    amod
# 954   punct
# 955   advcl
# 956     det
# 957     obj
# 958    amod
# 959    mark
# 960   advcl
# 961    case
# 962     det
# 963     det
# 964     obj
# 965     obj
# 966     acl
# 967    case
# 968     det
# 969     obj
# 970   punct
# 971    amod
# 972   appos
# 973      cc
# 974    conj
# 975    mark
# 976    mark
# 977     aux
# 978   advcl
# 979  advmod
# 980   punct
# 981
#
# [982 rows x 4 columns]

# %% [markdown]
# ### Navigating the parse tree
# SpaCy uses the terms head and child to describe the words connected by a single arc in the dependency tree. The term dep is used for the arc label, which describes the type of syntactic relation that connects the child to the head. As with other attributes, the value of .dep is a hash value. You can get the string value with .dep\_.
# - Text: The original token text.
# - Dep: The syntactic relation connecting child to head.
# - Head text: The original text of the token head.
# - Head POS: The part-of-speech tag of the token head.
# - Children: The immediate syntactic dependents of the token.

# %%
token_text = [token.text for token in doc]
token_head_pos = [token.head.pos_ for token in doc]
token_head_text = [token.head.text for token in doc]
token_dep = [token.dep_ for token in doc]
token_children = [[child for child in token.children] for token in doc]
pd.DataFrame(list(zip(token_text,token_dep,token_head_text,token_head_pos,token_children)), columns=['Text','Dep','Head text','Head POS','Children'])
# Out:
#             Text     Dep    Head text Head POS  \
# 0          Cerró    ROOT        Cerró     VERB
# 1             el     det      comedor     NOUN
# 2        comedor   nsubj        Cerró     VERB
# 3       cordobés    amod      comedor     NOUN
# 4             al    case          que     PRON
# 5            que     obj    prometido     VERB
# 6          Macri   nsubj    prometido     VERB
# 7             le     obj    prometido     VERB
# 8          había     aux    prometido     VERB
# 9      prometido     acl     cordobés      ADJ
# 10         ayuda     obj    prometido     VERB
# 11          Luis   nsubj    prometido     VERB
# 12      Almadaes    flat         Luis    PROPN
# 13      cordobés   nsubj       ytenía     VERB
# 14        ytenía   advcl        Cerró     VERB
# 15            un     det      comedor     NOUN
# 16       comedor     obj       ytenía     VERB
# 17   comunitario    amod      comedor     NOUN
# 18             y      cc    fundación     NOUN
# 19           una     det    fundación     NOUN
# 20     fundación    conj      comedor     NOUN
# 21          para    mark       ayudar     VERB
# 22        ayudar     acl    fundación     NOUN
# 23             a    case        gente     NOUN
# 24         gente     obj       ayudar     VERB
# 25            en    case    situación     NOUN
# 26     situación     obl       ayudar     VERB
# 27            de    case        calle     NOUN
# 28         calle    nmod    situación     NOUN
# 29             .   punct        Cerró     VERB
# ..           ...     ...          ...      ...
# 952     gobierno    nmod     conjunto     NOUN
# 953     nacional    amod     gobierno     NOUN
# 954            ,   punct     conjunto     NOUN
# 955  retomaremos   advcl  Ratificamos     VERB
# 956           el     det      trabajo     NOUN
# 957      trabajo     obj  retomaremos     VERB
# 958       juntos    amod      trabajo     NOUN
# 959         para    mark        sacar     VERB
# 960        sacar   advcl  retomaremos     VERB
# 961            a    case     personas     NOUN
# 962        todas     det          las      DET
# 963          las     det     personas     NOUN
# 964     personas     obj        sacar     VERB
# 965          que     obj      podamos      AUX
# 966      podamos     acl     personas     NOUN
# 967           de    case        calle     NOUN
# 968           la     det        calle     NOUN
# 969        calle     obj      podamos      AUX
# 970            ,   punct      podamos      AUX
# 971       darles    amod    formación     NOUN
# 972    formación   appos     personas     NOUN
# 973            y      cc      trabajo     NOUN
# 974      trabajo    conj    formación     NOUN
# 975         para    mark        vivir     VERB
# 976          que    mark        vivir     VERB
# 977       puedan     aux        vivir     VERB
# 978        vivir   advcl        sacar     VERB
# 979   dignamente  advmod        vivir     VERB
# 980            .   punct  Ratificamos     VERB
# 981           \n                    .    PUNCT
#
#                                  Children
# 0                    [comedor, ytenía, .]
# 1                                      []
# 2                          [el, cordobés]
# 3                             [prometido]
# 4                                      []
# 5                                    [al]
# 6                                      []
# 7                                      []
# 8                                      []
# 9    [que, Macri, le, había, ayuda, Luis]
# 10                                     []
# 11                             [Almadaes]
# 12                                     []
# 13                                     []
# 14                    [cordobés, comedor]
# 15                                     []
# 16           [un, comunitario, fundación]
# 17                                     []
# 18                                     []
# 19                                     []
# 20                       [y, una, ayudar]
# 21                                     []
# 22               [para, gente, situación]
# 23                                     []
# 24                                    [a]
# 25                                     []
# 26                            [en, calle]
# 27                                     []
# 28                                   [de]
# 29                                     []
# ..                                    ...
# 952                   [con, el, nacional]
# 953                                    []
# 954                                    []
# 955            [conjunto, trabajo, sacar]
# 956                                    []
# 957                          [el, juntos]
# 958                                    []
# 959                                    []
# 960               [para, personas, vivir]
# 961                                    []
# 962                                    []
# 963                               [todas]
# 964          [a, las, podamos, formación]
# 965                                    []
# 966                       [que, calle, ,]
# 967                                    []
# 968                                    []
# 969                              [de, la]
# 970                                    []
# 971                                    []
# 972                     [darles, trabajo]
# 973                                    []
# 974                                   [y]
# 975                                    []
# 976                                    []
# 977                                    []
# 978       [para, que, puedan, dignamente]
# 979                                    []
# 980                                  [\n]
# 981                                    []
#
# [982 rows x 5 columns]

# %% [markdown]
# ### Named entity recognition (NER)

# %%
for num, ent in enumerate(doc.ents):
    print ('Entity {}:'.format(num + 1),ent,'-', ent.label_,end='\n')
# Out:
# Entity 1: Macri - PER
# Entity 2: Luis Almadaes - PER
# Entity 3: Desesperado - LOC
# Entity 4: Mauricio Macripara - PER
# Entity 5: Allí - PER
# Entity 6: Yo Te Ayudo Amigo del Alma - MISC
# Entity 7: Almada - LOC
# Entity 8: La Naciónque - LOC
# Entity 9: Puse - PER
# Entity 10: No llamé al Presidente - MISC
# Entity 11: Macri me dijo - MISC
# Entity 12: Los tiempos de Nación - MISC
# Entity 13: Puse - PER
# Entity 14: No pedí nada para mí - MISC
# Entity 15: Vino el Presidente - PER
# Entity 16: Almada - LOC
# Entity 17: Provincia - LOC
# Entity 18: Municipalidad - LOC
# Entity 19: Hace - ORG
# Entity 20: Carolina Stanley - PER
# Entity 21: Presidente - PER
# Entity 22: Ahora - MISC
# Entity 23: Almada - LOC
# Entity 24: Cómo - MISC
# Entity 25: No tengo más plata - MISC
# Entity 26: Laburo - MISC
# Entity 27: El día de la visita presidencial - MISC
# Entity 28: Talleres - ORG
# Entity 29: Sin embargo - MISC
# Entity 30: Almada - LOC
# Entity 31: Estado Nacional - LOC
# Entity 32: Ayer - LOC
# Entity 33: Ello nos obliga a seguirlos - MISC
# Entity 34: Yo te ayudo Amigo del Alma - MISC
# Entity 35: Estado Nacional - LOC
# Entity 36: Córdoba - LOC
# Entity 37: Ayer - LOC
# Entity 38: Ello nos obliga a seguirlos - MISC
# Entity 39: Cuando hablamos con el gobierno - MISC
# Entity 40: El Ministerio de Desarrollo Social de la Nación - MISC
# Entity 41: Mientras no los tuvimos nosotros salimos por nuestra - MISC
# Entity 42: Le dimos Comida - MISC
# Entity 43: Le dimos Trabajo - MISC
# Entity 44: Le dimos Albergue - MISC
# Entity 45: Este flagelo esta contaminando gravemente nuestra población - MISC
# Entity 46: Entendimos que no alcanza con alimentarlos - MISC
# Entity 47: Ayer - LOC
# Entity 48: Le - LOC
# Entity 49: Acordamos que estos meses sirvieron para fortalecer el conocimiento compartido - MISC
# Entity 50: El gobierno nos acompaña - MISC
# Entity 51: Tanto nosotros - MISC
# Entity 52: Estado entendemos - LOC
# Entity 53: Entendemos - MISC
# Entity 54: Estado - LOC
# Entity 55: Nosotros - MISC
# Entity 56: Desde el Estado - MISC
# Entity 57: Por eso es necesario - MISC
# Entity 58: ES GENTE BUENA Y TODOS TENEMOS - MISC
# Entity 59: AYUDARLOS - LOC
# Entity 60: ESTAN SOLOS - MISC
# Entity 61: DESPROTEGIDOS - MISC
# Entity 62: Ratificamos - LOC
# Entity 63:
#  - MISC

# %% [markdown]
# ### Visualization with displaCy
# SpaCy has an integrated visualization library that can display the content in two styles: *dep* and *ent*.
# The *dep* style shows the dependency between words using arcs, the *ent* style prints out the text with colored NER labels wrapped around words.
#
# The method *.serve()* launches a local web server for visualization while the method *.render()* provides an image.
#
# __Note__: Style *dep* is not working well in Spanish because *tag* is used instead of *POS* for annotating words, but the *tag* field is much larger than *POS* thus causing overlapping.
#
# __Note2__: Style *ent* can't be viewed in Github, but in Jupyter is great.

# %%
from spacy import displacy
#displacy.serve(doc, style='dep')
options = {'distance':425, 'arrow_spacing':6}
displacy.render(doc,style='dep', jupyter=True, options=options)

# %%
#displacy.serve(doc, style='dep')
displacy.render(doc,style='ent', jupyter=True)

# %% [markdown]
# ### Text normalization: stemming, lemmatization and shape analysis
# Let's now move on to single token analysis. *Normalization* is a way of processing text that involves changing the words to make them less unique. We talk about *stemming* when we take the words and we remove the end, producing a new word that is not in the language dictionary. *Lemmatization* takes inflected words as input and tries to give the root word as output, so in some way is similar to stemming, but it produces meaningful (actually existing) words. The token *shape* is the decapitalization char mask that gets applied to the original (orthodox) token.

# %%
token_lemma = [token.lemma_ for token in doc]
token_shape = [token.shape_ for token in doc]

pd.DataFrame(list(zip(token_text, token_lemma, token_shape)),columns=['token_text', 'token_lemma', 'token_shape'])
# Out:
#       token_text  token_lemma token_shape
# 0          Cerró        cerró       Xxxxx
# 1             el           el          xx
# 2        comedor      comedor        xxxx
# 3       cordobés     cordobés        xxxx
# 4             al           al          xx
# 5            que          que         xxx
# 6          Macri        macri       Xxxxx
# 7             le           le          xx
# 8          había        había        xxxx
# 9      prometido    prometido        xxxx
# 10         ayuda        ayuda        xxxx
# 11          Luis         luis        Xxxx
# 12      Almadaes     almadaes       Xxxxx
# 13      cordobés     cordobés        xxxx
# 14        ytenía       ytenía        xxxx
# 15            un           un          xx
# 16       comedor      comedor        xxxx
# 17   comunitario  comunitario        xxxx
# 18             y            y           x
# 19           una          una         xxx
# 20     fundación    fundación        xxxx
# 21          para         para        xxxx
# 22        ayudar       ayudar        xxxx
# 23             a            a           x
# 24         gente        gente        xxxx
# 25            en           en          xx
# 26     situación    situación        xxxx
# 27            de           de          xx
# 28         calle        calle        xxxx
# 29             .            .           .
# ..           ...          ...         ...
# 952     gobierno     gobierno        xxxx
# 953     nacional     nacional        xxxx
# 954            ,            ,           ,
# 955  retomaremos  retomaremos        xxxx
# 956           el           el          xx
# 957      trabajo      trabajo        xxxx
# 958       juntos       juntos        xxxx
# 959         para         para        xxxx
# 960        sacar        sacar        xxxx
# 961            a            a           x
# 962        todas        todas        xxxx
# 963          las          las         xxx
# 964     personas     personas        xxxx
# 965          que          que         xxx
# 966      podamos      podamos        xxxx
# 967           de           de          xx
# 968           la           la          xx
# 969        calle        calle        xxxx
# 970            ,            ,           ,
# 971       darles       darles        xxxx
# 972    formación    formación        xxxx
# 973            y            y           x
# 974      trabajo      trabajo        xxxx
# 975         para         para        xxxx
# 976          que          que         xxx
# 977       puedan       puedan        xxxx
# 978        vivir        vivir        xxxx
# 979   dignamente   dignamente        xxxx
# 980            .            .           .
# 981           \n           \n          \n
#
# [982 rows x 3 columns]

# %% [markdown]
# Lemmatization is actually not supported for the Spanish language model. We still have some normalization, as seen from the shape mask applied to every word.
#
# ### Token-level entity analysis
# The standard way to access entity annotations is the *doc.ents* property, but you can also access token entity annotations using the *token.ent_iob* and *token.ent_type* attributes; *token.ent_iob* indicates whether an entity starts, continues or ends on the tag.
#
# IOB Scheme:
# - *I* - Token is *inside* an entity.
# - *O* - Token is *outside* an entity.
# - *B* - Token is the *beginning* of an entity.

# %%
token_entity_type = [token.ent_type_ for token in doc]
token_entity_iob = [token.ent_iob_ for token in doc]

pd.DataFrame(list(zip(token_text, token_entity_type, token_entity_iob)), columns=['token_text', 'entity_type', 'inside_outside_begin'])
# Out:
#       token_text entity_type inside_outside_begin
# 0          Cerró                                O
# 1             el                                O
# 2        comedor                                O
# 3       cordobés                                O
# 4             al                                O
# 5            que                                O
# 6          Macri         PER                    B
# 7             le                                O
# 8          había                                O
# 9      prometido                                O
# 10         ayuda                                O
# 11          Luis         PER                    B
# 12      Almadaes         PER                    I
# 13      cordobés                                O
# 14        ytenía                                O
# 15            un                                O
# 16       comedor                                O
# 17   comunitario                                O
# 18             y                                O
# 19           una                                O
# 20     fundación                                O
# 21          para                                O
# 22        ayudar                                O
# 23             a                                O
# 24         gente                                O
# 25            en                                O
# 26     situación                                O
# 27            de                                O
# 28         calle                                O
# 29             .                                O
# ..           ...         ...                  ...
# 952     gobierno                                O
# 953     nacional                                O
# 954            ,                                O
# 955  retomaremos                                O
# 956           el                                O
# 957      trabajo                                O
# 958       juntos                                O
# 959         para                                O
# 960        sacar                                O
# 961            a                                O
# 962        todas                                O
# 963          las                                O
# 964     personas                                O
# 965          que                                O
# 966      podamos                                O
# 967           de                                O
# 968           la                                O
# 969        calle                                O
# 970            ,                                O
# 971       darles                                O
# 972    formación                                O
# 973            y                                O
# 974      trabajo                                O
# 975         para                                O
# 976          que                                O
# 977       puedan                                O
# 978        vivir                                O
# 979   dignamente                                O
# 980            .                                O
# 981           \n        MISC                    B
#
# [982 rows x 3 columns]

# %% [markdown]
# ### Token-level attributes
# Other useful metadata is provided, such as the relative frequency of tokens, and whether or not a token matches any of these categories:
# - stopword
# - punctuation
# - whitespace
# - number
# - url
#
# and many more token [attributes](https://alpha.spacy.io/api/token#attributes)!

# %%
token_attributes = [(token.orth_,token.prob,token.is_stop,token.is_punct,token.is_space,token.like_num,token.like_url) for token in doc]

df = pd.DataFrame(token_attributes,columns=['text','log_probability','stop?','punctuation?','whitespace?','number?','url?'])

df.loc[:, 'stop?':'url?'] = (df.loc[:, 'stop?':'url?'].applymap(lambda x: u'Yes' if x else u''))
                                               
df
# Out:
#             text  log_probability stop? punctuation? whitespace? number? url?
# 0          Cerró            -20.0
# 1             el            -20.0   Yes
# 2        comedor            -20.0
# 3       cordobés            -20.0
# 4             al            -20.0   Yes
# 5            que            -20.0   Yes
# 6          Macri            -20.0
# 7             le            -20.0   Yes
# 8          había            -20.0   Yes
# 9      prometido            -20.0
# 10         ayuda            -20.0
# 11          Luis            -20.0
# 12      Almadaes            -20.0
# 13      cordobés            -20.0
# 14        ytenía            -20.0
# 15            un            -20.0   Yes
# 16       comedor            -20.0
# 17   comunitario            -20.0
# 18             y            -20.0
# 19           una            -20.0   Yes
# 20     fundación            -20.0
# 21          para            -20.0   Yes
# 22        ayudar            -20.0
# 23             a            -20.0
# 24         gente            -20.0
# 25            en            -20.0   Yes
# 26     situación            -20.0
# 27            de            -20.0   Yes
# 28         calle            -20.0
# 29             .            -20.0                Yes
# ..           ...              ...   ...          ...         ...     ...  ...
# 952     gobierno            -20.0
# 953     nacional            -20.0
# 954            ,            -20.0                Yes
# 955  retomaremos            -20.0
# 956           el            -20.0   Yes
# 957      trabajo            -20.0   Yes
# 958       juntos            -20.0
# 959         para            -20.0   Yes
# 960        sacar            -20.0
# 961            a            -20.0
# 962        todas            -20.0   Yes
# 963          las            -20.0   Yes
# 964     personas            -20.0
# 965          que            -20.0   Yes
# 966      podamos            -20.0
# 967           de            -20.0   Yes
# 968           la            -20.0   Yes
# 969        calle            -20.0
# 970            ,            -20.0                Yes
# 971       darles            -20.0
# 972    formación            -20.0
# 973            y            -20.0
# 974      trabajo            -20.0   Yes
# 975         para            -20.0   Yes
# 976          que            -20.0   Yes
# 977       puedan            -20.0
# 978        vivir            -20.0
# 979   dignamente            -20.0
# 980            .            -20.0                Yes
# 981           \n            -20.0                            Yes
#
# [982 rows x 7 columns]

# %% [markdown]
# The relative frequency is not stored in the model, but that's not important since we don't intend to rely on it anyways.
# ### Text normalization, lemmatization and sentence segmentation
# Now that we have explored all that spaCy can do for us, we can use it to parse our *text.txt* and generate a new *parsed_text.txt* that has the same text, normalized, lemmatized and segmented in sentences. I decided not to remove stop words because they can be part of composite words, as explained in the phrase modeling section of this notebook.
#
# We first define a helper function that constructs a generator to loop over the *text.txt* and yield the review one-by-one. A generator is similar to an iterator but it can be used only once because its content is generated on the fly and not stored in memory, saving precious computation.
#
# Then pass on the reviews to spaCy using the *.pipe()* method via a generator function to parse the reviews, lemmatize the text, and yield segmantized sentences. The standard way to initialize spaCy would be to call *nlp(text.txt)* on each review, but I will make use instead of the *.pipe()* method which allows efficient [multi-threading](https://spacy.io/docs/usage/processing-text#multithreading). Two [arguments](https://alpha.spacy.io/api/language#pipe) are given to *.pipe()*: *batch_size* is the number of reviews to buffer and *n_threads* which is the number of worker threads to use (default is 2, if -1 OpenMP will decide how many to use at run time, like in our case). You can also pass a *disable* option to turn off some components of the pipeline that is not needed to further optimize the processing. Note that all processing algorithms are linear-time in the length of the string.
#
# Finally, we write the sentences to a new txt file, *parsed_text.txt*.

# %%
# %%time
#Helper function that yields all reviews via generator 
def get_review(filename):
    with codecs.open(filename, encoding='utf_8') as textfile:
        for review in textfile:
            yield review
            
#Generator function to parse reviews, lemmatize the text, and yield sentences
#WARNING: This task is computationally demanding, adjust batch_size and n_threads according to your machine
def lemmatize_corpus(filename):
    for parsed_review in nlp.pipe(get_review(filename),batch_size=10, n_threads=-1):
        for sent in parsed_review.sents:
            yield u' '.join([token.lemma_ for token in sent if not (token.is_punct or token.is_space)])

with codecs.open('data/new_text.txt', 'w', encoding='utf_8') as f:
    for sent in lemmatize_corpus('data/text.txt'):
        f.write(sent + '\n')
# Out:
# CPU times: user 37.8 s, sys: 43 s, total: 1min 20s
# Wall time: 23.4 s

# %% [markdown]
# Let's see what we got out of it:

# %%
with codecs.open('data/new_text.txt',encoding='utf-8') as parsed_text:    
    print(parsed_text.read())
# Out:
# cerró el comedor cordobés al que macri le había prometido ayuda luis almadaes cordobés ytenía un comedor comunitario y una fundación para ayudar a gente en situación de calle
# desesperado en mayo le envió un mensaje por redes sociales al presidente mauricio macripara que lo ayude a sostener el emprendimiento
# el mandatario lo llamó por teléfono días después y el 12 de julio se vieron personalmente en esa provincia
# allí le prometió ayuda
# pero nunca llegó y por eso no tuvo más alternativa que bajar la persiana
# su fundación yo te ayudo amigo del alma ayudaba a unas 20 personas en situación de calle para que vendieran golosinas en la peatonal y pudieran capacitarse en un oficio
# almada dijo a la naciónque debió cerrar la fundación puse mi esfuerzo cumplí con lo que me comprometí pero solo no puedo
# no llamé al presidente para pedirle alfajores sino para que nos ayudara con tratamiento de adicciones con asistentes sociales
# macri me dijo que lo hagamos
# los tiempos de nación no son los mismos que los de la gente
# me fueron pateando primero dos meses después tres y la semana pasada me dijeron cuatro meses -continuó-
# puse plata de mi bolsillo pero no puedo más
# no pedí nada para mí era para la gente
# vino el presidente estamos haciendo un laburo donde tendrían que estar ellos
# almada dijo que son requisitos y más requisitos y nos piden un salón que sale $ 20.000 aparte del que estamos pagando la provincia nos dio alojamiento para los muchachos y la municipalidad nos dio el permiso para la venta callejera
# contó
# hace unos días habló telefónicamente con la ministra carolina stanley y según señaló envió a una asesora
# no me reuní con un concejal sino con el presidente y para mí su palabra vale ahora me dicen almada no le dijimos que empezara
# cómo me van a contar eso
# no tengo más plata lo positivo es que de los 30 muchachos con los que empecé a cuatro le conseguimos trabajo
# laburo diez horas por día para la sociedad pero no puedo más ahora la pelota está en la cancha de ellos
# el día de la visita presidencial el cordobés contó con el presidente carancheamos unos pollos de la fuente
# luego le regaló una camiseta de talleres con el nombre del presidente
# sin embargo luego de anunciar el cese de actividades de la fundación almada emitió un comunicado a través de las redes sociales en el que afirma que seguirá trabajando con el estado nacional para ayudar a las personas en situación de calle
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia explica el comunicado
# yo te ayudo amigo del alma ratifica que va a seguir trabajando con el estado nacional para ayudar a personas en situación de calle en córdoba
# ayer recibimos el pedido desesperado de la gente a la que ayudábamos también se comunicaron con nosotros personas con ganas de involucrarse y ayudar
# ello nos obliga a seguirlos ayudando y reevaluar la estrategia
# cuando hablamos con el gobierno se comprometieron a ayudarnos
# el ministerio de desarrollo social de la nación nos habían pedido algunos requisitos para que todo sea de manera transparente
# mientras no los tuvimos nosotros salimos por nuestra cuenta y a cuanta gente pudimos le dimos comida le dimos trabajo y le dimos albergue pero se nos hizo imposible luchar contra el flagelo de la droga
# este flagelo esta contaminando gravemente nuestra población principalmente a los que menos tienen
# entendimos que no alcanza con alimentarlos darles trabajo y la posibilidad de dormir en un albergue
# ayer tuvimos que parar la pelota no podemos resolver este problema desde la fundación
# le generamos un empleo dinero en su bolsillo y los terminamos dejando solos en la pelea contra la droga
# acordamos que estos meses sirvieron para fortalecer el conocimiento compartido sobre como abordar este flagelo
# el gobierno nos acompaña en esta temática para que los recursos económicos y de conocimiento que nos aporte sean bien utilizados y ayuden de verdad a la gente a salir de este problema
# tanto nosotros cómo el estado entendemos que todo esto significa un importante proceso de aprendizaje que nos servirá para continuar haciendo lo que queremos hacer
# entendemos además que el estado debe cuidar el dinero de los argentinos
# nosotros vimos una situación de vulnerabilidad y quisimos ayudar
# desde el estado se comprometieron a seguir redoblando esfuerzos para lograr concretar este sueño sin que sea perjudicial para nadie
# por eso es necesario que todos sepamos que detrás de todo esto hay historias de vida que no es fácil y que hay que tener paciencia y trabajo en equipo para ayudar a los que más lo necesitan
# esta gente en situación de calle es gente buena y todos tenemos que ayudarlos
# estan solos y desprotegidos
# ratificamos nuestras ganas buscaremos la manera y cuando estén dadas todas las condiciones necesarias en conjunto con el gobierno nacional retomaremos el trabajo juntos para sacar a todas las personas que podamos de la calle darles formación y trabajo para que puedan vivir dignamente
# detuvieron a un profesor universitario acusado de tirarle huevos a macri el profesor universitario aníbal prina acusado de haber tirado huevos contra la comitiva presidencial en el marco de la visita que hizo el jueves el jefe de estado mauricio macri a santa rosa fue detenido este viernes por la policía federal
# prina fue el tercer candidato a diputado nacional por el kirchnerista frente peronista barrial y quedó arrestado en la facultad de agronomía
# el docente está acusado de cometer el delito de intimidación publica estipulado por el artículo 211 del código penal
# en principio prina estuvo demorado durante dos horas en la facultad de agronomía ubicada en la ruta 5 a 10 kilómetros de la capital provincial porque el juez federal facundo cubas dio la orden de manera telefónica pero no estaba redactado el escrito formal
# pasadas las 12 un patrullero de la policía federal llevó el escrito y se dispuso la detención y el traslado del docente a la sede de la fuerza en pleno centro capitalino
# allí se organizaba una manifestación del frente peronista barrial y otras organizaciones políticas para repudiar la detención
# ayer el presidente fue recibido por militantes peronistas que esperaron el paso de la comitiva oficial para lanzar huevos en la zona de la rotonda del avión mientras que un referente mapuche fue desalojado del recinto donde se realizaba el acto y denunció que fue golpeado por personal de seguridad
# al pasar por el único acceso habilitado militantes peronistas tiraron huevos al auto del presidente macri y a otros vehículos de la delegación del gobierno nacional
# allí lo estaban esperando con carteles que preguntaban dónde está santiago maldonado
# y otros que afirmaban tarifazos es igual a pobreza
# macri queremos ser la generación que vino a cambiar la historia para siempre
# witolda una búsqueda por el universo gombrowicz apu se han reunido para crear una revista dedicada a witold gombrowicz
# nicolás hochman el proyecto arrancó en 2013 hicimos un congreso internacional sobre witold gombrowicz que es un escritor polaco que estuvo acá 24 años y que tiene mucho prestigio afuera es recontra conocido
# ganó el premio formentor que es el premio más importante que ganó borges y que afuera es uno de los escritores de vanguardia más importantes del siglo xx y acá que lo tuvimos un cuarto de siglo no básicamente
# las acciones que venimos desarrollando con el equipo del congerso gombrowicz tienen que ver con dar a conocer su vida su obra con intentar generar nuevos lectores y con hacer que los lectores que ya tiene tengan material fresco nuevo que les den ganas de retomarlo
# apu algo que tiene que ver con el formato es una revista de un solo número por qué eso y no un libro una compilación
# nh venimos haciendo cosas hace tiempo
# en 2014 hicimos un libro de antología de ilustraciones a partir de textos de él el año pasado una antología con 37 artículos inéditos sobre gombrowicz
# la idea de este año era dar una vuelta de tuerca
# surge un poco como un capricho como una especie de continuación se cumplen 70 años de la aparición de una revista que promocionaba ferdydurke
# esa revista se llamó aurora revista de la resistencia que también fue una revista de un solo número y un amigo suyo virginio piñeira que era uno de los traductores de ferdydurke al otro día sacó una revista que se llamó victrola revista de la insistencia
# 70 años después venimos a hacer witolda revista de la persistencia continuando con esa línea risas
# apu siguiendo también con la línea de humor que tenía witold donde realmente es importante el humor y el delirio sobre todo en la juventud
# nh la juventud la inmadurez la ruptura con las formas
# gombrowicz era un gran provocador hoy sería un gran tuitero risas
# queríamos retomar algo de esa provocación tanto con el formato como con los contenidos y con la revista como objeto
# es una obra de arte tiene tres colores negro rosa flúor y verde flúor es estridente aunque se puede leer perfecto pero causa una incomodidad en el impacto incial que es algo que queríamos transmitir
# apu pensando un poco en la relación vida obra qué aspectos destacás
# nh en gombrowicz vida y obra están completamente unidas de hecho es muy difícil distinguir cuando escribe ficción algo que pasa con cualquier escritor pero que en él es mucho más evidente
# en sus novelas cuentos y obras de teatro aparecen todo el tiempo elementos de una escritura del yo una primera persona absolutamente verosímil que concuerda casi paso a paso con su biografía y por otro lado las cartas sus diarios aparecen literalmente cosas que están tomadas de obras de ficción
# por ejemplo cuando se vuelve de argentina a europa se toma un transatlántico y va narrando qué le pasa cuando llega a la cubierta y hace poco descubrimos que hay fragmentos de eso que están tomados literalmente de un cuento que había publicado 30 años antes
# apu en la revista participan un montón de autores
# nh son más de 100 colaboradores pensando entre traductores escritores e ilustradores
# hay gente de afuera como enrique vila matas juan villoro o algunos de los especialistas en gombrowicz más importantes a nivel internacional que están traducidos especialmente tenemos un adelanto de clementina sujanov que es una polaca que viene acá seguido y que acaba de publicar la primera biografía sobre witold gombrowicz en el mundo
# y de acá también están cesar aira noé jitrik hernán ronsino germán garcía ricardo bartis
# son un montón de personas que nos llena de alegría encontrar
# nos pasan dos cosas por un lado encontrar lectores de gombrowicz en todo el mundo y por el otro ir formando lectores de él
# algo paradigmático para nosotros es que el cierre del evento va a estar a cargo ricardo tapia de la mississippi
# una de las secciones de la revista es preguntarle a diferentes personas si leyeron o no a gombrowicz y por qué
# tapia que es un gran lector nos dijo que no nos explicó por qué nunca lo había leído y a partir de ahí surgió el cierre que va a ser él con su guitarra cantando una canción basada en textos de gombrowicz
# apu de la obra de gombrowicz han surgido autores y obras interesantísimas por ejemplo minga de jorge di paola en qué autores está referenciada hoy la obra de gombrowicz
# nh uno de los textos más interesantes que tenemos es de una autora polaca eva kovietzka que hizo una tesis sobre la influencia de gombrowicz en los escritores locales
# con lo que se encontró es que con la mayoría de los escritores locales que dicen tener esa influencia no se ve risas la influencia aparece en otro que está mucho más tapado
# yo lo veo un montón en escritores que no saben que están influenciados por él
# gombrowicz empezó a transitar un camino que después iban a transitar otros pienso en perlongher aira copi que el que no sabe que dio inicio a esa literatura fue gombrowicz puig mismo incluso aparece gombrowicz en rayuela citado explícitamente
# entonces más allá de los autores que están explícitamente influenciados es interesante ver cómo la literatura de gombrowicz es un surco que después transitamos todos sepamos o no.
# se casa dalma maradona
# y el anuncio lo hizo nada menos que su padre diego maradona
# el diez usó su facebook para hacer el anuncio con una tierna foto de dalma casi bebé en sus brazos
# había una vez un joven llamado andrés caldarelli que llamó al padre de su novia para pedirle su mano
# caballeros como mi yerno no existen más
# estoy muy feliz y orgulloso de contarles que se casa mi hija dalma escribió diego en la red social
# de perfil bajo dalma está de novia con andrés desde hace cinco años
# su pareja igual que ella evita la exposición mediática
# antes de caldarelli dalma tuvo otro noviazgo largo y de poca exposición fiel a su estilo
# estoy re de novia hace cinco años
# él es lo más
# el tema del casamiento está jodido
# a él mucho no le divierte
# no lo puedo convencer había dicho hace un mes dalma en una entrevista en el programa morfi
# bono preguntó por maldonado la comunidad internacional no parece darle descanso al presidente mauricio macri
# además de las cautelares advertencias y declaraciones que viene recibiendo de las naciones unidas de la cidh y de amnistía internacional el presidente mauricio macri fue interpelado ayer por bono el líder de la banda u2
# como suelen hacer los mandatarios cuando viene una estrella de rock macri recibió al cantante entre sonrisas e intercambio de regalos recibió un libro de un poeta irlandés
# bono no obstante le preguntó por el avance de la causa de maldonado y también le habló sobre el sexismo en la educación
# según comentaron los adláteres de macri el encuentro fue muy cordial
# el gobierno usó la difusión del encuentro a su favor dado que al salir bono contó hablamos de santiago maldonado y sentí que el presidente está tomando el caso seriamente y como miembro de amnesty internacional eso me puso muy feliz
# si bien es costumbre de todos los presidentes recibir a las figuras internacionales del rock que vienen a la argentina en este caso los funcionarios destacaron que ya había existido una conversación previa con bono en el foro de davos donde había tenido como interlocutores al jefe de gabinete marcos peña y al secretario de asuntos estratégicos fulvio pompeo
# no casualmente fueron los dos funcionarios que acompañaron a macri junto con la responsable del g20 natalia zang
# bono también había tenido un encuentro previo con macri en nueva york cuando el presidente asistió a la apertura de la clinton global initiative
# bono llegó a la argentina para dar dos recitales en el marco de la gira the joshua tree world tour 2017 y visitó la casa rosada donde se congregó un grupo de fans para saludarlo
# el cantante pasó por los pasillos saludando a los empleados con los dedos en ve
# en principio el encuentro estaba pensado para hablar de educación pero el caso de santiago maldonado –que está teniendo más repercusión internacional de la que al gobierno le gustaría– se coló en el encuentro
# tras la reunión con macri que duró unos 50 minutos el cantante hizo un comentario con todas las fórmulas de cortesía del caso hablamos de santiago maldonado y sentí que el presidente está tomando el caso seriamente y como miembro de amnesty internacional eso me puso muy feliz sostuvo
# macri publicó esta declaración en su cuenta de twitter e incluso fue título de un adelanto del comunicado oficial sobre el encuentro en el gobierno lo leyeron como un respaldo de bono al presidente en el caso maldonado
# en el comunicado indicaron que macri explicó a bono todas las acciones llevadas a cabo para dar con el paradero del joven y la tarea de permanente colaboración que el gobierno está brindando a la justicia para esclarecer la causa en la que se investiga su desaparición
# en privado se arriesgaron a asegurar que bono se quedó conforme con las explicaciones
# también hablaron sobre la educación
# según dijo bono después tuve una gran reunión con el presidente
# y digo gran’ en el sentido de que cubrimos muchos temas
# hablamos de la educación y específicamente de la educación de las mujeres
# el presidente se sentará a la cabeza del encuentro del g-20 el año que viene
# y sabemos que la pobreza es sexista y sabemos que si tomás a las mujeres en serio y la educación de las mujeres en serio se puede progresar mucho
# estoy muy agradecido por cómo nos recibieron por su tiempo y el que nos dio el jefe de gabinete sostuvo antes de salir a firmar autógrafos de los fans que lo esperaban contra las rejas de la rosada
# según el comunicado oficial el cantante irlandés elogió el compromiso del jefe de estado para convertir a la educación en una de las prioridades de la presidencia argentina del g20 y lo invitó a la próxima conferencia para obtener financiamiento que organizará la alianza global para la educación global partnership for education convocada por los presidentes de francia y senegal emmanuel macron y macky sall que se realizará en dakar senegal en febrero de 2018
# los macristas agregaron que bono comparó a macri con angela merkel de alemania y con emmanuel macrón de francia
# desde el gobierno insistieron en la buena onda con bono e incluso informaron que piensan trabajar con la fundación one que él creó
# por último bono lo invitó a macri a uno de sus recitales
# la revancha del huevo el alimento lleno de propiedades saludables por otra parte el huevo es considerado un alimento clave para mujeres embarazadas porque además de contener 6 gramos de la mejor proteína por unidad
# los huevos son fuente de vitaminas y minerales como las vitaminas e b2 a d folato hierro y especialmente colina un nutriente semiesencial en el embarazo que interviene en el desarrollo del cerebro del bebé en gestación
# además los huevos contienen pigmentos amarillos de tipo carotenoides denominados luteína y zeaxantina que son potentes antioxidantes
# publicarán un nuevo libro de cincuenta sombras y prometen que será más oscuro que los anteriores
# nuevo round entre diego brancatelli y maría eugenia vidal la gobernadora de la provincia de buenos aires maría eugenia vidal y el panelista ultra kirchnerista de intratables diego brancatelli estuvieron nuevamente cara a cara en los estudios de américa y protagonizaron un nuevo round luego del mítico cruce que tuvieron previo a las paso
# aunque esta vez el tono fue más tranquilo las ironías y las chicanas estuvieron a flor de piel
# el periodista apuntó contra vidal al hacer acusaciones sobre una licitación muy polémica en el servicio penitenciario que incluye 1.100 millones de pesos y me hablan de victor lusardi
# siguiendo con su postura brancatelli le preguntó si conocía el caso y al personaje que acusaba y le dijo que se comprobó que varias cosas que dijo eran falsas en referencia al primer cruce entre ambos en el programa
# no lo conozco en general no conozco a los proveedores de la provincia
# y me parece bueno no conocerlo ni atenderlos
# sobre esta licitación de la que hablas firmé el pliego hace pocos días por lo que no debe ni estar adjudicada así quehablar de irregularidades en una licitación que ni siquiera se adjudicó me parece es por lo menos tendencioso respondió vidal
# como yo no conozco ni recibo a ninguno no tengo nada de qué preocuparme agregó la mandataria bonaerense
# a su turno vidal atacó a brancatelli por sus dichos sobre lo ocurrido en el escrache al presidente en la pampa
# claro no hablemos de las agresiones sino de lo que tenemos que hablar en esta campaña hablemos lo que se decide y me encantaría que cada uno lo haga sostuvo la referente de cambiemos
# qué bueno que podamos mostrar un equipo y que no haya una sola voz dentro de cambiemos como no la hubo nunca como cuando yo era candidata y me acompañaba mauricio a este programa sentenció haciendo clara alusión a cristina kirchner
# antes brancatelli había caldeado el ambiente cuando la chicaneó con que estaba al frente de la campaña sin ser candidata y ella lo tildó de tendencioso
# estoy sorprendido gratamente con la presencia de la gobernadora dado que no es candidata
# acompañando a sus candidatos raro no
# en el frente renovador habla sergio massa en unidad ciudadana habla cristina kirchner que es la candidata y en cumplir habla florencio randazzo ironizó brancatelli cuando comenzó su turno de preguntar
# siempre enaltece que una gobernadora salga a dar la cara por los candidatos
# disfruten y aprovechen dijo mirando a los candidatos esteban bullrich graciela ocaña gladys gonzalez guillermo montenegro y toti flores que está saliendo muy bien lo de maría eugenia al frente de la campaña
# todo eso muy positivo para los números agregó en forma provocativa
# mientras el periodista hablaba esteban bullrich decía desde su silla yo hablo también habla gladys habla graciela
# el que también se metió fue santiago del moro
# fernanda vallejos es candidata y no habla disparó el conductor del programa en referencia a la candidata kirchnerista
# a pesar de las contestaciones brancatelli siguió haciendo referencia al escrache que sufrió el presidente en la pampa
# me parece que no hay que hablar de lo de la pampa que son 5 y que me imagino que estarán detenidos porque son fáciles de identificar estarán todos detenidos no
# fueron violentos y atentaron contra el presidente hay que detenerlos
# me parece que quieren instalar que hay una agresividad y no hablar de la realidad lanzó el panelista
# tres muertos al chocar dos camiones y un micro en santa fe
# matan con un drone a la viuda blanca la británica reclutadora de isis
# la corte confirmó el embargo a flor kirchner por u$s 6 millones desestimó un recurso de queja de florencia kirchner la corte suprema de la nación por el embargo de los casi seis millones de dólares que atesoraba en una caja de seguridad del banco galicia
# fuentes judiciales informaron hoy que el máximo tribunal fundamentó su rechazo en que el recurso de la hija de los ex presidentes néstor kirchner y cristina fernández o equiparable a tal
# la fortuna que florencia kirchner guardó en una caja de seguridad del año pasado por el juez federal julián ercolini en el marco de la causa denominada hotesur
# polémica en brasil para combatir el hambre un alcalde propone dar alimento balanceado a los pobres el alcalde de san pablo joao doria considerado un presidenciable para 2018 defendió este viernes la entrega de alimento balanceado hecho con productos con fecha de vencimiento cercana para familias carenciadas al afirmar que es el mismo que consumen los astronautas en las misiones al espacio
# el alimento fue desarrollado por científicos elaborado con enorme cuidado y sometido por la municipalidad de san pablo con todos los respaldos académicos y científicos
# el alimento dura años y es el mismo que consumen los astronautas en el espacio dijo doria desde milán italia
# el alcalde del oficialista partido de la social democracia brasileña psdb aliado del presidente michel temer afirmó que las críticas de especialistas en nutrición y combate al hambre eran de personas con total falta de conocimiento
# la nueva política municipal forma parte de un programa que doria quiere instalar en el resto de brasil para combatir el hambre
# brasil había salido por primera vez en 2014 del mapa del hambre de la onu elaborado por la fao luego de la reducción del 82 en la subnutrición en los últimos 15 años
# el gobierno municipal de san pablo la ciudad más grande de américa del sur lanzó el plan alimentos para todos con el objetivo de reducir impuestos a supermercados y restaurantes que adhieran a entregar alimentos antes de perecer para la confección de alimento balanceado por parte de una empresa privada
# el consejo regional de nutricionistas del estado de san pablo divulgó un comunicado en el cual afirma que la política de alimento balanceado para pobres se enfrenta a los principios del derecho humano a la alimentación adecuada y a la guía alimentaria de la población brasileña dos rectores del combate al hambre
# es una total falta de respeto a los avances de las ultimas décadas en el campo de la seguridad alimentaria en lo que respecta a las políticas contra el hambre y la desnutrición dijo el consejo en un comunicado
# apunta que en los últimos 15 años políticas públicas como subsidios a l aagricultura familiar para la produccón y adquisición de alimentos programas de transferencia de renta vinculados a la atención medica y la educación de los niños lograron que brasil saliera del mapa del hambre de la onu que elabora la fao
# la distribución del alimento balanceado se realizará en centros comunitarios
# doria insistió desde italia mientras es feriado largo en brasil por motivo del 12 de octubre día de la virgen de aparecida patrona nacional
# es un alimento bueno yo ya lo comí tiene varios sabores e incluso el ejército lo usa en situaciones e emergencia enfatizó el magnate un empresario que financió gran parte de su campaña y ahora no descarta buscar un lugar en la liza electoral de 2018
# la presidenta de plataforma sinergía rossana perrotta encargada de fabricar el alimento balanceado para humanos dijo a la cadena globo que los alimentos serán procesados con un producto granulado llamado farinata con lo cual se tiene un stock de carbohidratos y fibras
# la oposición a doria en san pablo apunta la política del alcalde que redujo los productos saludables de la merienda escolar en las instituciones públicas y disminuyó la adquisición de orgánicos que consumen las escuelas
# daniel bandoni de la universidad federal de san pablo unifesp dijo que entregar una ración humana descontextualiza el acto de comer que va más allá de los nutrientes
# para el nutricionista los granulados son apenas para cuestiones de emergencia
# doria un ultraliberal que se posicionó como presidenciable se encuentra con popularidad a la baja según la encuesta de datafolha
# la popularidad del empresario y magnate quien asumió en enero cayó del 41 de apoyo al 32 pero apenas 10 respalda su posible renuncia a la alcaldía para intentar suerte en el ámbito nacional
# incluso en su partido el vicepresidente del psdb alberto goldman lo criticó en un video en las redes sociales al afirmar que san pablo no tiene una alcalde y sí un precandidato a la presidencia
# militante que escrachó a macri en la pampa le recagamos a huevazos el coche el presidente mauricio macri sufrió un escrache el jueves cuando un grupo de personas le arrojó huevos al vehículo en el que se trasladabaen la provincia de la pampa
# un hombre identificado como aníbal prina docente universitario y militante kirchnerista se jactó en su perfil de redes sociales de haber sido uno de los autores del hecho
# en una serie de imágenes que el hombre publicó en su cuenta de facebook se lo ve en la zona de la rotonda del avión el único acceso habilitado que permitía acercarse a la caravana presidencial que se dirigía a un acto de campaña en la ciudad de santa rosa
# esperando al gato tituló la serie de fotos en alusión al insulto que tiempo atrás se puso de moda para referirse al presidente
# prina de 60 años y quien dicta clases de botánica en la facultad de agronomía de la pampa celebró en la misma red social lo que hizo tirarle huevos al auto del mandatario
# somos nosotros pero después llegó más gente y otros grupos lo esperaban a macri en el centro para putearlo
# nosotros le recagamos a huevazos el coche sostuvo el docente al responder un comentario
# con chicanas y pases de factura cómo fue el reencuentro de vidal y brancatelli la gobernadora fue a intratables y volvió a intercambiar acusaciones con el periodista después del fuerte cruce que tuvieron antes de las paso hubo chicanas sí hubo pases de factura también
# pero este tercer round de maría eugenia vidal contra el periodista diego brancatelli no tuvo la tensión ni la rispidez de aquel que dio comienzo a la saga en la previa de las primarias abiertas simultáneas y obligatorias paso
# invitada a intratables junto a sus principales candidatos a senadores y diputados en octubre vidal estuvo gran parte del ciclo contestando preguntas de los panelistas incluidos el ferviente defensor de cristina kirchner
# estoy sorprendido gratamente con la presencia de la gobernadora dado que no es candidata
# acompañando a sus candidatos raro no
# arrancó brancatelli y comparó en el frente renovador habla massa
# en unidad ciudadana habla cristina que es la candidata y en cumplir habla randazzo
# la respuesta por lo bajo y durante su alocución llegó del candidato a senador esteban bullirch que aseguró que ellos sí hablaban
# a esto se sumó el conductor del programa santiago del moro que dijo que fernanda vallejos era la primera candidata a diputada por el kirchnerismo y que tampoco hablaba
# brancatelli siguió con sus chicanas y mirando a los candidatos de cambiemos dijo siempre enaltece que una gobernadora salga a dar la cara por los candidatos
# disfruten y aprovechen que está saliendo muy bien lo de maría eugenia al frente de la campaña
# todo eso es muy positivo para los números
# luego el panelista se metió con el tema del escrache al presidente en la pampa y dijo me parece que no hay que hablar de lo de la pampa que son cinco y que me imagino que estarán detenidos porque son fáciles de identificar
# estarán todos detenidos no
# fueron violentos y atentaron contra el presidente hay que detenerlos
# me parece que quieren instalar que hay una agresividad y no hablar de la realidad
# qué bueno que podamos mostrar un equipo y que no haya una sola voz dentro de cambiemos como no la hubo nunca como cuando yo era candidata y me acompañaba mauricio a este programa respondió sobre las críticas a su presencia con los candidatos y en clara contraposición al espíritu del frente para la victoria
# sobre el pedido de no hablar del ataque al presidente dijo claro no hablemos de las agresiones sino de lo que tenemos que hablar en esta campaña hablemos lo que se decide y me encantaría que cada uno lo haga
# la muerte en video hacía topless y falleció por imprudente dos amigas ivanna boirachuk y natalia borodina llegaron a punta cana pocos días atrás para disfrutar de unas vacaciones
# borodina llevó consigo a su hijo de 11 años
# una tarde mientras el niño se quedó en el hotel donde se hospedaban las amigas decidieron salir a recorrer la zona en auto y todo terminó en tragedia
# aprovechando que estaban sin el menor las jóvenes decidieron tomar alcohol aunque también la policía sospecha de drogas y en un momento natalia se quita la parte superior del traje de baño y saca su torso por la ventana del auto semidesnuda mientras su amiga quien conducía la filamaba
# como no estaba prestando atención al camino la conductora no pudo ver un pozo de agua que había adelante y perdió el control del vehículo
# natalia cayó del auto y si bien fue trasladada de urgencia a un centro de salud murió a las pocas horas a causa de las heridas recibidas en la cabeza
# ahora ivanna su mejor amiga enfrenta una causa judicial por conducir ebria y estar involucrada en la muerte de natalia
# paralelamente la familia quiere repatriar el cuerpo pero no cuenta con los recursos suficientes para hacerlo
# soy el único de mis hermanos que no pudo cagar a trompadas a mi papá exitoina el cantante revivió la violencia que sufrió en su infancia y contó cómo la superó y cuál es la relación con su papá
# mirá el video
# así como hoy es un referente musical entre los artistas que le cantan al amor y a la esperanza axelcontó alguna vez que vivió una infancia violenta
# y entrevistado por verónica lozano el músico revivió algunas de las cosas por las que debió pasar
# en mi casa viví muchísima violencia pero no sólo para conmigo sino también con mis hermanos y mi mamá
# ella era muy sometida porque no podía salir de ese círculo vicioso
# mi papá para adentro era una persona súper violenta y para afuera un cobarde
# el patrón típico relató en cortá por lozano
# pero igualmente yo nunca guardé rencor por mi papá y el año pasado lo llevé a recorrer europa y a ver la final de la copa davis
# yo siempre sostengo algo que es fundamental en mi vida cachetada de guante blando es como dar la otra mejilla
# siempre da un golpe de amor y buscá trascender eso explicó el cantante
# sobre el final de la entrevista lozano fue de frente nunca te dio ganas de cagarlo a trompadas
# y axel respondió con total sinceridad fui el único de mis hermanos que no pudo
# nunca le pegué a nadie y no me parece que sea la solución
# no va conmigo
# corte suprema confirmó embargo de cuentas de florencia kirchner la corte suprema de la nación desestimó un recurso de queja de florencia kirchner por el embargo de los casi seis millones de dólares que atesoraba en una caja de seguridad del banco galicia
# fuentes judiciales informaron que el máximo tribunal fundamentó su rechazo en que el recurso de la hija de los ex presidentes néstor kirchner y cristina fernández no se dirige contra una sentencia definitiva o equiparable a tal
# la fortuna que florencia kirchner guardó en una caja de seguridad fue embargada el 15 de julio del año pasado por el juez federal julián ercolini en el marco de la causa denominada hotesur
# detuvieron a un docente que se adjudicó el ataque a huevazos contra macri en la pampa
# la justicia ordenó la detención de un docente universitario por ser uno de los responsables del ataque a huevazos en santa rosa contra el auto en el que iba el presidente mauricio macri
# se trata de aníbal prina un profesor de biología que integra la agrupación kirchnerista frente peronista barrial y que fue precandidato a diputado nacional pero su propuesta sacó 8.501 votos y quedó afuera de las elecciones del 22 de octubre
# ja ja ja somos nosotros pero después llegó más gente y lo esperaban en el centro para putearlo
# nosotros le recagamos a huevazos el coche tuiteó prina de 60 años
# según informa diariotextual de la pampa el juez federal facundo cubas ordenó su detención por el delito de intimidación pública que tiene una pena que va de los dos a seis años de prisión
# sólo que sé quién es mi enemigo principal hoy y es el gobierno neoliberal de macri y mis esfuerzos estarán destinados a enfrentarlo y frenarlo donde sea y como sea había publicado prina durante su campaña
# no lo puedo creer
# el mapa de calor de messi ante ecuador forma un
# en las redes sociales se viralizó la imagen
# qué es
# lionel messi jugó en un nivel altísimo contra ecuador
# por tal motivo opta que detalla el movimiento de todos los jugadores en el campo de juego publicó el mapa de calor de la pulga
# la particularidad es que hilando fino una de las formas que queda con sus movimientos en el gráfico se asemeja a la de un pene algo que los usuarios de las redes sociales no dejaron pasar
# conocé a la jenny personaje mendocino que revoluciona las redes una mendocina que hace stand up creó un personaje polémico
# que da que hablar
# se trata de la jennifer brittany shodrigue alias la rocha
# están quienes se ríen con sus ocurrencias y quienes dicen que es totalmente discriminatoria
# en su canal de youtube escribió es solo una humorada está hecho sin ánimo de ofender a nadie todo lo contrario
# la idea es robarte una sonrisa al menos sobre gustos no hay nada escrito
# agradecería que se ahorren los comentarios con mala vibra
# besos para todos
# la jenni hizo su propia versión del tema la tonta de jimena barón
# y vuelvo a ser la rocha que se copa con tu vida la que te espera mientras te requisan que se pone violenta si te ve con otra mujer canta
# sus ocurrencias también pueden verse en su perfil de facebook
# el partido cordobés que devolvió $ 1,2 millones que no usó en campaña encuentro vecinal reintegró entre antes de las paso y ahora $ 1,2 millones cordoba
# encuentro vecinal es un partido político cordobés que provocó impacto con una conducta que debería ser la habitual ya devolvieron $ 757.000 de lo que le entregaron para la legislativa del 22
# recibieron $ 997.000 y lo que les sobró fue reintegrado después de las paso fueron $ 521.000
# en el 2013 tuvieron la misma conducta reintegraron $ 200.000
# para aurelio garcía elorrio legislador provincial y cabeza de la lista de diputados nacionales lo que hizo el partido es sólo lo que se debe hacer absolutamente normal
# en las paso la fuerza quedó quinta y compite el domingo 22
# del ministerio del interior recibió $ 667.000 para la impresión de los votos hicieron 1,5 millones de boletas gastaron unos $ 140.000 y regresaron el resto de los fondos
# para el domingo 22 imprimieron 2 millones de boletas como son el doble de grande insumen más dinero
# el partido nació en 2011 por la fusión de encuentro por córdoba y la unión vecinal córdoba ese año presentaron lista sólo para legisladores provinciales e ingresó a la unicameral garcía elorrio
# se autodefinen como un grupo de ciudadanos cordobeses ajenos a la actividad política que decidimos meternos en política para cambiar la política
# desde encuentro vecinal su tesorero fernando rombaldi explicó a la nacion que es lógico devolver el dinero que les sobró porque interior lo entrega para la impresión de boletas si se usa para otro fin es malversación de fondos
# en la página web de la fuerza ofrecen distintas opciones para donar fondos vía depósito bancario o débito y recuerdan que el esquema posibilita deducir la donación de lo que se debe pagar por ganancias hasta un 5 del monto a tributar
# ante dudas dan el teléfono móvil del tesorero para hablar directamente con él
# hacemos todas las rendiciones de cuentas que exige la ley y la presentación de balances
# es poco el dinero que viene por afuera porque somos un partido chico en época de campaña se acerca más gente que comparte los principios que tenemos describe rombaldi
# incluso desde antes de ser legislador garcía elorrio se presentó como un defensor de las normas antiabortos en la plataforma de su partido se remarca el respeto sin excepciones ni condicionamiento alguno de la dignidad de todo ser humano desde el comienzo de su vida en la concepción hasta su muerte natural
# es uno de los creadores de la fundación portal de belén un albergue para madres solteras
# como legislador es un denunciante activo de las bandas de narcotráfico puntos de venta y cocinas de droga en córdoba varias veces presentó ante la justicia y la policía antinarcóticos cordobesa una lista con los 35 cabecillas que -según sus datos- manejan la pasta base y las cocinas
# es crítico de la política provincial en el área
# junto a los legisladores liliana montero y juan pablo quintero viene denunciando supuestas irregularidades del accionar de odebrecht en córdoba incluso solicitaron al fiscal brasileño delton dellagnol quien lleva adelante la acusación en la mega causa lava jato que sea la propia justicia de brasil la que interrogue a alberto youssef sobre quiénes son las personas que con seudónimos han sido mencionadas en relación a los pagos de sobornos de las obras en la provincia
# página12
# los precios saltan por encima de la meta el aumento promedio de los precios al consumidor en septiembre del 1,9 por ciento medidos por el indec ubica la inflación acumulada en los nueve meses ya transcurridos de 2017 en el 17,6 por ciento
# con lo cual faltando aún un trimestre completo para completar el año ya quedó superado el techo del rango de aumento de precios que el gobierno de cambiemos aspiraba alcanzar en su segundo año de mandato
# la meta de inflación oficial ubicaba el aumento de precios en 2017 punta a punta de enero a diciembre entre el 12 y el 17 por ciento
# no sólo se superó el techo sino que el piso hasta podría duplicarse teniendo en cuenta la incidencia en los índices de noviembre y diciembre próximos por las subas en combustibles electricidad y gas que el gobierno proyecta aplicar una vez pasadas las elecciones legislativas y antes de fin de año
# pese a la política monetaria contractiva del banco central y la apertura comercial para facilitar la oferta de productos importados la política de desinflación no tuvo los resultados esperados
# al contrario el nivel general de precios retomó su tendencia alcista desde el inicio del presente año luego de un segundo semestre de 2016 en el que se había observado un relativo aquietamiento de la inflación
# algunos datos que reflejan la distancia entre los postulados del gobierno de cambiemos y los resultados el índice general de precios aumentó en septiembre 1,9 por ciento
# el rubro que más aumentó en el último mes es prendas de vestir y calzado 3,8 por ciento
# en el área metropolitana ciudad autónoma y conurbano bonaerense región de mayor volumen de consumo de dichos productos la inflación en ese rubro alcanzó el 5,9 por ciento
# este rubro ha sido uno de los más castigados a nivel industrial por la caída del consumo interno pero además por el impacto de la importación
# en el renglón de textil e indumentaria las importaciones de este año ya se ubican en volumen más de 50 por ciento sobre los niveles de 2016
# en calzados el incremento de oferta importada es del orden del 27 por ciento y en marroquinería de más del 40 por ciento
# pese a esta invasión de importados con reducción de la demanda los precios internos siguen subiendo
# aunque los industriales textiles no niegan cierta incidencia en los aumentos estacionales cambio de temporada voceros del mismo sector señalan que esto demuestra que el desplazamiento de la industria local por la importación no sirvió para bajar precios si entran productos más baratos aumentan los márgenes de comercialización y no hay beneficio para los consumidores
# el achicamiento de la demanda también induce a que el comercio aumente los márgenes para compensar la menor cantidad de unidades vendidas
# tampoco hay controles oficiales ni seguimiento sobre los canales de comercialización
# por el contrario recientemente la dirección de aduanas dependiente de la afip dispuso que no se entregue más información sobre la identidad del importador ni detalles sobre los productos ingresados en cada despacho por considerarlo violatorio del secreto fiscal
# esto le impide a la industria nacional hacer un seguimiento de las importaciones y medir por ejemplo si hay maniobras de dumping en el precio de los productos ingresados
# los otros rubros señalados por el indec con aumentos por encima del nivel general de inflación en septiembre son educación 3,7 por ciento recreación y cultura 2,7 por ciento y salud 2,4 por ciento
# detrás se ubica el rubro vivienda agua electricidad y gas con el 2 por ciento de aumento en el mes aunque los principales ajustes en las tarifas domiciliarias fueron postergados para después de las elecciones legislativas del próximo domingo 22
# alimentos y bebidas se ubicó apenas un escalón debajo del aumento de precios al consumidor a nivel general con el 1,8 por ciento
# el fracaso de la receta de apertura más contracción de la demanda interna para contener la inflación se complementa además con las consecuencias del ajuste y los cambios estructurales a favor de los sectores más concentrados que operan como otros factores que alimentan la inflación
# el fuerte impacto de la devaluación y quita de retenciones a las exportaciones casi en simultáneo con el inicio del mandato de mauricio macri diciembre de 2015 provocó un shock inflacionario que se prolongó a lo largo de los primeros meses de 2016
# posteriormente hubo cierta calma inflacionaria que duró hasta los últimos meses del mismo año cuando las presiones de los sectores dominantes en cada mercado volvieron a impulsar aumentos para recomponer márgenes de ganancias
# con los aumentos previstos para el último bimestre del año en tarifas y combustibles la proyección de la inflación se ubica por encima del 23 por ciento incluso suponiendo un impacto moderado
# los acuerdos salariales pactados a mitad de año volverán a quedar –como en 2016– por detrás de la inflación y en vísperas de un año 2018 donde las perspectivas para las negociaciones paritarias no son más alentadoras
# procesan a gils carbó por administración fraudulenta la procuradora general de la nación alejandra gils carbó jefa de los fiscales quedó procesada por administración fraudulenta luego de que un juez entendió que urdió un plan con un funcionario a su cargo para direccionar la compra de un nuevo edificio de la procuración por 44 millones de pesos y permitir que un intermediario cobrara una desmedida comisión de casi 8 millones de pesos
# la decisión fue firmada por el juez federal julián ercolini que embargó los bienes de gils carbó hasta la suma de 7 millones de pesos
# con este fallo el oficialismo retomó la idea de impulsar el juicio político de la procuradora
# ésta es la resolución que esperaba el gobierno para forzar su alejamiento pues su mandato es vitalicio
# el gobierno entiende que gils carbó es la más encumbrada operadora del kirchnerismo que aún conserva poder y que lo usa con fiscales leales para impulsar denuncias contra funcionarios de cambiemos
# gil carbó no reaccionó y en cambio dio a conocer anoche un comunicado de su abogado león arslanian en el que dice que apelará porque -sostiene- lejos de perjudicar al estado la compra del edificio lo benefició y señala que le provoca suspicacia que el fallo se conozca antes de las elecciones del 22
# además de a gils carbó el juez procesó a guillermo alfredo bellingi subdirector general de la procuración quien llevó adelante la compra y a juan carlos thill su medio hermano que actuó como intermediario de la inmobiliaria jaureguiberry y asociados que intervino en la operación
# el póster de la 5 ° temporada de vikings te adelanta su futuro
# el 29 de noviembre los vikingos vuelven a la acción en lo que será el estreno de su quinta temporada
# y para empezar a palpitar lo que nos espera history channel presentó el póster oficial de la serie
# una imagen poderosa y ensangrentada decora la incógnita quién llegará a lo más alto
# ahí podemos ver por ejemplo a katheryn winnick como lagertha alex høgh andersen como ivar the boneless y alexander ludwig como bjorn
# espadas sangre y y miradas cómplices hacen de este póster el primer adelanto sobre lo que nos espera en esta quinta temporada
# habrá alianzas y traiciones
# quién llegará a lo más alto del reinado vikingo
# podrán los hijos de ragnar mantenerse unidos
# todo eso y mucho más será recién develado el 29 de noviembre cuando el primero de los 20 nuevos episodios vea la luz en history channel
# amazon ampliará su negocio a brasil y la acción de mercadolibre cayó 10 amazon es un gigante que hace tambalear todo a su paso
# ayer se conoció la noticia de que el líder de e- commerce planea ampliar su presencia en brasil y la firma argentina mercadolibre sintió sus efectos
# en wall street el papel del unicornio local se desplomó un 10 por los efectos negativos que la llegada de amazon podría causar en una de sus principales plazas
# según informó el diario brasileño valor cinco años después de llegar a brasil amazon comenzará a vender productos tecnológicos en el país vecino en las próximas semanas
# además antes de fin de año expandiría esta lista a fin de volcar en este país toda su gama de productos y servicios que actualmente ofrece en ee.uu
# esto afectaría directamente las proyecciones y ganancias de la empresa creada por marcos galperín ya que es en este mercado donde obtiene más del 50 de su revenue
# los inversores manifestaron su preocupación y ayer el papel de mercadolibre inició la rueda con un rojo de 7 que fue progresando hasta finalizar con un desplome de 10
# además de ser el principal mercado del hasta ahora líder regional en ventas por internet brasil es una plaza codiciada el comercio electrónico en ese país moverá este año más de u$s 15.800 millones según datos de la compañía de procesamiento de pagos on line pagbrasil
# con su desembarco en el país más grande de sudamérica la firma dirigida por jeff bezos podría destronar la plataforma de comercio electrónico argentina que se jacta de ser la líder en los 19 países en las que opera
# otro jugador del e commerce en brasil la compañía b2w perdió ayer 4,3 en la bolsa brasileña tras conocerse la noticia
# no es el primer golpe que recibe el papel de mercado libre en wall street este año
# hace poco más de dos meses la acción se había desplomado un 17 tras anunciar los resultados del segundo trimestre que no cumplieron con las estimaciones de sus inversores
# ...
# días atrás los fiscales gerardo pollicita e ignacio mahiques pidieron un embargo sobre distintos bienes de cristina kirchner sus hijos el exministro de planificación federal julio de vido y otros funcionarios
# ese otro pedido fue hecho ante el juez federal julián ercolini en la causa por defraudación en la obra pública en la que la ex mandataria ya está procesada al igual que el empresario lázaro báez entre otros
# el alcalde de san pablo entregará alimento balanceado a las familias pobres el alcalde de san pablo joao doria entregará a las familias carecientes un alimento balanceado producido con comida a punto de vencer decisión que desató polémica y el rechazo de los nutricionistas y expertos en políticas para combatir el hambre
# la decisión forma parte del plan social alimentos para todos de la municipalidad san pablo en acuerdo con la empresa privada plataforma sinergia que informó que el alimento llegará en forma de granulados para la población pobre
# la fabricación de este alimento balanceado responde a un programa de incentivo económico a supermercados y restaurantes para que entreguen sin cargo alimentos con fecha de vencimiento cercana de modo de evitar el desperdicio según una nueva ley municipal
# doria un empresario millonario que asumió como alcalde en enero es considerado un presidenciable del oficialista partido de la social democracia brasileña psdb cuya dirigencia lo enfrentó abiertamente esta semana a raíz de que se ha dedicado a viajar por el país para promocionarse como candidato a la jefatura del estado
# la presidenta de plataforma sinergía rossana perrotta dijo a la cadena globo que los alimentos serán procesados con un producto granulado llamado farinata con lo cual se tiene un stock de carbohidratos y fibras
# la acción forma parte de la política municipal de erradicación del hambre que esta semana lanzó doria uno de los principales aliados del presidente brasileño michel temer
# el alcalde paulista no descarta ser candidato presidencial en 2018
# para los especialistas la situación sobre el alimento balanceado a los más pobres genera rechazo como es el caso de la nutricionista de la universidad del estado de rio de janeiro uerj ana carolina feldenheimer que además es miembro de la alianza para la alimentación adecuada y saludable
# alimentación no es apenas un nutriente granulado
# es tener alimentos saludables frescos de buena calidad y y diferenciados
# y no es una salida de la sociedad para alimentar a su población más pobres dijo feldeheimer
# la oposición paulista a doria apunta la política del alcalde que redujo los productos saludables de la merienda escolar en las instituciones públicas y también la compra de alimentos orgánicos que se consumen las escuelas
# daniel bandoni de la universidad federal de san pablo sostuvo que entregar una ración humana descontextualiza el acto de comer que va más allá de los nutrientes
# para el nutricionista los granulados son apenas para cuestiones de emergencia
# la doctora en alimentos de la universidad de campinas unicamp elke stedefeldt dijo que la política de doria es contraria a la iniciativa nacional de alimentación y nutrición
# ante la polémica la alcaldía emitió un comunicado en el que indicó que su política está siendo elaborada y será aprobada siguiendo las normas nacionales y en conjunto con los deseos de la población
# doria de orientación política ultraliberal tiene un nivel de popularidad con tendencia a la baja según la encuesta de datafolha
# en este sentido las estadísticas de la encuestadora marcan que la popularidad del alcalde paulista cayó del 41 al 32 mientras que apenas 10 respalda su posible renuncia al cargo para tentar suerte en el ámbito nacional
# alberto goldman vicepresidente del psdb criticó a su correligionario mediante un video difundido por las redes sociales en el que afirma que san pablo no tiene una alcalde y sí un precandidato a la presidencia
# overoles y cascos las fotos que más le gustan a mauricio macri el 37 de los imágenes publicadas en la cuenta de casa rosada que tienen al presidente como protagonista lo muestran inaugurando obras
# junto a unos pocos funcionarios mariu vidal horacio rodríguez larreta y guillo dietrich los que más repiten y varios operarios con overoles azules y naranjas y cascos amarillos o blancos mauricio macri se muestra sonriente
# y su discurso repite los latiguillos de la campaña verdad cambio equipo con el foco puesto en las obras
# no es muy distinto del escenario que también elegía cristina kirchner que hasta inauguraba obras vía skype en diálogo con operarios
# de hecho el presidente repitió la mecánica esta semana en su primera videoconferencia
# del otro lado en jujuy estaban el jefe de gabinete marcos peña y el gobernador gerardo morales
# con cascos de obreros puestos hicieron el anuncio del comienzo de las obras del parque fotovoltaico caucharí la planta de energía solar más grande de latinoamérica
# en todo momento el macri presidente apela con orgullo al macri ingeniero
# es el cuadro que se repite en los últimos dos meses al menos dos veces a la semana
# y en algunos casos varias veces en un día la semana pasada en un raid contrarreloj macri inauguró cuatro obras en sólo cinco horas
# más de mauricio macri -“el sueño de macri de separar los sindicatos de los partidos -“¿qué gastos ajustará el gobierno de macri el año próximo -“prat gay por qué macri echó a su ministro estrella solo en septiembre el presidente acumula media docena de ejemplos en el sitio de casa rosada desde el inicio de las obras del viaducto del ferrocarril mitre beneficiaría a unos 120 mil usuarios pasando a una recorrida por las instalaciones de la central térmica de anchoris luján de cuyo y terminando en la inauguración del tramo final del viaducto de puente la noria
# y cuando no se traslada para inaugurar una obra macri encuentra un obrero con overol y pa la en el fondo de su casa el 15 de septiembre observó el comienzo de los trabajos para abrir e integrar la quinta presidencial al barrio de olivos y poner en valor su patrimonio paisajístico y favorecer el desarrollo de nuevos espacios verdes
# cada semana hay un proyecto que se termina dice macri
# ahora la ventaja lo maravilloso de trabajar en equipo y decirnos la verdad es que las obras empiezan y terminan en las fechas comprometidas afirmó el presidente hace una semana en la inauguración de una planta depuradora en lomas de zamora que incorporará 350 mil habitantes al sistema cloacal
# la apelación a la gestión que consagra también a sus discípulos en las encuestas en capital y la provincia de buenos aires
# economistas apuntaron al bcra por fracaso de meta oficial de inflación luego de que el indec difundiera el dato de inflación de septiembre que arrojó un aumento del 1,9 con respecto al mes de agosto hecho que marca la ruptura del techo del 17 que el gobierno había estimado para el año ámbito.com dialogó con economistas quienes analizaron la situación y ofrecieron distintas perspectivas de cara el comienzo del 2018.aldo abram director de la consultora libertad y progreso alertó sobre los efectos de la depreciación del peso que el bcra permitió entre mayo y los días previos a las paso
# de esto tiene que aprender el central
# hay muchos que festejan la suba del tipo de cambio real
# tarda en pasar a los precios pero ocurre es un proceso simplemente coyuntural destacó
# asimismo abram analizó federico sturzenegger había dicho que cambiar las metas era lo mismo que no existieran pero no cumplirlas también implica lo mismo
# el gobierno dijo que la depreciación del peso no iba a tener ese impacto en los precios y podés mirar la evolución del índice canasta básica en los últimos meses para darte cuenta que sí lo tuvo
# por otra parte el economista afirmó que el bcra no cumplió con su objetivo de bajar la inflación ya que está llevando adelante una política expansiva pese a que dicen que es contractiva
# hace rato ya nadie pensaba que se pudiera cumplir la meta estamos cada vez más lejos del 20
# a principio de año yo era de los que creían que era posible pero se volvieron a repetir errores del pasado lanzó
# soy fanático de las metas de inflación pero parece que el central prioriza otras cuestiones en vez de cumplirlas
# venimos de un contexto con elevada inflación en el que no había datos certeros sobre ella necesitamos que la gente aprenda a tener una brújula común que son las metas concluyó
# rodrigo álvarez por su parte señaló que se trata de un dato alto que muestra que al gobierno y al bcra le cuesta perforar y bajar la inflación llevarla al menos al 1,5 y ni hablar de al 1
# asimismo puntualizó en que el problema estuvo desde un primer momento en poner las metas demasiado bajas ya que generó una expectativa que no se pudo cumplir
# además remarcó que si bien el proceso de desinflación está siendo desestimado por el bcra no es exclusiva su responsabilidad está haciendo lo que puede
# de todas maneras criticó en parte la estrategia tomada hasta el momento sostener la baja con la tasa de interés está siendo imposible
# para álvarez el gobierno va a tener que revisar dichas herramientas y las medidas tomadas ya que se trata de un problema serio que debe tener la coordinación de distintas áreas la inflación no es una cruzada solo del bcra sino que debe interpelar también a la secretaria de comercio y a energía entre otras
# por otro lado consideró que con los aumentos de tarifas de servicios públicos previstos para después de las elecciones la inflación anual se ubicará dentro de un límite entorno al 24
# consultado por este medio el exdiputado claudio lozano aseguró que el gobierno erra en el enfoque que toma sobre la temática
# no hay tanto éxito como decían que iba a haber
# la gestión anterior había terminado con una tasa de inflación del 2 mensual estar en el 1,5 no es un gran logro analizó
# además lozano sostuvo que la inflación en ningún momento estuvo por debajo del 1,5 y que una parte de la desaceleración de los precios tuvo que ver con el momento recesivo que atravesó el país por eso ante los primeros signos de reactivación económica es lógico que los precios se disparen
# de todos modos lozano expresó que uno de las causantes ha sido la salida del shock inflacionario que cambiemos había generado en el 2016 lo que produjo una baja relativa que terminó por invertirse con los primeros signos de reactivación económica
# sin embargo el especialista asegura que tal repunte no se debe a la inversión productiva sino a los elevados niveles de endeudamiento
# en cuanto al futuro inmediato el economista prevé que la inflación llegará al 25 para fin de año casi 8 puntos por encima de lo que estipulaba el macrismo
# hasta acá nos venimos sosteniendo únicamente con endeudamiento que en vistas del presupuesto del 2018 pretende sostenerse en el tiempo
# la combinatoria entre renta financiera a contramano de la inversión precio de los alimentos caros salario real barato y bajo consumo del sector industrial es una combinación preocupante alertó
# por último afirmó seguimos tan estancados como antes y con problemas de precios con el agravante que tenemos los alimentos y los servicios caros y consecuentemente salarios reales en caída y bajo nivel de demanda en el sector industrial
# producción periodística de gonzalo zanotti y joaquín rodríguez freire
# cristina kirchner volvió a la carga contra el gobierno está saqueando los bolsillos la candidata a senadora nacional por la provincia de buenos aires de unidad ciudadana cristina kirchner afirmó que el gobierno de mauricio macri está saqueando bolsillos
# además destacó el papel del intendente de hurligham juan zabaleta quien dejó el espacio de florencio randazzo para apoyar al kirchnerismo
# al encabezar un acto en villa tesei la exmandataria planteó que desde cambiemos están saqueando los bolsillos las finanzas del estado y las posibilidades de desarrollo a futuro
# en este marco cristina señaló que cambiemos en 18 meses de gestión importó más petróleo que durante los ocho años de su gobierno
# el aumento de las tarifas es porque los dueños de las empresas son ellos acusó
# además insistió en que en su mandato no existía desabastecimiento energético sino el apetito voraz de vaciar los bolsillos de los argentinos para las empresas de electricidad y gas y el impacto que esto ha tenido
# asimismo cuestionó a la oposición que pone más énfasis tiempo y prensa en criticar a unidad ciudadana que en denunciar estas cosas que le están pasando al pueblo
# quiero agradecerte la actitud de un compañero que hoy está junto a nosotros que no significa ni arrepentirse de donde estuvo sino que los que han obtenido la voluntad popular sean reconocidos le dijo a zabaleta al considerar que es necesario canalizar en un espacio el lugar para poner un límite al ajuste
# por último la exmandataria habló de las elecciones presidenciales del 2019 y la necesidad de buscar una alternativa al modelo del oficialismo no se cierren ni se encaprichen con nada
# sean inteligentes para tener la grandeza de construir una opción diferente
# acá estamos los que todos los días ponemos el cuerpo y el alma escuchando a nuestra gente
# acá estamos los que no dudamos en estar juntos para ganarle a macri arengó por su parte zabaleta
# la destitución de gils carbó será un tema central para el gobierno después de las elecciones ante la pregunta sobre en qué puede influir una derrota del kirchnerismo en las elecciones legislativas frente al proceso de destitución de la procuradora que impulsa el ejecutivo indicó que la importancia que tiene la elección tiene que ver con la composición del congreso porque lo que ha tenido hasta ahora el kirchnerismo es una minoría que ha bloqueado su juicio
# el sitio de televisión cartelera de cine música moda y entretenimiento de la voz del interior en infama le consultaron a barbie vélez sobre su supuesta relación con el empresario patricio silberman el ex de karina jelinek y ella negó la vinculación sentimental
# no es verdad de hecho las declaraciones que salen en la revista son las que dije en susana hace bastante tiempo y medio que las pusieron como si fuesen actuales denunció la joven
# cuando le consultaron si este romance estaba armado para desviar la atención de su amorío con el hijo de fabián rodríguez marido de su madre ella dijo me parece una guachada sinceramente
# además si estuviera saliendo con lucas o con quien fuere no estoy saliendo con alguien casado que tiene hijos que tiene familia
# sinceramente estoy contenta y con alguien con el que realmente no estoy en el momento de blanquearlo
# pero tampoco estoy para ocultarlo y esconderlo armando toda una pareja eso ya me parece una locura
# mirá el video acá
# atacan a huevazos a mauricio macri en la pampa
# harvey weinstein la caída del señor hollywood las acusaciones más escandalosas ashley juddfue de las primeras en denunciar aunque demoró más de 20 años
# en 1996 llegó al hotel donde se hospedaba weinstein creyendo que asistía a un reunión de negocios
# el productor apareció en bata de baño y le pidió un masaje y que lo viera ducharse
# gwyneth paltrow tenía 22 años cuando harvey weinstein la manoseó en la suite de un hotel de beverly hills
# angelina jolie contó que él avanzó sobre ella en una habitación de hotel pero ella lo rechazó
# lucia evansdijo que al llegar a un casting weinstein la atacó sexualmente y la obligó a practicarle sexo oral
# ambra battilana gutiérrez ex finalista del miss italia contó que en 2015 weinstein se le lanzó tocó sus pechos y trató de meter la mano por debajo de su minifalda
# cara delevingne asegura que weinstein le pidió hacer un trío
# lea seydoux dijo que se avalanzó sobre ella e intentó besarla
# katherine kendallacompañó al productor a su casa en 1993 cuando llegaron weinstein se desvistió y la persiguió desnudo por toda la casa
# asia argentodenunció que weinstein le quitó la falda y la forzó a practicar sexo oral
# mira sorvino dijo que intentó sobrepasarse con ella pero la actriz lo rechazó y se fue
# rosanna arquette contó que ella se negó a masturbarlo

# %% [markdown]
# ## Phrase Modeling with Gensim

# %% [markdown]
# Phrase modeling is a form of text manipulation that consists in producing new one token words from two or more tokens. As we saw in named entity recognition, there are groups of words that represent things that have nothing to do with the single words themselves that make up the group. For example *New York* is supposed to be different in meaning from *New* and *York*. We would like to have these single token words joined together in a single word, with an underscore instead of a space.
#
# There is a very simple formula for measuring the co-occurrence of these composite words in the corpus, meaning the frequency these words appear together in sequence, compared to the frequency they appear alone. We will use gensim to achieve this task.
